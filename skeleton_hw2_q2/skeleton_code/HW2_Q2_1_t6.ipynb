# %% [markdown]
# # Deep Learning Homework 2 - Question 2.1
# ## RNA Binding Protein (RBP) Interaction Prediction

# %% [markdown]
# ## 1. Setup and Imports

# %%
# Install required packages
# !pip install openpyxl -q

# %%
import os
import random
import time
import itertools
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from typing import List, Tuple

# Create Output Directory
OUTPUT_DIR = 'Outputs_t6'
os.makedirs(OUTPUT_DIR, exist_ok=True)

# Check device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# Using device: cuda
# GPU: NVIDIA GeForce RTX 4060 Laptop GPU

# %% [markdown]
# ## 2. Download Data
#
# Download the data files from the Google Drive link provided in the homework:
# - `norm_data.txt`
# - `metadata.xlsx`
#
# Upload them to Colab or mount your Google Drive.

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
# Set the path to your data files
DATA_DIR = 'data'  # Change this to your folder path

# %% [markdown]
# ## 3. Configuration and Utility Functions

# %%
from config import RNAConfig

# %%
from utils import configure_seed, masked_mse_loss, masked_spearman_correlation

configure_seed(42)

# %% [markdown]
# ## 4. Data Loader

# %%
from utils import RNACompeteLoader, load_rnacompete_data

# %% [markdown]
# ## 5. Model Definitions
#
# ### 5.1 CNN Model

# %%
class RNABindingCNN(nn.Module):
    """
    1D Convolutional Neural Network for RNA sequence binding prediction.

    Architecture:
    - 3 convolutional layers with increasing channels (64 -> 128 -> 256)
    - Batch normalization after each conv layer
    - ReLU activation and dropout for regularization
    - Global max + average pooling for richer representation
    - 2 fully connected layers for regression output
    """

    def __init__(self, input_channels=4, seq_length=41, hidden_dim=128, dropout=0.3):
        super(RNABindingCNN, self).__init__()
        #L_out = ((L_in + 2P - K) / S)  + 1

        # Convolutional layers with different kernel sizes to capture various motif lengths
        # Padding choices allow to preserve input length through the feature maps
        #L_out = 41
        self.conv1 = nn.Conv1d(input_channels, 64, kernel_size=5, padding=2)
        self.bn1 = nn.BatchNorm1d(64)

        #L_out = 41
        self.conv2 = nn.Conv1d(64, 128, kernel_size=7, padding=3)
        self.bn2 = nn.BatchNorm1d(128)

        #L_out = 41
        self.conv3 = nn.Conv1d(128, 256, kernel_size=9, padding=4)
        self.bn3 = nn.BatchNorm1d(256)

        self.dropout = nn.Dropout(dropout)

        # Global pooling (both max and average)
        # allows to get the strongest value of a given feature for the sequence
        self.global_max_pool = nn.AdaptiveMaxPool1d(1)
        # allows to get the average of how much a feature is present throughout the sequence
        self.global_avg_pool = nn.AdaptiveAvgPool1d(1)

        # Fully connected layers
        self.fc1 = nn.Linear(256 * 2, hidden_dim)  # *2 for concat of max and avg pool
        self.fc2 = nn.Linear(hidden_dim, 1)
        self.relu = nn.ReLU()

    def forward(self, x):
        # Input x shape: (batch, seq_length, 4)
        # Conv1d expects: (batch, channels, seq_length)
        x = x.permute(0, 2, 1)

        # Convolutional blocks
        x = self.relu(self.bn1(self.conv1(x)))
        x = self.dropout(x)

        x = self.relu(self.bn2(self.conv2(x)))
        x = self.dropout(x)

        x = self.relu(self.bn3(self.conv3(x)))
        x = self.dropout(x)

        # Global pooling
        max_pool = self.global_max_pool(x).squeeze(-1)
        avg_pool = self.global_avg_pool(x).squeeze(-1)
        x = torch.cat([max_pool, avg_pool], dim=1)

        # Fully connected layers
        x = self.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.fc2(x)

        return x

# %% [markdown]
# ### 5.2 LSTM Model

# %%
class RNABindingLSTM(nn.Module):
    """
    Bidirectional LSTM for RNA sequence binding prediction.

    Architecture:
    - 2-layer bidirectional LSTM
    - Batch normalization
    - Dropout for regularization
    - 2 fully connected layers for regression
    """

    def __init__(self, input_dim=4, hidden_dim=128, num_layers=2, dropout=0.3, bidirectional=True):
        super(RNABindingLSTM, self).__init__()

        self.hidden_dim = hidden_dim
        self.num_layers = num_layers
        self.bidirectional = bidirectional
        self.num_directions = 2 if bidirectional else 1

        self.lstm = nn.LSTM(
            input_size=input_dim,
            hidden_size=hidden_dim,
            num_layers=num_layers,
            batch_first=True,
            dropout=dropout if num_layers > 1 else 0,
            bidirectional=bidirectional
        )

        self.bn = nn.BatchNorm1d(hidden_dim * self.num_directions)
        self.dropout = nn.Dropout(dropout)

        self.fc1 = nn.Linear(hidden_dim * self.num_directions, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, 1)
        self.relu = nn.ReLU()

    def forward(self, x):
        # Input x shape: (batch, seq_length, 4)
        lstm_out, (hidden, cell) = self.lstm(x)

        if self.bidirectional:
            # Concatenate last hidden states from forward and backward
            hidden_forward = hidden[-2, :, :]
            hidden_backward = hidden[-1, :, :]
            combined = torch.cat([hidden_forward, hidden_backward], dim=1)
        else:
            combined = hidden[-1, :, :]

        combined = self.bn(combined)
        combined = self.dropout(combined)

        x = self.relu(self.fc1(combined))
        x = self.dropout(x)
        x = self.fc2(x)

        return x

# %% [markdown]
# ## 6. Training and Evaluation Functions

# %%
def train_epoch(model, train_loader, optimizer, device):
    """Train for one epoch and return loss and correlation."""
    model.train()
    total_loss = 0.0
    num_batches = 0
    
    all_preds = []
    all_targets = []
    all_masks = []

    for batch in train_loader:
        x, y, mask = batch
        x, y, mask = x.to(device), y.to(device), mask.to(device)

        optimizer.zero_grad()
        predictions = model(x)
        loss = masked_mse_loss(predictions, y, mask)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()

        total_loss += loss.item()
        num_batches += 1
        
        # Collect for metric calculation
        all_preds.append(predictions.detach().cpu())
        all_targets.append(y.detach().cpu())
        all_masks.append(mask.detach().cpu())

    all_preds = torch.cat(all_preds, dim=0)
    all_targets = torch.cat(all_targets, dim=0)
    all_masks = torch.cat(all_masks, dim=0)
    
    spearman_corr = masked_spearman_correlation(all_preds, all_targets, all_masks)

    return total_loss / num_batches, spearman_corr.item()


def evaluate(model, data_loader, device):
    """Evaluate model and return loss and Spearman correlation."""
    model.eval()
    total_loss = 0.0
    num_batches = 0

    all_preds = []
    all_targets = []
    all_masks = []

    with torch.no_grad():
        for batch in data_loader:
            x, y, mask = batch
            x, y, mask = x.to(device), y.to(device), mask.to(device)

            predictions = model(x)
            loss = masked_mse_loss(predictions, y, mask)

            total_loss += loss.item()
            num_batches += 1

            all_preds.append(predictions.cpu())
            all_targets.append(y.cpu())
            all_masks.append(mask.cpu())

    all_preds = torch.cat(all_preds, dim=0)
    all_targets = torch.cat(all_targets, dim=0)
    all_masks = torch.cat(all_masks, dim=0)

    spearman_corr = masked_spearman_correlation(all_preds, all_targets, all_masks)

    return total_loss / num_batches, spearman_corr.item()


def train_model(model, train_loader, val_loader, optimizer, scheduler, device,
                num_epochs, model_name, patience=15, save_every=10):
    """Full training loop with early stopping and periodic checkpoints."""
    print(f"\n{'='*60}")
    print(f"Training {model_name}")
    print(f"{'='*60}")

    train_losses = []
    train_correlations = []
    val_losses = []
    val_correlations = []

    best_val_corr = -float('inf')
    best_model_state = None
    epochs_without_improvement = 0

    start_time = time.time()

    for epoch in range(num_epochs):
        epoch_start = time.time()

        train_loss, train_corr = train_epoch(model, train_loader, optimizer, device)
        val_loss, val_corr = evaluate(model, val_loader, device)

        if scheduler is not None:
            scheduler.step(val_corr)

        train_losses.append(train_loss)
        train_correlations.append(train_corr)
        val_losses.append(val_loss)
        val_correlations.append(val_corr)

        if val_corr > best_val_corr:
            best_val_corr = val_corr
            best_model_state = {k: v.cpu().clone() for k, v in model.state_dict().items()}
            epochs_without_improvement = 0
            # Save best model to Output directory
            torch.save(best_model_state, f'{OUTPUT_DIR}/{model_name}_best_t6.pth')
            print(f"  → Saved new best model (Spearman: {val_corr:.4f})")
        else:
            epochs_without_improvement += 1

        epoch_time = time.time() - epoch_start

        if (epoch + 1) % 5 == 0 or epoch == 0:
            print(f"Epoch {epoch+1:3d}/{num_epochs} | "
                  f"Train Loss: {train_loss:.4f} | "
                  f"Val Loss: {val_loss:.4f} | "
                  f"Train Spearman: {train_corr:.4f} | "
                  f"Val Spearman: {val_corr:.4f} | "
                  f"Time: {epoch_time:.2f}s")

        # Periodic checkpoint every N epochs
        if (epoch + 1) % save_every == 0:
            checkpoint = {
                'epoch': epoch + 1,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'train_losses': train_losses,
                'train_correlations': train_correlations,
                'val_losses': val_losses,
                'val_correlations': val_correlations,
                'best_val_corr': best_val_corr
            }
            torch.save(checkpoint, f'{OUTPUT_DIR}/{model_name}_checkpoint_epoch{epoch+1}_t6.pth')
            print(f"  → Checkpoint saved at epoch {epoch+1}")

        if epochs_without_improvement >= patience:
            print(f"\nEarly stopping at epoch {epoch+1}")
            break

    total_time = time.time() - start_time

    if best_model_state is not None:
        model.load_state_dict(best_model_state)

    print(f"\nTraining completed in {total_time:.2f}s")
    print(f"Best validation Spearman correlation: {best_val_corr:.4f}")

    return {
        'train_losses': train_losses,
        'train_correlations': train_correlations,
        'val_losses': val_losses,
        'val_correlations': val_correlations,
        'best_val_corr': best_val_corr,
        'training_time': total_time
    }

# %% [markdown]
# ## 7. Load Data

# %%
PROTEIN_NAME = 'RBFOX1'
BATCH_SIZE = 64

# Load data
print(f"Loading data for protein: {PROTEIN_NAME}")
config = RNAConfig()

train_dataset = load_rnacompete_data(PROTEIN_NAME, split='train', config=config)
val_dataset = load_rnacompete_data(PROTEIN_NAME, split='val', config=config)
test_dataset = load_rnacompete_data(PROTEIN_NAME, split='test', config=config)

print(f"\nDataset sizes:")
print(f"  Train: {len(train_dataset)}")
print(f"  Val: {len(val_dataset)}")
print(f"  Test: {len(test_dataset)}")

# Create data loaders
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)
# Out:
# Loading data for protein: RBFOX1
# Found cached data for RBFOX1 (train). Loading from data/RBFOX1_train_data.pt...
# Found cached data for RBFOX1 (val). Loading from data/RBFOX1_val_data.pt...
# Found cached data for RBFOX1 (test). Loading from data/RBFOX1_test_data.pt...
#
# Dataset sizes:
#   Train: 96261
#   Val: 24065
#   Test: 121031

# %% [markdown]
# ## 8. Hyperparameter Search and Training
#
# Here we define the search space and a function to iterate through hyperparameters, training the model for each combination.

# %%
# --- ROBUST GRID SEARCH (12 Combinations) ---
# for train_model with patience 7, and scheduler patience 5
# POSSIBLE HYPERPARAMETER TO ADD- SHCEDULER PATIENCE, INFLUENCES HOW LR CHANGES
cnn_param_grid = {
    'learning_rate': [0.00001, 0.00006, 0.0001, 0.0005, 0.001, 0.003, 0.005],
    'hidden_dim': [256],
    'dropout': [0.3]
}

lstm_param_grid = {
    'learning_rate': [0.00001, 0.00006, 0.0001, 0.0003, 0.0005, 0.0007, 0.001],
    'hidden_dim': [256],
    'dropout': [0.4]
}

#simply fast grid to test if code runs well
# param_grid = {
#     # Covers best LSTM (0.001), best CNN (0.0001) and midpoint (0.0005)
#     'learning_rate': [0.0001],
#     # Tests if doubling capacity improves results
#     'hidden_dim': [2],
#     # Standard regularization vs Stronger regularization (for larger models)
#     'dropout': [0.8]
# }

def hyperparameter_search(model_class, model_name, param_grid, train_loader, val_loader, device, epochs=50):
    keys, values = zip(*param_grid.items())
    experiments = [dict(zip(keys, v)) for v in itertools.product(*values)]
    
    best_val_corr = -float('inf')
    best_config = None
    best_history = None
    
    print(f"Starting Hyperparameter Search for {model_name} with {len(experiments)} configurations...")
    
    results = []
    # Define a path for the intermediate results
    results_path = f'{OUTPUT_DIR}/{model_name}_search_results_t6.json'
    
    for i, config in enumerate(experiments):
        print(f"\nRunning experiment {i+1}/{len(experiments)}: {config}")
        
        configure_seed(42)
        
        # Initialize model with current config
        # Note: LSTM and CNN have slightly different init signatures if not careful,
        # but here we matched the param names in the grid to the init args
        if model_name == 'LSTM':
             model = model_class(
                hidden_dim=config['hidden_dim'],
                dropout=config['dropout']
            ).to(device)
        else:
             model = model_class(
                hidden_dim=config['hidden_dim'],
                dropout=config['dropout']
            ).to(device)
            
        optimizer = optim.Adam(model.parameters(), lr=config['learning_rate'], weight_decay=1e-5)
        scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', factor=0.5, patience=5)
        
        # Train - using fewer epochs for search to save time (can increase for final result)
        # We use a unique name for temporary checkpoints
        temp_name = f"{model_name}_exp{i}"
        history = train_model(
            model, train_loader, val_loader, optimizer, scheduler,
            device, num_epochs=epochs, model_name=temp_name, patience=7, save_every=100
        )
        
        # --- SAVE PROGRESS IMMEDIATELY ---
        run_result = {
            'experiment_index': i,
            'config': config,
            'best_val_corr': history['best_val_corr'],
            'training_time': history['training_time'],
            'history': history # Full history included for plotting/resuming
        }
        results.append(run_result)
        
        try:
            with open(results_path, 'w') as f:
                json.dump(results, f, indent=4)
            print(f"  → Search progress saved to {results_path}")
        except Exception as e:
            print(f"  → Warning: Could not save progress to JSON: {e}")

        if history['best_val_corr'] > best_val_corr:
            best_val_corr = history['best_val_corr']
            best_config = config
            best_history = history
            
            # Save the best model of the search as the final best model
            # We load the best state from the temp file and save it to the final destination
            best_state = torch.load(f'{OUTPUT_DIR}/{temp_name}_best_t6.pth')
            torch.save(best_state, f'{OUTPUT_DIR}/best_{model_name.lower()}_model_t6.pth')
            
    print(f"\n{'='*60}")
    print(f"Best {model_name} configuration: {best_config}")
    print(f"Best validation Spearman: {best_val_corr:.4f}")
    print(f"Best model saved to {OUTPUT_DIR}/best_{model_name.lower()}_model_t6.pth")
    print(f"{'='*60}")
    
    return best_config, best_history

# %%
# 8.1 Train and Search CNN
print("---- Tuning CNN ----")
best_cnn_config, cnn_history = hyperparameter_search(
    RNABindingCNN, 'CNN', cnn_param_grid, train_loader, val_loader, device, epochs=50
)
# Out:
# ---- Tuning CNN ----
# Starting Hyperparameter Search for CNN with 7 configurations...
#
# Running experiment 1/7: {'learning_rate': 1e-05, 'hidden_dim': 256, 'dropout': 0.3}
#
# ============================================================
# Training CNN_exp0
# ============================================================
#   → Saved new best model (Spearman: 0.3963)
# Epoch   1/50 | Train Loss: 0.9908 | Val Loss: 0.9063 | Train Spearman: 0.1440 | Val Spearman: 0.3963 | Time: 20.37s
#   → Saved new best model (Spearman: 0.4720)
#   → Saved new best model (Spearman: 0.4770)
#   → Saved new best model (Spearman: 0.4807)
#   → Saved new best model (Spearman: 0.4855)
# Epoch   5/50 | Train Loss: 0.6763 | Val Loss: 0.6800 | Train Spearman: 0.4336 | Val Spearman: 0.4855 | Time: 18.77s
#   → Saved new best model (Spearman: 0.4897)
#   → Saved new best model (Spearman: 0.4947)
#   → Saved new best model (Spearman: 0.4991)
#   → Saved new best model (Spearman: 0.5052)
#   → Saved new best model (Spearman: 0.5100)
# Epoch  10/50 | Train Loss: 0.5818 | Val Loss: 0.6427 | Train Spearman: 0.4681 | Val Spearman: 0.5100 | Time: 18.98s
#   → Saved new best model (Spearman: 0.5156)
#   → Saved new best model (Spearman: 0.5169)
#   → Saved new best model (Spearman: 0.5251)
#   → Saved new best model (Spearman: 0.5271)
# Epoch  15/50 | Train Loss: 0.5493 | Val Loss: 0.6666 | Train Spearman: 0.4874 | Val Spearman: 0.5261 | Time: 18.77s
#   → Saved new best model (Spearman: 0.5311)
#   → Saved new best model (Spearman: 0.5339)
#   → Saved new best model (Spearman: 0.5382)
#   → Saved new best model (Spearman: 0.5392)
#   → Saved new best model (Spearman: 0.5413)
# Epoch  20/50 | Train Loss: 0.5287 | Val Loss: 0.5836 | Train Spearman: 0.5008 | Val Spearman: 0.5413 | Time: 18.27s
#   → Saved new best model (Spearman: 0.5447)
#   → Saved new best model (Spearman: 0.5470)
#   → Saved new best model (Spearman: 0.5478)
#   → Saved new best model (Spearman: 0.5529)
#   → Saved new best model (Spearman: 0.5534)
# Epoch  25/50 | Train Loss: 0.5080 | Val Loss: 0.5404 | Train Spearman: 0.5146 | Val Spearman: 0.5534 | Time: 18.54s
#   → Saved new best model (Spearman: 0.5566)
#   → Saved new best model (Spearman: 0.5636)
#   → Saved new best model (Spearman: 0.5662)
#   → Saved new best model (Spearman: 0.5665)
#   → Saved new best model (Spearman: 0.5729)
# Epoch  30/50 | Train Loss: 0.4853 | Val Loss: 0.5221 | Train Spearman: 0.5305 | Val Spearman: 0.5729 | Time: 19.23s
#   → Saved new best model (Spearman: 0.5738)
#   → Saved new best model (Spearman: 0.5753)
#   → Saved new best model (Spearman: 0.5775)
#   → Saved new best model (Spearman: 0.5821)
#   → Saved new best model (Spearman: 0.5867)
# Epoch  35/50 | Train Loss: 0.4700 | Val Loss: 0.5018 | Train Spearman: 0.5456 | Val Spearman: 0.5867 | Time: 18.62s
#   → Saved new best model (Spearman: 0.5874)
#   → Saved new best model (Spearman: 0.5930)
#   → Saved new best model (Spearman: 0.5980)
# Epoch  40/50 | Train Loss: 0.4570 | Val Loss: 0.4615 | Train Spearman: 0.5597 | Val Spearman: 0.5980 | Time: 18.91s
#   → Saved new best model (Spearman: 0.5998)
#   → Saved new best model (Spearman: 0.6029)
#   → Saved new best model (Spearman: 0.6040)
#   → Saved new best model (Spearman: 0.6068)
# Epoch  45/50 | Train Loss: 0.4472 | Val Loss: 0.4670 | Train Spearman: 0.5671 | Val Spearman: 0.6068 | Time: 19.13s
#   → Saved new best model (Spearman: 0.6074)
#   → Saved new best model (Spearman: 0.6079)
#   → Saved new best model (Spearman: 0.6089)
# Epoch  50/50 | Train Loss: 0.4368 | Val Loss: 0.4511 | Train Spearman: 0.5770 | Val Spearman: 0.6089 | Time: 18.47s
#
# Training completed in 917.50s
# Best validation Spearman correlation: 0.6089
#   → Search progress saved to Outputs_t6/CNN_search_results_t6.json
#
# Running experiment 2/7: {'learning_rate': 6e-05, 'hidden_dim': 256, 'dropout': 0.3}
#
# ============================================================
# Training CNN_exp1
# ============================================================
#   → Saved new best model (Spearman: 0.4897)
# Epoch   1/50 | Train Loss: 0.7994 | Val Loss: 0.6574 | Train Spearman: 0.3579 | Val Spearman: 0.4897 | Time: 19.58s
#   → Saved new best model (Spearman: 0.5158)
#   → Saved new best model (Spearman: 0.5279)
#   → Saved new best model (Spearman: 0.5432)
#   → Saved new best model (Spearman: 0.5562)
# Epoch   5/50 | Train Loss: 0.5104 | Val Loss: 0.4908 | Train Spearman: 0.5061 | Val Spearman: 0.5562 | Time: 18.91s
#   → Saved new best model (Spearman: 0.5706)
#   → Saved new best model (Spearman: 0.5858)
#   → Saved new best model (Spearman: 0.5974)
#   → Saved new best model (Spearman: 0.6042)
#   → Saved new best model (Spearman: 0.6137)
# Epoch  10/50 | Train Loss: 0.4456 | Val Loss: 0.4053 | Train Spearman: 0.5657 | Val Spearman: 0.6137 | Time: 18.37s
#   → Saved new best model (Spearman: 0.6204)
#   → Saved new best model (Spearman: 0.6210)
#   → Saved new best model (Spearman: 0.6264)
#   → Saved new best model (Spearman: 0.6300)
# Epoch  15/50 | Train Loss: 0.4125 | Val Loss: 0.3902 | Train Spearman: 0.5883 | Val Spearman: 0.6291 | Time: 18.46s
#   → Saved new best model (Spearman: 0.6330)
#   → Saved new best model (Spearman: 0.6376)
#   → Saved new best model (Spearman: 0.6419)
# Epoch  20/50 | Train Loss: 0.3948 | Val Loss: 0.3744 | Train Spearman: 0.6002 | Val Spearman: 0.6417 | Time: 18.65s
#   → Saved new best model (Spearman: 0.6441)
#   → Saved new best model (Spearman: 0.6449)
#   → Saved new best model (Spearman: 0.6473)
# Epoch  25/50 | Train Loss: 0.3811 | Val Loss: 0.3821 | Train Spearman: 0.6092 | Val Spearman: 0.6461 | Time: 19.20s
#   → Saved new best model (Spearman: 0.6498)
#   → Saved new best model (Spearman: 0.6506)
# Epoch  30/50 | Train Loss: 0.3674 | Val Loss: 0.3610 | Train Spearman: 0.6173 | Val Spearman: 0.6506 | Time: 17.70s
#   → Saved new best model (Spearman: 0.6518)
# Epoch  35/50 | Train Loss: 0.3605 | Val Loss: 0.3712 | Train Spearman: 0.6195 | Val Spearman: 0.6514 | Time: 18.36s
#   → Saved new best model (Spearman: 0.6542)
# Epoch  40/50 | Train Loss: 0.3504 | Val Loss: 0.3711 | Train Spearman: 0.6248 | Val Spearman: 0.6530 | Time: 18.64s
#   → Saved new best model (Spearman: 0.6548)
# Epoch  45/50 | Train Loss: 0.3413 | Val Loss: 0.3604 | Train Spearman: 0.6326 | Val Spearman: 0.6548 | Time: 18.48s
#   → Saved new best model (Spearman: 0.6556)
#   → Saved new best model (Spearman: 0.6598)
# Epoch  50/50 | Train Loss: 0.3314 | Val Loss: 0.3484 | Train Spearman: 0.6362 | Val Spearman: 0.6598 | Time: 18.43s
#
# Training completed in 930.70s
# Best validation Spearman correlation: 0.6598
#   → Search progress saved to Outputs_t6/CNN_search_results_t6.json
#
# Running experiment 3/7: {'learning_rate': 0.0001, 'hidden_dim': 256, 'dropout': 0.3}
#
# ============================================================
# Training CNN_exp2
# ============================================================
#   → Saved new best model (Spearman: 0.5082)
# Epoch   1/50 | Train Loss: 0.7296 | Val Loss: 0.5917 | Train Spearman: 0.3909 | Val Spearman: 0.5082 | Time: 18.00s
#   → Saved new best model (Spearman: 0.5313)
#   → Saved new best model (Spearman: 0.5429)
#   → Saved new best model (Spearman: 0.5681)
#   → Saved new best model (Spearman: 0.5874)
# Epoch   5/50 | Train Loss: 0.4804 | Val Loss: 0.4429 | Train Spearman: 0.5318 | Val Spearman: 0.5874 | Time: 19.49s
#   → Saved new best model (Spearman: 0.5997)
#   → Saved new best model (Spearman: 0.6057)
#   → Saved new best model (Spearman: 0.6151)
#   → Saved new best model (Spearman: 0.6221)
#   → Saved new best model (Spearman: 0.6258)
# Epoch  10/50 | Train Loss: 0.4261 | Val Loss: 0.4079 | Train Spearman: 0.5805 | Val Spearman: 0.6258 | Time: 19.88s
#   → Saved new best model (Spearman: 0.6309)
#   → Saved new best model (Spearman: 0.6330)
#   → Saved new best model (Spearman: 0.6369)
#   → Saved new best model (Spearman: 0.6387)
#   → Saved new best model (Spearman: 0.6398)
# Epoch  15/50 | Train Loss: 0.3983 | Val Loss: 0.3761 | Train Spearman: 0.5985 | Val Spearman: 0.6398 | Time: 19.36s
#   → Saved new best model (Spearman: 0.6428)
#   → Saved new best model (Spearman: 0.6438)
#   → Saved new best model (Spearman: 0.6459)
#   → Saved new best model (Spearman: 0.6471)
# Epoch  20/50 | Train Loss: 0.3806 | Val Loss: 0.3707 | Train Spearman: 0.6068 | Val Spearman: 0.6471 | Time: 18.96s
#   → Saved new best model (Spearman: 0.6497)
# Epoch  25/50 | Train Loss: 0.3683 | Val Loss: 0.4070 | Train Spearman: 0.6163 | Val Spearman: 0.6478 | Time: 18.43s
#   → Saved new best model (Spearman: 0.6507)
#   → Saved new best model (Spearman: 0.6557)
# Epoch  30/50 | Train Loss: 0.3570 | Val Loss: 0.3647 | Train Spearman: 0.6221 | Val Spearman: 0.6550 | Time: 19.18s
# Epoch  35/50 | Train Loss: 0.3397 | Val Loss: 0.3666 | Train Spearman: 0.6303 | Val Spearman: 0.6534 | Time: 18.60s
#
# Early stopping at epoch 35
#
# Training completed in 658.86s
# Best validation Spearman correlation: 0.6557
#   → Search progress saved to Outputs_t6/CNN_search_results_t6.json
#
# Running experiment 4/7: {'learning_rate': 0.0005, 'hidden_dim': 256, 'dropout': 0.3}
#
# ============================================================
# Training CNN_exp3
# ============================================================
#   → Saved new best model (Spearman: 0.5389)
# Epoch   1/50 | Train Loss: 0.6299 | Val Loss: 0.4937 | Train Spearman: 0.4405 | Val Spearman: 0.5389 | Time: 18.79s
#   → Saved new best model (Spearman: 0.5700)
#   → Saved new best model (Spearman: 0.5964)
#   → Saved new best model (Spearman: 0.5981)
#   → Saved new best model (Spearman: 0.6090)
# Epoch   5/50 | Train Loss: 0.4495 | Val Loss: 0.4277 | Train Spearman: 0.5604 | Val Spearman: 0.6090 | Time: 19.06s
#   → Saved new best model (Spearman: 0.6222)
#   → Saved new best model (Spearman: 0.6260)
#   → Saved new best model (Spearman: 0.6324)
#   → Saved new best model (Spearman: 0.6338)
#   → Saved new best model (Spearman: 0.6351)
# Epoch  10/50 | Train Loss: 0.4122 | Val Loss: 0.3888 | Train Spearman: 0.5912 | Val Spearman: 0.6351 | Time: 18.81s
#   → Saved new best model (Spearman: 0.6376)
#   → Saved new best model (Spearman: 0.6392)
#   → Saved new best model (Spearman: 0.6411)
# Epoch  15/50 | Train Loss: 0.3935 | Val Loss: 0.3914 | Train Spearman: 0.6019 | Val Spearman: 0.6400 | Time: 18.96s
#   → Saved new best model (Spearman: 0.6439)
#   → Saved new best model (Spearman: 0.6483)
#   → Saved new best model (Spearman: 0.6502)
# Epoch  20/50 | Train Loss: 0.3808 | Val Loss: 0.3683 | Train Spearman: 0.6092 | Val Spearman: 0.6481 | Time: 18.23s
#   → Saved new best model (Spearman: 0.6509)
#   → Saved new best model (Spearman: 0.6534)
# Epoch  25/50 | Train Loss: 0.3702 | Val Loss: 0.3894 | Train Spearman: 0.6150 | Val Spearman: 0.6534 | Time: 19.21s
#   → Saved new best model (Spearman: 0.6548)
# Epoch  30/50 | Train Loss: 0.3591 | Val Loss: 0.3643 | Train Spearman: 0.6210 | Val Spearman: 0.6540 | Time: 18.78s
#   → Saved new best model (Spearman: 0.6555)
# Epoch  35/50 | Train Loss: 0.3415 | Val Loss: 0.3615 | Train Spearman: 0.6315 | Val Spearman: 0.6555 | Time: 19.18s
#   → Saved new best model (Spearman: 0.6606)
# Epoch  40/50 | Train Loss: 0.3303 | Val Loss: 0.3689 | Train Spearman: 0.6381 | Val Spearman: 0.6593 | Time: 18.57s
#   → Saved new best model (Spearman: 0.6609)
#   → Saved new best model (Spearman: 0.6611)
# Epoch  45/50 | Train Loss: 0.3220 | Val Loss: 0.3599 | Train Spearman: 0.6410 | Val Spearman: 0.6611 | Time: 18.60s
#   → Saved new best model (Spearman: 0.6631)
# Epoch  50/50 | Train Loss: 0.3166 | Val Loss: 0.3386 | Train Spearman: 0.6441 | Val Spearman: 0.6631 | Time: 18.49s
#
# Training completed in 939.49s
# Best validation Spearman correlation: 0.6631
#   → Search progress saved to Outputs_t6/CNN_search_results_t6.json
#
# Running experiment 5/7: {'learning_rate': 0.001, 'hidden_dim': 256, 'dropout': 0.3}
#
# ============================================================
# Training CNN_exp4
# ============================================================
#   → Saved new best model (Spearman: 0.5484)
# Epoch   1/50 | Train Loss: 0.6328 | Val Loss: 0.5268 | Train Spearman: 0.4396 | Val Spearman: 0.5484 | Time: 18.48s
#   → Saved new best model (Spearman: 0.5775)
#   → Saved new best model (Spearman: 0.5957)
#   → Saved new best model (Spearman: 0.6095)
#   → Saved new best model (Spearman: 0.6175)
# Epoch   5/50 | Train Loss: 0.4668 | Val Loss: 0.4156 | Train Spearman: 0.5552 | Val Spearman: 0.6175 | Time: 18.45s
#   → Saved new best model (Spearman: 0.6217)
#   → Saved new best model (Spearman: 0.6277)
#   → Saved new best model (Spearman: 0.6306)
#   → Saved new best model (Spearman: 0.6328)
# Epoch  10/50 | Train Loss: 0.4340 | Val Loss: 0.4395 | Train Spearman: 0.5814 | Val Spearman: 0.6328 | Time: 18.67s
#   → Saved new best model (Spearman: 0.6349)
#   → Saved new best model (Spearman: 0.6391)
#   → Saved new best model (Spearman: 0.6417)
#   → Saved new best model (Spearman: 0.6418)
# Epoch  15/50 | Train Loss: 0.4203 | Val Loss: 0.4379 | Train Spearman: 0.5949 | Val Spearman: 0.6418 | Time: 18.84s
#   → Saved new best model (Spearman: 0.6426)
#   → Saved new best model (Spearman: 0.6434)
#   → Saved new best model (Spearman: 0.6449)
#   → Saved new best model (Spearman: 0.6449)
# Epoch  20/50 | Train Loss: 0.4047 | Val Loss: 0.3707 | Train Spearman: 0.5968 | Val Spearman: 0.6449 | Time: 19.50s
#   → Saved new best model (Spearman: 0.6455)
#   → Saved new best model (Spearman: 0.6547)
# Epoch  25/50 | Train Loss: 0.3910 | Val Loss: 0.3907 | Train Spearman: 0.6065 | Val Spearman: 0.6547 | Time: 19.04s
# Epoch  30/50 | Train Loss: 0.3858 | Val Loss: 0.3896 | Train Spearman: 0.6098 | Val Spearman: 0.6492 | Time: 18.75s
#   → Saved new best model (Spearman: 0.6559)
#   → Saved new best model (Spearman: 0.6572)
# Epoch  35/50 | Train Loss: 0.3785 | Val Loss: 0.3647 | Train Spearman: 0.6131 | Val Spearman: 0.6539 | Time: 18.91s
#   → Saved new best model (Spearman: 0.6620)
# Epoch  40/50 | Train Loss: 0.3466 | Val Loss: 0.3691 | Train Spearman: 0.6292 | Val Spearman: 0.6617 | Time: 18.36s
#   → Saved new best model (Spearman: 0.6650)
# Epoch  45/50 | Train Loss: 0.3401 | Val Loss: 0.3777 | Train Spearman: 0.6365 | Val Spearman: 0.6642 | Time: 18.55s
#   → Saved new best model (Spearman: 0.6656)
#   → Saved new best model (Spearman: 0.6658)
# Epoch  50/50 | Train Loss: 0.3339 | Val Loss: 0.3475 | Train Spearman: 0.6386 | Val Spearman: 0.6640 | Time: 19.17s
#
# Training completed in 928.02s
# Best validation Spearman correlation: 0.6658
#   → Search progress saved to Outputs_t6/CNN_search_results_t6.json
#
# Running experiment 6/7: {'learning_rate': 0.003, 'hidden_dim': 256, 'dropout': 0.3}
#
# ============================================================
# Training CNN_exp5
# ============================================================
#   → Saved new best model (Spearman: 0.5303)
# Epoch   1/50 | Train Loss: 0.7171 | Val Loss: 0.5633 | Train Spearman: 0.4227 | Val Spearman: 0.5303 | Time: 19.23s
#   → Saved new best model (Spearman: 0.5446)
#   → Saved new best model (Spearman: 0.5748)
#   → Saved new best model (Spearman: 0.5902)
#   → Saved new best model (Spearman: 0.6013)
# Epoch   5/50 | Train Loss: 0.5123 | Val Loss: 0.4824 | Train Spearman: 0.5282 | Val Spearman: 0.6013 | Time: 19.11s
#   → Saved new best model (Spearman: 0.6048)
#   → Saved new best model (Spearman: 0.6158)
#   → Saved new best model (Spearman: 0.6175)
#   → Saved new best model (Spearman: 0.6252)
# Epoch  10/50 | Train Loss: 0.4563 | Val Loss: 0.4133 | Train Spearman: 0.5624 | Val Spearman: 0.6252 | Time: 18.76s
#   → Saved new best model (Spearman: 0.6272)
#   → Saved new best model (Spearman: 0.6338)
# Epoch  15/50 | Train Loss: 0.4381 | Val Loss: 0.4657 | Train Spearman: 0.5786 | Val Spearman: 0.6338 | Time: 18.54s
#   → Saved new best model (Spearman: 0.6356)
# Epoch  20/50 | Train Loss: 0.4190 | Val Loss: 0.4293 | Train Spearman: 0.5848 | Val Spearman: 0.6290 | Time: 17.54s
#   → Saved new best model (Spearman: 0.6398)
#   → Saved new best model (Spearman: 0.6453)
# Epoch  25/50 | Train Loss: 0.4123 | Val Loss: 0.4511 | Train Spearman: 0.5917 | Val Spearman: 0.6453 | Time: 17.69s
#   → Saved new best model (Spearman: 0.6454)
# Epoch  30/50 | Train Loss: 0.4022 | Val Loss: 0.4569 | Train Spearman: 0.5932 | Val Spearman: 0.6371 | Time: 18.12s
#   → Saved new best model (Spearman: 0.6534)
# Epoch  35/50 | Train Loss: 0.3729 | Val Loss: 0.3686 | Train Spearman: 0.6146 | Val Spearman: 0.6531 | Time: 18.84s
#   → Saved new best model (Spearman: 0.6547)
#   → Saved new best model (Spearman: 0.6568)
# Epoch  40/50 | Train Loss: 0.3613 | Val Loss: 0.3974 | Train Spearman: 0.6169 | Val Spearman: 0.6564 | Time: 17.81s
#   → Saved new best model (Spearman: 0.6582)
# Epoch  45/50 | Train Loss: 0.3551 | Val Loss: 0.3845 | Train Spearman: 0.6209 | Val Spearman: 0.6573 | Time: 18.32s
#   → Saved new best model (Spearman: 0.6608)
# Epoch  50/50 | Train Loss: 0.3512 | Val Loss: 0.3682 | Train Spearman: 0.6227 | Val Spearman: 0.6579 | Time: 18.01s
#
# Training completed in 925.32s
# Best validation Spearman correlation: 0.6608
#   → Search progress saved to Outputs_t6/CNN_search_results_t6.json
#
# Running experiment 7/7: {'learning_rate': 0.005, 'hidden_dim': 256, 'dropout': 0.3}
#
# ============================================================
# Training CNN_exp6
# ============================================================
#   → Saved new best model (Spearman: 0.5125)
# Epoch   1/50 | Train Loss: 0.8915 | Val Loss: 0.5405 | Train Spearman: 0.3744 | Val Spearman: 0.5125 | Time: 18.59s
#   → Saved new best model (Spearman: 0.5365)
#   → Saved new best model (Spearman: 0.5519)
#   → Saved new best model (Spearman: 0.5662)
#   → Saved new best model (Spearman: 0.5929)
# Epoch   5/50 | Train Loss: 0.5130 | Val Loss: 0.4988 | Train Spearman: 0.5192 | Val Spearman: 0.5929 | Time: 18.49s
#   → Saved new best model (Spearman: 0.5994)
#   → Saved new best model (Spearman: 0.6092)
#   → Saved new best model (Spearman: 0.6096)
#   → Saved new best model (Spearman: 0.6135)
# Epoch  10/50 | Train Loss: 0.4647 | Val Loss: 0.4310 | Train Spearman: 0.5567 | Val Spearman: 0.6135 | Time: 18.61s
#   → Saved new best model (Spearman: 0.6171)
#   → Saved new best model (Spearman: 0.6182)
#   → Saved new best model (Spearman: 0.6187)
#   → Saved new best model (Spearman: 0.6236)
# Epoch  15/50 | Train Loss: 0.4502 | Val Loss: 0.5074 | Train Spearman: 0.5694 | Val Spearman: 0.6236 | Time: 18.85s
#   → Saved new best model (Spearman: 0.6259)
# Epoch  20/50 | Train Loss: 0.4429 | Val Loss: 0.3992 | Train Spearman: 0.5710 | Val Spearman: 0.6248 | Time: 18.30s
#   → Saved new best model (Spearman: 0.6332)
#   → Saved new best model (Spearman: 0.6382)
#   → Saved new best model (Spearman: 0.6456)
# Epoch  25/50 | Train Loss: 0.4016 | Val Loss: 0.4386 | Train Spearman: 0.5965 | Val Spearman: 0.6456 | Time: 18.55s
# Epoch  30/50 | Train Loss: 0.3959 | Val Loss: 0.4165 | Train Spearman: 0.5986 | Val Spearman: 0.6354 | Time: 17.70s
#
# Early stopping at epoch 32
#
# Training completed in 595.41s
# Best validation Spearman correlation: 0.6456
#   → Search progress saved to Outputs_t6/CNN_search_results_t6.json
#
# ============================================================
# Best CNN configuration: {'learning_rate': 0.001, 'hidden_dim': 256, 'dropout': 0.3}
# Best validation Spearman: 0.6658
# Best model saved to Outputs_t6/best_cnn_model_t6.pth
# ============================================================

# %%
# 8.2 Train and Search LSTM
print("---- Tuning LSTM ----")
best_lstm_config, lstm_history = hyperparameter_search(
    RNABindingLSTM, 'LSTM', lstm_param_grid, train_loader, val_loader, device, epochs=50
)
# Out:
# ---- Tuning LSTM ----
# Starting Hyperparameter Search for LSTM with 7 configurations...
#
# Running experiment 1/7: {'learning_rate': 1e-05, 'hidden_dim': 256, 'dropout': 0.4}
#
# ============================================================
# Training LSTM_exp0
# ============================================================
#   → Saved new best model (Spearman: 0.2309)
# Epoch   1/50 | Train Loss: 1.0538 | Val Loss: 0.9677 | Train Spearman: 0.0717 | Val Spearman: 0.2309 | Time: 40.97s
#   → Saved new best model (Spearman: 0.2405)
#   → Saved new best model (Spearman: 0.2502)
#   → Saved new best model (Spearman: 0.2598)
#   → Saved new best model (Spearman: 0.2679)
# Epoch   5/50 | Train Loss: 0.9929 | Val Loss: 0.9539 | Train Spearman: 0.1793 | Val Spearman: 0.2679 | Time: 39.99s
#   → Saved new best model (Spearman: 0.2775)
#   → Saved new best model (Spearman: 0.2815)
#   → Saved new best model (Spearman: 0.2825)
#   → Saved new best model (Spearman: 0.2854)
#   → Saved new best model (Spearman: 0.2882)
# Epoch  10/50 | Train Loss: 0.9678 | Val Loss: 0.9420 | Train Spearman: 0.2316 | Val Spearman: 0.2882 | Time: 39.77s
#   → Saved new best model (Spearman: 0.2896)
#   → Saved new best model (Spearman: 0.2944)
#   → Saved new best model (Spearman: 0.3002)
#   → Saved new best model (Spearman: 0.3247)
#   → Saved new best model (Spearman: 0.3567)
# Epoch  15/50 | Train Loss: 0.9249 | Val Loss: 0.9118 | Train Spearman: 0.3154 | Val Spearman: 0.3567 | Time: 40.26s
#   → Saved new best model (Spearman: 0.3592)
#   → Saved new best model (Spearman: 0.3677)
#   → Saved new best model (Spearman: 0.3690)
# Epoch  20/50 | Train Loss: 0.8932 | Val Loss: 0.8754 | Train Spearman: 0.3503 | Val Spearman: 0.3690 | Time: 38.23s
#   → Saved new best model (Spearman: 0.3772)
#   → Saved new best model (Spearman: 0.3810)
# Epoch  25/50 | Train Loss: 0.8792 | Val Loss: 0.8608 | Train Spearman: 0.3642 | Val Spearman: 0.3810 | Time: 40.15s
#   → Saved new best model (Spearman: 0.3853)
#   → Saved new best model (Spearman: 0.3864)
#   → Saved new best model (Spearman: 0.3913)
#   → Saved new best model (Spearman: 0.3948)
# Epoch  30/50 | Train Loss: 0.8614 | Val Loss: 0.8477 | Train Spearman: 0.3789 | Val Spearman: 0.3948 | Time: 39.55s
#   → Saved new best model (Spearman: 0.3965)
#   → Saved new best model (Spearman: 0.4003)
#   → Saved new best model (Spearman: 0.4023)
#   → Saved new best model (Spearman: 0.4041)
# Epoch  35/50 | Train Loss: 0.8473 | Val Loss: 0.8862 | Train Spearman: 0.3919 | Val Spearman: 0.4041 | Time: 39.20s
#   → Saved new best model (Spearman: 0.4086)
#   → Saved new best model (Spearman: 0.4125)
#   → Saved new best model (Spearman: 0.4125)
# Epoch  40/50 | Train Loss: 0.8334 | Val Loss: 0.8224 | Train Spearman: 0.4019 | Val Spearman: 0.4125 | Time: 40.45s
#   → Saved new best model (Spearman: 0.4135)
#   → Saved new best model (Spearman: 0.4197)
#   → Saved new best model (Spearman: 0.4223)
# Epoch  45/50 | Train Loss: 0.8173 | Val Loss: 0.8137 | Train Spearman: 0.4129 | Val Spearman: 0.4194 | Time: 39.10s
#   → Saved new best model (Spearman: 0.4245)
#   → Saved new best model (Spearman: 0.4276)
#   → Saved new best model (Spearman: 0.4297)
# Epoch  50/50 | Train Loss: 0.8082 | Val Loss: 0.7987 | Train Spearman: 0.4202 | Val Spearman: 0.4297 | Time: 39.67s
#
# Training completed in 1996.87s
# Best validation Spearman correlation: 0.4297
#   → Search progress saved to Outputs_t6/LSTM_search_results_t6.json
#
# Running experiment 2/7: {'learning_rate': 6e-05, 'hidden_dim': 256, 'dropout': 0.4}
#
# ============================================================
# Training LSTM_exp1
# ============================================================
#   → Saved new best model (Spearman: 0.2754)
# Epoch   1/50 | Train Loss: 1.0144 | Val Loss: 0.9495 | Train Spearman: 0.1419 | Val Spearman: 0.2754 | Time: 39.73s
#   → Saved new best model (Spearman: 0.2967)
#   → Saved new best model (Spearman: 0.3550)
#   → Saved new best model (Spearman: 0.3786)
#   → Saved new best model (Spearman: 0.3962)
# Epoch   5/50 | Train Loss: 0.8715 | Val Loss: 0.8515 | Train Spearman: 0.3705 | Val Spearman: 0.3962 | Time: 39.95s
#   → Saved new best model (Spearman: 0.4166)
#   → Saved new best model (Spearman: 0.4259)
#   → Saved new best model (Spearman: 0.4335)
#   → Saved new best model (Spearman: 0.4412)
# Epoch  10/50 | Train Loss: 0.7792 | Val Loss: 0.7648 | Train Spearman: 0.4338 | Val Spearman: 0.4387 | Time: 40.04s
#   → Saved new best model (Spearman: 0.4608)
#   → Saved new best model (Spearman: 0.4725)
#   → Saved new best model (Spearman: 0.5042)
#   → Saved new best model (Spearman: 0.5065)
#   → Saved new best model (Spearman: 0.5247)
# Epoch  15/50 | Train Loss: 0.5599 | Val Loss: 0.5439 | Train Spearman: 0.5025 | Val Spearman: 0.5247 | Time: 38.63s
#   → Saved new best model (Spearman: 0.5268)
#   → Saved new best model (Spearman: 0.5333)
#   → Saved new best model (Spearman: 0.5582)
# Epoch  20/50 | Train Loss: 0.4992 | Val Loss: 0.4841 | Train Spearman: 0.5397 | Val Spearman: 0.5582 | Time: 40.98s
#   → Saved new best model (Spearman: 0.5675)
#   → Saved new best model (Spearman: 0.5830)
# Epoch  25/50 | Train Loss: 0.4606 | Val Loss: 0.4909 | Train Spearman: 0.5658 | Val Spearman: 0.5732 | Time: 39.83s
#   → Saved new best model (Spearman: 0.5858)
#   → Saved new best model (Spearman: 0.5866)
# Epoch  30/50 | Train Loss: 0.4284 | Val Loss: 0.4332 | Train Spearman: 0.5804 | Val Spearman: 0.5866 | Time: 40.20s
#   → Saved new best model (Spearman: 0.6055)
#   → Saved new best model (Spearman: 0.6098)
# Epoch  35/50 | Train Loss: 0.4159 | Val Loss: 0.4378 | Train Spearman: 0.5894 | Val Spearman: 0.6004 | Time: 41.33s
#   → Saved new best model (Spearman: 0.6164)
#   → Saved new best model (Spearman: 0.6192)
# Epoch  40/50 | Train Loss: 0.4017 | Val Loss: 0.4086 | Train Spearman: 0.5981 | Val Spearman: 0.6192 | Time: 40.40s
#   → Saved new best model (Spearman: 0.6210)
#   → Saved new best model (Spearman: 0.6275)
# Epoch  45/50 | Train Loss: 0.3919 | Val Loss: 0.3848 | Train Spearman: 0.6069 | Val Spearman: 0.6083 | Time: 41.24s
#   → Saved new best model (Spearman: 0.6307)
#   → Saved new best model (Spearman: 0.6333)
#   → Saved new best model (Spearman: 0.6341)
# Epoch  50/50 | Train Loss: 0.3850 | Val Loss: 0.3722 | Train Spearman: 0.6095 | Val Spearman: 0.6341 | Time: 39.20s
#
# Training completed in 2000.96s
# Best validation Spearman correlation: 0.6341
#   → Search progress saved to Outputs_t6/LSTM_search_results_t6.json
#
# Running experiment 3/7: {'learning_rate': 0.0001, 'hidden_dim': 256, 'dropout': 0.4}
#
# ============================================================
# Training LSTM_exp2
# ============================================================
#   → Saved new best model (Spearman: 0.2893)
# Epoch   1/50 | Train Loss: 1.0019 | Val Loss: 0.9478 | Train Spearman: 0.1671 | Val Spearman: 0.2893 | Time: 41.71s
#   → Saved new best model (Spearman: 0.3486)
#   → Saved new best model (Spearman: 0.4010)
#   → Saved new best model (Spearman: 0.4146)
#   → Saved new best model (Spearman: 0.4354)
# Epoch   5/50 | Train Loss: 0.8043 | Val Loss: 0.8170 | Train Spearman: 0.4187 | Val Spearman: 0.4354 | Time: 40.42s
#   → Saved new best model (Spearman: 0.4632)
#   → Saved new best model (Spearman: 0.4869)
#   → Saved new best model (Spearman: 0.4990)
#   → Saved new best model (Spearman: 0.5192)
#   → Saved new best model (Spearman: 0.5454)
# Epoch  10/50 | Train Loss: 0.5227 | Val Loss: 0.5015 | Train Spearman: 0.5185 | Val Spearman: 0.5454 | Time: 40.10s
#   → Saved new best model (Spearman: 0.5526)
#   → Saved new best model (Spearman: 0.5599)
#   → Saved new best model (Spearman: 0.5679)
#   → Saved new best model (Spearman: 0.5727)
# Epoch  15/50 | Train Loss: 0.4549 | Val Loss: 0.4838 | Train Spearman: 0.5638 | Val Spearman: 0.5727 | Time: 39.40s
#   → Saved new best model (Spearman: 0.5734)
#   → Saved new best model (Spearman: 0.5965)
#   → Saved new best model (Spearman: 0.6019)
#   → Saved new best model (Spearman: 0.6122)
# Epoch  20/50 | Train Loss: 0.4189 | Val Loss: 0.3988 | Train Spearman: 0.5876 | Val Spearman: 0.6122 | Time: 39.36s
#   → Saved new best model (Spearman: 0.6224)
# Epoch  25/50 | Train Loss: 0.4007 | Val Loss: 0.4073 | Train Spearman: 0.6021 | Val Spearman: 0.6205 | Time: 41.39s
#   → Saved new best model (Spearman: 0.6239)
#   → Saved new best model (Spearman: 0.6276)
# Epoch  30/50 | Train Loss: 0.3760 | Val Loss: 0.3940 | Train Spearman: 0.6144 | Val Spearman: 0.6265 | Time: 40.69s
#   → Saved new best model (Spearman: 0.6356)
# Epoch  35/50 | Train Loss: 0.3711 | Val Loss: 0.3983 | Train Spearman: 0.6212 | Val Spearman: 0.6260 | Time: 39.36s
#   → Saved new best model (Spearman: 0.6377)
#   → Saved new best model (Spearman: 0.6382)
# Epoch  40/50 | Train Loss: 0.3570 | Val Loss: 0.3619 | Train Spearman: 0.6284 | Val Spearman: 0.6358 | Time: 40.55s
#   → Saved new best model (Spearman: 0.6457)
#   → Saved new best model (Spearman: 0.6481)
# Epoch  45/50 | Train Loss: 0.3495 | Val Loss: 0.3582 | Train Spearman: 0.6334 | Val Spearman: 0.6386 | Time: 39.31s
#   → Saved new best model (Spearman: 0.6506)
# Epoch  50/50 | Train Loss: 0.3434 | Val Loss: 0.3532 | Train Spearman: 0.6383 | Val Spearman: 0.6476 | Time: 39.88s
#
# Training completed in 2003.20s
# Best validation Spearman correlation: 0.6506
#   → Search progress saved to Outputs_t6/LSTM_search_results_t6.json
#
# Running experiment 4/7: {'learning_rate': 0.0003, 'hidden_dim': 256, 'dropout': 0.4}
#
# ============================================================
# Training LSTM_exp3
# ============================================================
#   → Saved new best model (Spearman: 0.3808)
# Epoch   1/50 | Train Loss: 0.9669 | Val Loss: 0.8677 | Train Spearman: 0.2330 | Val Spearman: 0.3808 | Time: 39.36s
#   → Saved new best model (Spearman: 0.4789)
#   → Saved new best model (Spearman: 0.5199)
#   → Saved new best model (Spearman: 0.5418)
# Epoch   5/50 | Train Loss: 0.5157 | Val Loss: 0.6601 | Train Spearman: 0.5267 | Val Spearman: 0.5410 | Time: 40.22s
#   → Saved new best model (Spearman: 0.5443)
#   → Saved new best model (Spearman: 0.5882)
#   → Saved new best model (Spearman: 0.6013)
# Epoch  10/50 | Train Loss: 0.4237 | Val Loss: 0.4250 | Train Spearman: 0.5813 | Val Spearman: 0.6011 | Time: 39.46s
#   → Saved new best model (Spearman: 0.6202)
#   → Saved new best model (Spearman: 0.6291)
# Epoch  15/50 | Train Loss: 0.3884 | Val Loss: 0.3902 | Train Spearman: 0.6079 | Val Spearman: 0.6291 | Time: 39.27s
#   → Saved new best model (Spearman: 0.6308)
#   → Saved new best model (Spearman: 0.6434)
# Epoch  20/50 | Train Loss: 0.3683 | Val Loss: 0.3601 | Train Spearman: 0.6241 | Val Spearman: 0.6425 | Time: 40.21s
#   → Saved new best model (Spearman: 0.6487)
#   → Saved new best model (Spearman: 0.6490)
# Epoch  25/50 | Train Loss: 0.3528 | Val Loss: 0.3776 | Train Spearman: 0.6342 | Val Spearman: 0.6472 | Time: 39.30s
#   → Saved new best model (Spearman: 0.6508)
#   → Saved new best model (Spearman: 0.6525)
#   → Saved new best model (Spearman: 0.6559)
#   → Saved new best model (Spearman: 0.6572)
# Epoch  30/50 | Train Loss: 0.3349 | Val Loss: 0.3504 | Train Spearman: 0.6441 | Val Spearman: 0.6528 | Time: 38.60s
#   → Saved new best model (Spearman: 0.6583)
#   → Saved new best model (Spearman: 0.6646)
# Epoch  35/50 | Train Loss: 0.3198 | Val Loss: 0.3506 | Train Spearman: 0.6528 | Val Spearman: 0.6556 | Time: 41.00s
#   → Saved new best model (Spearman: 0.6651)
#   → Saved new best model (Spearman: 0.6661)
#   → Saved new best model (Spearman: 0.6676)
# Epoch  40/50 | Train Loss: 0.3054 | Val Loss: 0.3299 | Train Spearman: 0.6577 | Val Spearman: 0.6676 | Time: 40.03s
#   → Saved new best model (Spearman: 0.6735)
# Epoch  45/50 | Train Loss: 0.2922 | Val Loss: 0.3299 | Train Spearman: 0.6636 | Val Spearman: 0.6686 | Time: 39.69s
#   → Saved new best model (Spearman: 0.6741)
# Epoch  50/50 | Train Loss: 0.2795 | Val Loss: 0.3289 | Train Spearman: 0.6674 | Val Spearman: 0.6741 | Time: 41.01s
#
# Training completed in 2001.60s
# Best validation Spearman correlation: 0.6741
#   → Search progress saved to Outputs_t6/LSTM_search_results_t6.json
#
# Running experiment 5/7: {'learning_rate': 0.0005, 'hidden_dim': 256, 'dropout': 0.4}
#
# ============================================================
# Training LSTM_exp4
# ============================================================
#   → Saved new best model (Spearman: 0.4149)
# Epoch   1/50 | Train Loss: 0.9347 | Val Loss: 0.8781 | Train Spearman: 0.2736 | Val Spearman: 0.4149 | Time: 40.54s
#   → Saved new best model (Spearman: 0.5090)
#   → Saved new best model (Spearman: 0.5587)
# Epoch   5/50 | Train Loss: 0.4932 | Val Loss: 0.6965 | Train Spearman: 0.5398 | Val Spearman: 0.5587 | Time: 40.70s
#   → Saved new best model (Spearman: 0.5849)
#   → Saved new best model (Spearman: 0.5995)
#   → Saved new best model (Spearman: 0.6270)
# Epoch  10/50 | Train Loss: 0.4146 | Val Loss: 0.3869 | Train Spearman: 0.5909 | Val Spearman: 0.6270 | Time: 39.09s
#   → Saved new best model (Spearman: 0.6329)
#   → Saved new best model (Spearman: 0.6330)
# Epoch  15/50 | Train Loss: 0.3844 | Val Loss: 0.3864 | Train Spearman: 0.6118 | Val Spearman: 0.6330 | Time: 40.75s
#   → Saved new best model (Spearman: 0.6397)
#   → Saved new best model (Spearman: 0.6487)
#   → Saved new best model (Spearman: 0.6502)
# Epoch  20/50 | Train Loss: 0.3597 | Val Loss: 0.3660 | Train Spearman: 0.6287 | Val Spearman: 0.6424 | Time: 38.44s
#   → Saved new best model (Spearman: 0.6517)
#   → Saved new best model (Spearman: 0.6531)
#   → Saved new best model (Spearman: 0.6552)
# Epoch  25/50 | Train Loss: 0.3419 | Val Loss: 0.3787 | Train Spearman: 0.6387 | Val Spearman: 0.6552 | Time: 38.88s
#   → Saved new best model (Spearman: 0.6621)
# Epoch  30/50 | Train Loss: 0.3207 | Val Loss: 0.3389 | Train Spearman: 0.6487 | Val Spearman: 0.6596 | Time: 40.33s
#   → Saved new best model (Spearman: 0.6623)
#   → Saved new best model (Spearman: 0.6663)
#   → Saved new best model (Spearman: 0.6693)
# Epoch  35/50 | Train Loss: 0.3096 | Val Loss: 0.3295 | Train Spearman: 0.6562 | Val Spearman: 0.6665 | Time: 38.23s
# Epoch  40/50 | Train Loss: 0.2927 | Val Loss: 0.3279 | Train Spearman: 0.6623 | Val Spearman: 0.6648 | Time: 40.96s
#   → Saved new best model (Spearman: 0.6732)
#   → Saved new best model (Spearman: 0.6747)
#   → Saved new best model (Spearman: 0.6758)
#   → Saved new best model (Spearman: 0.6764)
# Epoch  45/50 | Train Loss: 0.2559 | Val Loss: 0.3186 | Train Spearman: 0.6790 | Val Spearman: 0.6758 | Time: 39.45s
#   → Saved new best model (Spearman: 0.6782)
# Epoch  50/50 | Train Loss: 0.2439 | Val Loss: 0.3199 | Train Spearman: 0.6838 | Val Spearman: 0.6769 | Time: 39.87s
#
# Training completed in 1998.55s
# Best validation Spearman correlation: 0.6782
#   → Search progress saved to Outputs_t6/LSTM_search_results_t6.json
#
# Running experiment 6/7: {'learning_rate': 0.0007, 'hidden_dim': 256, 'dropout': 0.4}
#
# ============================================================
# Training LSTM_exp5
# ============================================================
#   → Saved new best model (Spearman: 0.4455)
# Epoch   1/50 | Train Loss: 0.9073 | Val Loss: 1.8369 | Train Spearman: 0.2969 | Val Spearman: 0.4455 | Time: 38.62s
#   → Saved new best model (Spearman: 0.5179)
#   → Saved new best model (Spearman: 0.5423)
#   → Saved new best model (Spearman: 0.5641)
# Epoch   5/50 | Train Loss: 0.5081 | Val Loss: 0.7178 | Train Spearman: 0.5304 | Val Spearman: 0.5641 | Time: 38.29s
#   → Saved new best model (Spearman: 0.5985)
#   → Saved new best model (Spearman: 0.5986)
#   → Saved new best model (Spearman: 0.6214)
#   → Saved new best model (Spearman: 0.6234)
# Epoch  10/50 | Train Loss: 0.4052 | Val Loss: 0.4117 | Train Spearman: 0.6009 | Val Spearman: 0.6234 | Time: 40.08s
#   → Saved new best model (Spearman: 0.6447)
# Epoch  15/50 | Train Loss: 0.3731 | Val Loss: 0.3853 | Train Spearman: 0.6196 | Val Spearman: 0.6327 | Time: 39.75s
#   → Saved new best model (Spearman: 0.6498)
#   → Saved new best model (Spearman: 0.6499)
# Epoch  20/50 | Train Loss: 0.3480 | Val Loss: 0.3531 | Train Spearman: 0.6351 | Val Spearman: 0.6499 | Time: 40.67s
#   → Saved new best model (Spearman: 0.6562)
#   → Saved new best model (Spearman: 0.6589)
#   → Saved new best model (Spearman: 0.6656)
# Epoch  25/50 | Train Loss: 0.3306 | Val Loss: 0.3516 | Train Spearman: 0.6462 | Val Spearman: 0.6656 | Time: 38.64s
#   → Saved new best model (Spearman: 0.6670)
# Epoch  30/50 | Train Loss: 0.3109 | Val Loss: 0.3378 | Train Spearman: 0.6524 | Val Spearman: 0.6623 | Time: 39.51s
#   → Saved new best model (Spearman: 0.6681)
#   → Saved new best model (Spearman: 0.6708)
# Epoch  35/50 | Train Loss: 0.2961 | Val Loss: 0.3249 | Train Spearman: 0.6606 | Val Spearman: 0.6695 | Time: 39.99s
# Epoch  40/50 | Train Loss: 0.2800 | Val Loss: 0.3269 | Train Spearman: 0.6652 | Val Spearman: 0.6647 | Time: 39.82s
#   → Saved new best model (Spearman: 0.6760)
#   → Saved new best model (Spearman: 0.6777)
# Epoch  45/50 | Train Loss: 0.2442 | Val Loss: 0.3329 | Train Spearman: 0.6830 | Val Spearman: 0.6749 | Time: 40.49s
#   → Saved new best model (Spearman: 0.6777)
#   → Saved new best model (Spearman: 0.6785)
# Epoch  50/50 | Train Loss: 0.2324 | Val Loss: 0.3314 | Train Spearman: 0.6869 | Val Spearman: 0.6761 | Time: 40.09s
#
# Training completed in 1990.46s
# Best validation Spearman correlation: 0.6785
#   → Search progress saved to Outputs_t6/LSTM_search_results_t6.json
#
# Running experiment 7/7: {'learning_rate': 0.001, 'hidden_dim': 256, 'dropout': 0.4}
#
# ============================================================
# Training LSTM_exp6
# ============================================================
#   → Saved new best model (Spearman: 0.1801)
# Epoch   1/50 | Train Loss: 1.0056 | Val Loss: 1.0186 | Train Spearman: 0.0940 | Val Spearman: 0.1801 | Time: 40.09s
#   → Saved new best model (Spearman: 0.2610)
#   → Saved new best model (Spearman: 0.3885)
#   → Saved new best model (Spearman: 0.5279)
#   → Saved new best model (Spearman: 0.5362)
# Epoch   5/50 | Train Loss: 0.5367 | Val Loss: 0.7035 | Train Spearman: 0.5125 | Val Spearman: 0.5362 | Time: 41.74s
#   → Saved new best model (Spearman: 0.5501)
#   → Saved new best model (Spearman: 0.5774)
#   → Saved new best model (Spearman: 0.5920)
#   → Saved new best model (Spearman: 0.6177)
# Epoch  10/50 | Train Loss: 0.4211 | Val Loss: 0.3882 | Train Spearman: 0.5826 | Val Spearman: 0.6177 | Time: 41.93s
#   → Saved new best model (Spearman: 0.6178)
#   → Saved new best model (Spearman: 0.6259)
#   → Saved new best model (Spearman: 0.6332)
# Epoch  15/50 | Train Loss: 0.3686 | Val Loss: 0.3977 | Train Spearman: 0.6182 | Val Spearman: 0.6268 | Time: 41.07s
#   → Saved new best model (Spearman: 0.6389)
#   → Saved new best model (Spearman: 0.6494)
#   → Saved new best model (Spearman: 0.6592)
# Epoch  20/50 | Train Loss: 0.3378 | Val Loss: 0.3586 | Train Spearman: 0.6374 | Val Spearman: 0.6523 | Time: 29.27s
#   → Saved new best model (Spearman: 0.6618)
#   → Saved new best model (Spearman: 0.6630)
# Epoch  25/50 | Train Loss: 0.3100 | Val Loss: 0.3463 | Train Spearman: 0.6488 | Val Spearman: 0.6482 | Time: 28.97s
#   → Saved new best model (Spearman: 0.6653)
#   → Saved new best model (Spearman: 0.6684)
# Epoch  30/50 | Train Loss: 0.2859 | Val Loss: 0.3462 | Train Spearman: 0.6582 | Val Spearman: 0.6651 | Time: 36.16s
#   → Saved new best model (Spearman: 0.6707)
# Epoch  35/50 | Train Loss: 0.2648 | Val Loss: 0.3386 | Train Spearman: 0.6675 | Val Spearman: 0.6696 | Time: 34.89s
#   → Saved new best model (Spearman: 0.6731)
# Epoch  40/50 | Train Loss: 0.2751 | Val Loss: 0.3373 | Train Spearman: 0.6484 | Val Spearman: 0.6587 | Time: 32.88s
#
# Early stopping at epoch 43
#
# Training completed in 1587.01s
# Best validation Spearman correlation: 0.6731
#   → Search progress saved to Outputs_t6/LSTM_search_results_t6.json
#
# ============================================================
# Best LSTM configuration: {'learning_rate': 0.0007, 'hidden_dim': 256, 'dropout': 0.4}
# Best validation Spearman: 0.6785
# Best model saved to Outputs_t6/best_lstm_model_t6.pth
# ============================================================

# %% [markdown]
# ## 9. Test Evaluation

# %%
# Load best CNN model
cnn_model = RNABindingCNN(
    hidden_dim=best_cnn_config['hidden_dim'], 
    dropout=best_cnn_config['dropout']
).to(device)
cnn_model.load_state_dict(torch.load(f'{OUTPUT_DIR}/best_cnn_model_t6.pth'))

# Evaluate CNN on test set
cnn_test_loss, cnn_test_corr = evaluate(cnn_model, test_loader, device)
print(f"\nBest CNN Test Results:")
print(f"  Test Loss: {cnn_test_loss:.4f}")
print(f"  Test Spearman Correlation: {cnn_test_corr:.4f}")
# Out:
# Best CNN Test Results:
#   Test Loss: 0.3701
#   Test Spearman Correlation: 0.6668

# %%
# Load best LSTM model
lstm_model = RNABindingLSTM(
    hidden_dim=best_lstm_config['hidden_dim'], 
    dropout=best_lstm_config['dropout']
).to(device)
lstm_model.load_state_dict(torch.load(f'{OUTPUT_DIR}/best_lstm_model_t6.pth'))

# Evaluate LSTM on test set
lstm_test_loss, lstm_test_corr = evaluate(lstm_model, test_loader, device)
print(f"\nBest LSTM Test Results:")
print(f"  Test Loss: {lstm_test_loss:.4f}")
print(f"  Test Spearman Correlation: {lstm_test_corr:.4f}")
# Out:
# Best LSTM Test Results:
#   Test Loss: 0.3237
#   Test Spearman Correlation: 0.6760

# %% [markdown]
# ## 10. Plotting Results and Saving History
#
# Saving plots and full experiment history to JSON for reproducibility.

# %%
import json

def save_and_plot_results(cnn_hist, lstm_hist, cnn_config, lstm_config, cnn_test_res, lstm_test_res):
    # Unpack test results
    cnn_test_loss, cnn_test_corr = cnn_test_res
    lstm_test_loss, lstm_test_corr = lstm_test_res
    
    # 1. Prepare Data for JSON Storage
    experiment_data = {
        "CNN": {
            "parameters": cnn_config,
            "training_time_seconds": cnn_hist['training_time'],
            "best_val_accuracy": cnn_hist['best_val_corr'],
            "best_val_epoch": int(np.argmax(cnn_hist['val_correlations']) + 1),
            "test_loss": cnn_test_loss,
            "test_accuracy": cnn_test_corr,
            "history": {
                "train_losses": cnn_hist['train_losses'],
                "train_correlations": cnn_hist['train_correlations'],
                "val_losses": cnn_hist['val_losses'],
                "val_correlations": cnn_hist['val_correlations']
            }
        },
        "LSTM": {
            "parameters": lstm_config,
            "training_time_seconds": lstm_hist['training_time'],
            "best_val_accuracy": lstm_hist['best_val_corr'],
            "best_val_epoch": int(np.argmax(lstm_hist['val_correlations']) + 1),
            "test_loss": lstm_test_loss,
            "test_accuracy": lstm_test_corr,
            "history": {
                "train_losses": lstm_hist['train_losses'],
                "train_correlations": lstm_hist['train_correlations'],
                "val_losses": lstm_hist['val_losses'],
                "val_correlations": lstm_hist['val_correlations']
            }
        }
    }

    # Save to JSON
    json_path = f'{OUTPUT_DIR}/complete_experiment_data_t6.json'
    with open(json_path, 'w') as f:
        json.dump(experiment_data, f, indent=4)
    print(f"Complete experiment data saved to '{json_path}'")

    # 2. Plotting
    epochs_cnn = range(1, len(cnn_hist['train_losses']) + 1)
    epochs_lstm = range(1, len(lstm_hist['train_losses']) + 1)

    # --- Plot 1: Loss ---
    plt.figure(figsize=(10, 6))
    plt.plot(epochs_cnn, cnn_hist['train_losses'], label='CNN Train Loss', color='blue', linestyle='--')
    plt.plot(epochs_cnn, cnn_hist['val_losses'], label='CNN Val Loss', color='blue')
    plt.plot(epochs_lstm, lstm_hist['train_losses'], label='LSTM Train Loss', color='red', linestyle='--')
    plt.plot(epochs_lstm, lstm_hist['val_losses'], label='LSTM Val Loss', color='red')
    plt.xlabel('Epochs')
    plt.ylabel('Loss (MSE)')
    plt.title('Training and Validation Loss')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.savefig(f'{OUTPUT_DIR}/loss_plot.png')
    plt.close()

    # --- Plot 2: Accuracy (Spearman Correlation) ---
    plt.figure(figsize=(10, 6))
    plt.plot(epochs_cnn, cnn_hist['train_correlations'], label='CNN Train Spearman', color='blue', linestyle='--')
    plt.plot(epochs_cnn, cnn_hist['val_correlations'], label='CNN Val Spearman', color='blue')
    plt.plot(epochs_lstm, lstm_hist['train_correlations'], label='LSTM Train Spearman', color='red', linestyle='--')
    plt.plot(epochs_lstm, lstm_hist['val_correlations'], label='LSTM Val Spearman', color='red')
    plt.xlabel('Epochs')
    plt.ylabel('Spearman Correlation')
    plt.title('Training and Validation Spearman Correlation')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.savefig(f'{OUTPUT_DIR}/accuracy_plot.png')
    plt.close()
    
    print("Plots saved to 'loss_plot.png' and 'accuracy_plot.png'.")

# Execute
save_and_plot_results(
    cnn_history, lstm_history, 
    best_cnn_config, best_lstm_config, 
    (cnn_test_loss, cnn_test_corr), 
    (lstm_test_loss, lstm_test_corr)
)
# Out:
# Complete experiment data saved to 'Outputs_t6/complete_experiment_data_t6.json'
# Plots saved to 'loss_plot.png' and 'accuracy_plot.png'.
