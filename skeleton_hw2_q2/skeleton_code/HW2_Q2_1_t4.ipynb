# %% [markdown]
# # Deep Learning Homework 2 - Question 2.1
# ## RNA Binding Protein (RBP) Interaction Prediction

# %% [markdown]
# ## 1. Setup and Imports

# %%
# Install required packages
# !pip install openpyxl -q

# %%
import os
import random
import time
import itertools
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from typing import List, Tuple

# Create Output Directory
OUTPUT_DIR = 'Outputs_t4'
os.makedirs(OUTPUT_DIR, exist_ok=True)

# Check device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# Using device: cuda
# GPU: NVIDIA GeForce RTX 4060 Laptop GPU

# %% [markdown]
# ## 2. Download Data
#
# Download the data files from the Google Drive link provided in the homework:
# - `norm_data.txt`
# - `metadata.xlsx`
#
# Upload them to Colab or mount your Google Drive.

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
# Set the path to your data files
DATA_DIR = 'data'  # Change this to your folder path

# %% [markdown]
# ## 3. Configuration and Utility Functions

# %%
from config import RNAConfig

# %%
from utils import configure_seed, masked_mse_loss, masked_spearman_correlation

configure_seed(42)

# %% [markdown]
# ## 4. Data Loader

# %%
from utils import RNACompeteLoader, load_rnacompete_data

# %% [markdown]
# ## 5. Model Definitions
#
# ### 5.1 CNN Model

# %%
class RNABindingCNN(nn.Module):
    """
    1D Convolutional Neural Network for RNA sequence binding prediction.

    Architecture:
    - 3 convolutional layers with increasing channels (64 -> 128 -> 256)
    - Batch normalization after each conv layer
    - ReLU activation and dropout for regularization
    - Global max + average pooling for richer representation
    - 2 fully connected layers for regression output
    """

    def __init__(self, input_channels=4, seq_length=41, hidden_dim=128, dropout=0.3):
        super(RNABindingCNN, self).__init__()
        #L_out = ((L_in + 2P - K) / S)  + 1

        # Convolutional layers with different kernel sizes to capture various motif lengths
        # Padding choices allow to preserve input length through the feature maps
        #L_out = 41
        self.conv1 = nn.Conv1d(input_channels, 64, kernel_size=5, padding=2)
        self.bn1 = nn.BatchNorm1d(64)

        #L_out = 41
        self.conv2 = nn.Conv1d(64, 128, kernel_size=7, padding=3)
        self.bn2 = nn.BatchNorm1d(128)

        #L_out = 41
        self.conv3 = nn.Conv1d(128, 256, kernel_size=9, padding=4)
        self.bn3 = nn.BatchNorm1d(256)

        self.dropout = nn.Dropout(dropout)

        # Global pooling (both max and average)
        # allows to get the strongest value of a given feature for the sequence
        self.global_max_pool = nn.AdaptiveMaxPool1d(1)
        # allows to get the average of how much a feature is present throughout the sequence
        self.global_avg_pool = nn.AdaptiveAvgPool1d(1)

        # Fully connected layers
        self.fc1 = nn.Linear(256 * 2, hidden_dim)  # *2 for concat of max and avg pool
        self.fc2 = nn.Linear(hidden_dim, 1)
        self.relu = nn.ReLU()

    def forward(self, x):
        # Input x shape: (batch, seq_length, 4)
        # Conv1d expects: (batch, channels, seq_length)
        x = x.permute(0, 2, 1)

        # Convolutional blocks
        x = self.relu(self.bn1(self.conv1(x)))
        x = self.dropout(x)

        x = self.relu(self.bn2(self.conv2(x)))
        x = self.dropout(x)

        x = self.relu(self.bn3(self.conv3(x)))
        x = self.dropout(x)

        # Global pooling
        max_pool = self.global_max_pool(x).squeeze(-1)
        avg_pool = self.global_avg_pool(x).squeeze(-1)
        x = torch.cat([max_pool, avg_pool], dim=1)

        # Fully connected layers
        x = self.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.fc2(x)

        return x

# %% [markdown]
# ### 5.2 LSTM Model

# %%
class RNABindingLSTM(nn.Module):
    """
    Bidirectional LSTM for RNA sequence binding prediction.

    Architecture:
    - 2-layer bidirectional LSTM
    - Batch normalization
    - Dropout for regularization
    - 2 fully connected layers for regression
    """

    def __init__(self, input_dim=4, hidden_dim=128, num_layers=2, dropout=0.3, bidirectional=True):
        super(RNABindingLSTM, self).__init__()

        self.hidden_dim = hidden_dim
        self.num_layers = num_layers
        self.bidirectional = bidirectional
        self.num_directions = 2 if bidirectional else 1

        self.lstm = nn.LSTM(
            input_size=input_dim,
            hidden_size=hidden_dim,
            num_layers=num_layers,
            batch_first=True,
            dropout=dropout if num_layers > 1 else 0,
            bidirectional=bidirectional
        )

        self.bn = nn.BatchNorm1d(hidden_dim * self.num_directions)
        self.dropout = nn.Dropout(dropout)

        self.fc1 = nn.Linear(hidden_dim * self.num_directions, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, 1)
        self.relu = nn.ReLU()

    def forward(self, x):
        # Input x shape: (batch, seq_length, 4)
        lstm_out, (hidden, cell) = self.lstm(x)

        if self.bidirectional:
            # Concatenate last hidden states from forward and backward
            hidden_forward = hidden[-2, :, :]
            hidden_backward = hidden[-1, :, :]
            combined = torch.cat([hidden_forward, hidden_backward], dim=1)
        else:
            combined = hidden[-1, :, :]

        combined = self.bn(combined)
        combined = self.dropout(combined)

        x = self.relu(self.fc1(combined))
        x = self.dropout(x)
        x = self.fc2(x)

        return x

# %% [markdown]
# ## 6. Training and Evaluation Functions

# %%
def train_epoch(model, train_loader, optimizer, device):
    """Train for one epoch and return loss and correlation."""
    model.train()
    total_loss = 0.0
    num_batches = 0
    
    all_preds = []
    all_targets = []
    all_masks = []

    for batch in train_loader:
        x, y, mask = batch
        x, y, mask = x.to(device), y.to(device), mask.to(device)

        optimizer.zero_grad()
        predictions = model(x)
        loss = masked_mse_loss(predictions, y, mask)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()

        total_loss += loss.item()
        num_batches += 1
        
        # Collect for metric calculation
        all_preds.append(predictions.detach().cpu())
        all_targets.append(y.detach().cpu())
        all_masks.append(mask.detach().cpu())

    all_preds = torch.cat(all_preds, dim=0)
    all_targets = torch.cat(all_targets, dim=0)
    all_masks = torch.cat(all_masks, dim=0)
    
    spearman_corr = masked_spearman_correlation(all_preds, all_targets, all_masks)

    return total_loss / num_batches, spearman_corr.item()


def evaluate(model, data_loader, device):
    """Evaluate model and return loss and Spearman correlation."""
    model.eval()
    total_loss = 0.0
    num_batches = 0

    all_preds = []
    all_targets = []
    all_masks = []

    with torch.no_grad():
        for batch in data_loader:
            x, y, mask = batch
            x, y, mask = x.to(device), y.to(device), mask.to(device)

            predictions = model(x)
            loss = masked_mse_loss(predictions, y, mask)

            total_loss += loss.item()
            num_batches += 1

            all_preds.append(predictions.cpu())
            all_targets.append(y.cpu())
            all_masks.append(mask.cpu())

    all_preds = torch.cat(all_preds, dim=0)
    all_targets = torch.cat(all_targets, dim=0)
    all_masks = torch.cat(all_masks, dim=0)

    spearman_corr = masked_spearman_correlation(all_preds, all_targets, all_masks)

    return total_loss / num_batches, spearman_corr.item()


def train_model(model, train_loader, val_loader, optimizer, scheduler, device,
                num_epochs, model_name, patience=15, save_every=10):
    """Full training loop with early stopping and periodic checkpoints."""
    print(f"\n{'='*60}")
    print(f"Training {model_name}")
    print(f"{'='*60}")

    train_losses = []
    train_correlations = []
    val_losses = []
    val_correlations = []

    best_val_corr = -float('inf')
    best_model_state = None
    epochs_without_improvement = 0

    start_time = time.time()

    for epoch in range(num_epochs):
        epoch_start = time.time()

        train_loss, train_corr = train_epoch(model, train_loader, optimizer, device)
        val_loss, val_corr = evaluate(model, val_loader, device)

        if scheduler is not None:
            scheduler.step(val_corr)

        train_losses.append(train_loss)
        train_correlations.append(train_corr)
        val_losses.append(val_loss)
        val_correlations.append(val_corr)

        if val_corr > best_val_corr:
            best_val_corr = val_corr
            best_model_state = {k: v.cpu().clone() for k, v in model.state_dict().items()}
            epochs_without_improvement = 0
            # Save best model to Output directory
            torch.save(best_model_state, f'{OUTPUT_DIR}/{model_name}_best_t4.pth')
            print(f"  → Saved new best model (Spearman: {val_corr:.4f})")
        else:
            epochs_without_improvement += 1

        epoch_time = time.time() - epoch_start

        if (epoch + 1) % 5 == 0 or epoch == 0:
            print(f"Epoch {epoch+1:3d}/{num_epochs} | "
                  f"Train Loss: {train_loss:.4f} | "
                  f"Val Loss: {val_loss:.4f} | "
                  f"Train Spearman: {train_corr:.4f} | "
                  f"Val Spearman: {val_corr:.4f} | "
                  f"Time: {epoch_time:.2f}s")

        # Periodic checkpoint every N epochs
        if (epoch + 1) % save_every == 0:
            checkpoint = {
                'epoch': epoch + 1,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'train_losses': train_losses,
                'train_correlations': train_correlations,
                'val_losses': val_losses,
                'val_correlations': val_correlations,
                'best_val_corr': best_val_corr
            }
            torch.save(checkpoint, f'{OUTPUT_DIR}/{model_name}_checkpoint_epoch{epoch+1}_t4.pth')
            print(f"  → Checkpoint saved at epoch {epoch+1}")

        if epochs_without_improvement >= patience:
            print(f"\nEarly stopping at epoch {epoch+1}")
            break

    total_time = time.time() - start_time

    if best_model_state is not None:
        model.load_state_dict(best_model_state)

    print(f"\nTraining completed in {total_time:.2f}s")
    print(f"Best validation Spearman correlation: {best_val_corr:.4f}")

    return {
        'train_losses': train_losses,
        'train_correlations': train_correlations,
        'val_losses': val_losses,
        'val_correlations': val_correlations,
        'best_val_corr': best_val_corr,
        'training_time': total_time
    }

# %% [markdown]
# ## 7. Load Data

# %%
PROTEIN_NAME = 'RBFOX1'
BATCH_SIZE = 64

# Load data
print(f"Loading data for protein: {PROTEIN_NAME}")
config = RNAConfig()

train_dataset = load_rnacompete_data(PROTEIN_NAME, split='train', config=config)
val_dataset = load_rnacompete_data(PROTEIN_NAME, split='val', config=config)
test_dataset = load_rnacompete_data(PROTEIN_NAME, split='test', config=config)

print(f"\nDataset sizes:")
print(f"  Train: {len(train_dataset)}")
print(f"  Val: {len(val_dataset)}")
print(f"  Test: {len(test_dataset)}")

# Create data loaders
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)
# Out:
# Loading data for protein: RBFOX1
# Found cached data for RBFOX1 (train). Loading from data/RBFOX1_train_data.pt...
# Found cached data for RBFOX1 (val). Loading from data/RBFOX1_val_data.pt...
# Found cached data for RBFOX1 (test). Loading from data/RBFOX1_test_data.pt...
#
# Dataset sizes:
#   Train: 96261
#   Val: 24065
#   Test: 121031

# %% [markdown]
# ## 8. Hyperparameter Search and Training
#
# Here we define the search space and a function to iterate through hyperparameters, training the model for each combination.

# %%
# --- ROBUST GRID SEARCH (12 Combinations) ---
# for train_model with patience 7, and scheduler patience 5
# POSSIBLE HYPERPARAMETER TO ADD- SHCEDULER PATIENCE, INFLUENCES HOW LR CHANGES
cnn_param_grid = {
    'learning_rate': [0.00006, 0.00001, 0.02, 0.04],
    'hidden_dim': [256],   # 256 was better than 128, so we test 512
    'dropout': [0.2]       # Lower dropout preferred for CNNs
}

lstm_param_grid = {
    'learning_rate': [0.00006, 0.00001, 0.0015, 0.0025],
    'hidden_dim': [256],   # Larger LSTMs often capture complex motifs better
    'dropout': [0.3]       # Standard regularization for LSTMs
}

#simply fast grid to test if code runs well
# param_grid = {
#     # Covers best LSTM (0.001), best CNN (0.0001) and midpoint (0.0005)
#     'learning_rate': [0.0001],
#     # Tests if doubling capacity improves results
#     'hidden_dim': [2],
#     # Standard regularization vs Stronger regularization (for larger models)
#     'dropout': [0.8]
# }

def hyperparameter_search(model_class, model_name, param_grid, train_loader, val_loader, device, epochs=50):
    keys, values = zip(*param_grid.items())
    experiments = [dict(zip(keys, v)) for v in itertools.product(*values)]
    
    best_val_corr = -float('inf')
    best_config = None
    best_history = None
    
    print(f"Starting Hyperparameter Search for {model_name} with {len(experiments)} configurations...")
    
    results = []
    # Define a path for the intermediate results
    results_path = f'{OUTPUT_DIR}/{model_name}_search_results_t4.json'
    
    for i, config in enumerate(experiments):
        print(f"\nRunning experiment {i+1}/{len(experiments)}: {config}")
        
        configure_seed(42)
        
        # Initialize model with current config
        # Note: LSTM and CNN have slightly different init signatures if not careful,
        # but here we matched the param names in the grid to the init args
        if model_name == 'LSTM':
             model = model_class(
                hidden_dim=config['hidden_dim'],
                dropout=config['dropout']
            ).to(device)
        else:
             model = model_class(
                hidden_dim=config['hidden_dim'],
                dropout=config['dropout']
            ).to(device)
            
        optimizer = optim.Adam(model.parameters(), lr=config['learning_rate'], weight_decay=1e-5)
        scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', factor=0.5, patience=5)
        
        # Train - using fewer epochs for search to save time (can increase for final result)
        # We use a unique name for temporary checkpoints
        temp_name = f"{model_name}_exp{i}"
        history = train_model(
            model, train_loader, val_loader, optimizer, scheduler,
            device, num_epochs=epochs, model_name=temp_name, patience=7, save_every=100
        )
        
        # --- SAVE PROGRESS IMMEDIATELY ---
        run_result = {
            'experiment_index': i,
            'config': config,
            'best_val_corr': history['best_val_corr'],
            'training_time': history['training_time'],
            'history': history # Full history included for plotting/resuming
        }
        results.append(run_result)
        
        try:
            with open(results_path, 'w') as f:
                json.dump(results, f, indent=4)
            print(f"  → Search progress saved to {results_path}")
        except Exception as e:
            print(f"  → Warning: Could not save progress to JSON: {e}")

        if history['best_val_corr'] > best_val_corr:
            best_val_corr = history['best_val_corr']
            best_config = config
            best_history = history
            
            # Save the best model of the search as the final best model
            # We load the best state from the temp file and save it to the final destination
            best_state = torch.load(f'{OUTPUT_DIR}/{temp_name}_best_t4.pth')
            torch.save(best_state, f'{OUTPUT_DIR}/best_{model_name.lower()}_model_t4.pth')
            
    print(f"\n{'='*60}")
    print(f"Best {model_name} configuration: {best_config}")
    print(f"Best validation Spearman: {best_val_corr:.4f}")
    print(f"Best model saved to {OUTPUT_DIR}/best_{model_name.lower()}_model_t4.pth")
    print(f"{'='*60}")
    
    return best_config, best_history

# %%
# 8.1 Train and Search CNN
print("---- Tuning CNN ----")
best_cnn_config, cnn_history = hyperparameter_search(
    RNABindingCNN, 'CNN', cnn_param_grid, train_loader, val_loader, device, epochs=50
)
# Out:
# ---- Tuning CNN ----
# Starting Hyperparameter Search for CNN with 4 configurations...
#
# Running experiment 1/4: {'learning_rate': 6e-05, 'hidden_dim': 256, 'dropout': 0.2}
#
# ============================================================
# Training CNN_exp0
# ============================================================
#   → Saved new best model (Spearman: 0.5170)
# Epoch   1/50 | Train Loss: 0.7051 | Val Loss: 0.5599 | Train Spearman: 0.4121 | Val Spearman: 0.5170 | Time: 21.28s
#   → Saved new best model (Spearman: 0.5465)
#   → Saved new best model (Spearman: 0.5577)
#   → Saved new best model (Spearman: 0.5833)
#   → Saved new best model (Spearman: 0.6101)
# Epoch   5/50 | Train Loss: 0.4468 | Val Loss: 0.4160 | Train Spearman: 0.5590 | Val Spearman: 0.6101 | Time: 12.34s
#   → Saved new best model (Spearman: 0.6177)
#   → Saved new best model (Spearman: 0.6284)
#   → Saved new best model (Spearman: 0.6377)
#   → Saved new best model (Spearman: 0.6420)
# Epoch  10/50 | Train Loss: 0.3880 | Val Loss: 0.3657 | Train Spearman: 0.6075 | Val Spearman: 0.6420 | Time: 12.48s
#   → Saved new best model (Spearman: 0.6475)
#   → Saved new best model (Spearman: 0.6520)
#   → Saved new best model (Spearman: 0.6523)
# Epoch  15/50 | Train Loss: 0.3604 | Val Loss: 0.3635 | Train Spearman: 0.6215 | Val Spearman: 0.6507 | Time: 14.01s
#   → Saved new best model (Spearman: 0.6588)
# Epoch  20/50 | Train Loss: 0.3402 | Val Loss: 0.3515 | Train Spearman: 0.6337 | Val Spearman: 0.6587 | Time: 12.13s
#   → Saved new best model (Spearman: 0.6593)
#   → Saved new best model (Spearman: 0.6604)
#   → Saved new best model (Spearman: 0.6608)
# Epoch  25/50 | Train Loss: 0.3253 | Val Loss: 0.3519 | Train Spearman: 0.6412 | Val Spearman: 0.6608 | Time: 13.17s
#   → Saved new best model (Spearman: 0.6628)
#   → Saved new best model (Spearman: 0.6629)
#   → Saved new best model (Spearman: 0.6635)
#   → Saved new best model (Spearman: 0.6661)
# Epoch  30/50 | Train Loss: 0.3119 | Val Loss: 0.3373 | Train Spearman: 0.6462 | Val Spearman: 0.6661 | Time: 11.10s
# Epoch  35/50 | Train Loss: 0.3009 | Val Loss: 0.3388 | Train Spearman: 0.6509 | Val Spearman: 0.6661 | Time: 14.34s
#   → Saved new best model (Spearman: 0.6669)
# Epoch  40/50 | Train Loss: 0.2943 | Val Loss: 0.3396 | Train Spearman: 0.6568 | Val Spearman: 0.6659 | Time: 15.57s
#   → Saved new best model (Spearman: 0.6701)
# Epoch  45/50 | Train Loss: 0.2835 | Val Loss: 0.3325 | Train Spearman: 0.6615 | Val Spearman: 0.6690 | Time: 21.74s
#
# Early stopping at epoch 48
#
# Training completed in 643.22s
# Best validation Spearman correlation: 0.6701
#   → Search progress saved to Outputs_t4/CNN_search_results_t4.json
#
# Running experiment 2/4: {'learning_rate': 1e-05, 'hidden_dim': 256, 'dropout': 0.2}
#
# ============================================================
# Training CNN_exp1
# ============================================================
#   → Saved new best model (Spearman: 0.4609)
# Epoch   1/50 | Train Loss: 0.9420 | Val Loss: 0.7841 | Train Spearman: 0.2337 | Val Spearman: 0.4609 | Time: 12.75s
#   → Saved new best model (Spearman: 0.4808)
#   → Saved new best model (Spearman: 0.4904)
#   → Saved new best model (Spearman: 0.5019)
#   → Saved new best model (Spearman: 0.5140)
# Epoch   5/50 | Train Loss: 0.5811 | Val Loss: 0.5742 | Train Spearman: 0.4734 | Val Spearman: 0.5140 | Time: 9.20s
#   → Saved new best model (Spearman: 0.5210)
#   → Saved new best model (Spearman: 0.5264)
#   → Saved new best model (Spearman: 0.5336)
#   → Saved new best model (Spearman: 0.5426)
#   → Saved new best model (Spearman: 0.5467)
# Epoch  10/50 | Train Loss: 0.5169 | Val Loss: 0.5095 | Train Spearman: 0.5084 | Val Spearman: 0.5467 | Time: 12.02s
#   → Saved new best model (Spearman: 0.5496)
#   → Saved new best model (Spearman: 0.5510)
#   → Saved new best model (Spearman: 0.5578)
#   → Saved new best model (Spearman: 0.5616)
#   → Saved new best model (Spearman: 0.5627)
# Epoch  15/50 | Train Loss: 0.4876 | Val Loss: 0.5355 | Train Spearman: 0.5306 | Val Spearman: 0.5627 | Time: 11.63s
#   → Saved new best model (Spearman: 0.5683)
#   → Saved new best model (Spearman: 0.5733)
#   → Saved new best model (Spearman: 0.5785)
#   → Saved new best model (Spearman: 0.5846)
#   → Saved new best model (Spearman: 0.5870)
# Epoch  20/50 | Train Loss: 0.4617 | Val Loss: 0.4689 | Train Spearman: 0.5537 | Val Spearman: 0.5870 | Time: 11.57s
#   → Saved new best model (Spearman: 0.5906)
#   → Saved new best model (Spearman: 0.5968)
#   → Saved new best model (Spearman: 0.5976)
#   → Saved new best model (Spearman: 0.6045)
#   → Saved new best model (Spearman: 0.6080)
# Epoch  25/50 | Train Loss: 0.4344 | Val Loss: 0.4357 | Train Spearman: 0.5730 | Val Spearman: 0.6080 | Time: 11.61s
#   → Saved new best model (Spearman: 0.6085)
#   → Saved new best model (Spearman: 0.6155)
#   → Saved new best model (Spearman: 0.6173)
#   → Saved new best model (Spearman: 0.6198)
# Epoch  30/50 | Train Loss: 0.4133 | Val Loss: 0.4337 | Train Spearman: 0.5868 | Val Spearman: 0.6198 | Time: 11.47s
#   → Saved new best model (Spearman: 0.6226)
#   → Saved new best model (Spearman: 0.6239)
#   → Saved new best model (Spearman: 0.6296)
# Epoch  35/50 | Train Loss: 0.4034 | Val Loss: 0.4293 | Train Spearman: 0.5975 | Val Spearman: 0.6296 | Time: 9.36s
#   → Saved new best model (Spearman: 0.6314)
#   → Saved new best model (Spearman: 0.6359)
# Epoch  40/50 | Train Loss: 0.3907 | Val Loss: 0.4058 | Train Spearman: 0.6058 | Val Spearman: 0.6359 | Time: 9.21s
#   → Saved new best model (Spearman: 0.6377)
#   → Saved new best model (Spearman: 0.6413)
# Epoch  45/50 | Train Loss: 0.3804 | Val Loss: 0.4097 | Train Spearman: 0.6105 | Val Spearman: 0.6413 | Time: 12.02s
#   → Saved new best model (Spearman: 0.6414)
#   → Saved new best model (Spearman: 0.6420)
# Epoch  50/50 | Train Loss: 0.3722 | Val Loss: 0.4141 | Train Spearman: 0.6178 | Val Spearman: 0.6420 | Time: 12.11s
#
# Training completed in 566.74s
# Best validation Spearman correlation: 0.6420
#   → Search progress saved to Outputs_t4/CNN_search_results_t4.json
#
# Running experiment 3/4: {'learning_rate': 0.02, 'hidden_dim': 256, 'dropout': 0.2}
#
# ============================================================
# Training CNN_exp2
# ============================================================
#   → Saved new best model (Spearman: 0.5084)
# Epoch   1/50 | Train Loss: 9.7091 | Val Loss: 0.5383 | Train Spearman: 0.4133 | Val Spearman: 0.5084 | Time: 11.35s
#   → Saved new best model (Spearman: 0.5208)
#   → Saved new best model (Spearman: 0.5390)
#   → Saved new best model (Spearman: 0.5437)
# Epoch   5/50 | Train Loss: 0.5414 | Val Loss: 0.4987 | Train Spearman: 0.4849 | Val Spearman: 0.5437 | Time: 11.70s
#   → Saved new best model (Spearman: 0.5540)
# Epoch  10/50 | Train Loss: 0.5291 | Val Loss: 0.4894 | Train Spearman: 0.4920 | Val Spearman: 0.5499 | Time: 12.10s
#   → Saved new best model (Spearman: 0.5626)
# Epoch  15/50 | Train Loss: 0.4888 | Val Loss: 0.5218 | Train Spearman: 0.5146 | Val Spearman: 0.5537 | Time: 12.33s
#   → Saved new best model (Spearman: 0.5721)
#   → Saved new best model (Spearman: 0.5767)
# Epoch  20/50 | Train Loss: 0.4739 | Val Loss: 0.4552 | Train Spearman: 0.5278 | Val Spearman: 0.5767 | Time: 12.02s
#   → Saved new best model (Spearman: 0.5886)
# Epoch  25/50 | Train Loss: 0.4615 | Val Loss: 0.4944 | Train Spearman: 0.5376 | Val Spearman: 0.5824 | Time: 8.92s
#   → Saved new best model (Spearman: 0.5923)
#   → Saved new best model (Spearman: 0.5948)
# Epoch  30/50 | Train Loss: 0.4586 | Val Loss: 0.4196 | Train Spearman: 0.5490 | Val Spearman: 0.5891 | Time: 8.92s
#   → Saved new best model (Spearman: 0.6058)
# Epoch  35/50 | Train Loss: 0.4545 | Val Loss: 0.3995 | Train Spearman: 0.5512 | Val Spearman: 0.6033 | Time: 15.45s
#   → Saved new best model (Spearman: 0.6161)
#   → Saved new best model (Spearman: 0.6188)
#   → Saved new best model (Spearman: 0.6212)
# Epoch  40/50 | Train Loss: 0.4191 | Val Loss: 0.3953 | Train Spearman: 0.5710 | Val Spearman: 0.6212 | Time: 10.40s
#   → Saved new best model (Spearman: 0.6234)
# Epoch  45/50 | Train Loss: 0.4141 | Val Loss: 0.3866 | Train Spearman: 0.5724 | Val Spearman: 0.6185 | Time: 8.83s
#   → Saved new best model (Spearman: 0.6250)
# Epoch  50/50 | Train Loss: 0.4085 | Val Loss: 0.3873 | Train Spearman: 0.5778 | Val Spearman: 0.6238 | Time: 9.59s
#
# Training completed in 572.00s
# Best validation Spearman correlation: 0.6250
#   → Search progress saved to Outputs_t4/CNN_search_results_t4.json
#
# Running experiment 4/4: {'learning_rate': 0.04, 'hidden_dim': 256, 'dropout': 0.2}
#
# ============================================================
# Training CNN_exp3
# ============================================================
#   → Saved new best model (Spearman: 0.4514)
# Epoch   1/50 | Train Loss: 35.3503 | Val Loss: 0.5708 | Train Spearman: 0.3479 | Val Spearman: 0.4514 | Time: 12.40s
#   → Saved new best model (Spearman: 0.4664)
#   → Saved new best model (Spearman: 0.4846)
#   → Saved new best model (Spearman: 0.4865)
#   → Saved new best model (Spearman: 0.4881)
# Epoch   5/50 | Train Loss: 0.6522 | Val Loss: 0.6243 | Train Spearman: 0.4168 | Val Spearman: 0.4881 | Time: 11.51s
#   → Saved new best model (Spearman: 0.5079)
#   → Saved new best model (Spearman: 0.5168)
# Epoch  10/50 | Train Loss: 0.6306 | Val Loss: 0.5890 | Train Spearman: 0.4218 | Val Spearman: 0.5130 | Time: 11.74s
#   → Saved new best model (Spearman: 0.5185)
# Epoch  15/50 | Train Loss: 0.6234 | Val Loss: 0.7106 | Train Spearman: 0.4357 | Val Spearman: 0.5185 | Time: 11.32s
#   → Saved new best model (Spearman: 0.5214)
# Epoch  20/50 | Train Loss: 0.6407 | Val Loss: 4.3636 | Train Spearman: 0.4243 | Val Spearman: 0.3385 | Time: 12.02s
#   → Saved new best model (Spearman: 0.5225)
#   → Saved new best model (Spearman: 0.5237)
#   → Saved new best model (Spearman: 0.5239)
# Epoch  25/50 | Train Loss: 0.6252 | Val Loss: 0.7447 | Train Spearman: 0.4334 | Val Spearman: 0.5104 | Time: 9.29s
#   → Saved new best model (Spearman: 0.5257)
# Epoch  30/50 | Train Loss: 0.6186 | Val Loss: 0.5922 | Train Spearman: 0.4362 | Val Spearman: 0.5172 | Time: 9.53s
#   → Saved new best model (Spearman: 0.5258)
# Epoch  35/50 | Train Loss: 0.6275 | Val Loss: 0.5168 | Train Spearman: 0.4277 | Val Spearman: 0.5155 | Time: 11.85s
#   → Saved new best model (Spearman: 0.5294)
#   → Saved new best model (Spearman: 0.5387)
# Epoch  40/50 | Train Loss: 0.5790 | Val Loss: 0.5022 | Train Spearman: 0.4651 | Val Spearman: 0.5367 | Time: 12.32s
# Epoch  45/50 | Train Loss: 0.5669 | Val Loss: 0.6229 | Train Spearman: 0.4670 | Val Spearman: 0.5054 | Time: 11.62s
#   → Saved new best model (Spearman: 0.5426)
#   → Saved new best model (Spearman: 0.5466)
#   → Saved new best model (Spearman: 0.5475)
# Epoch  50/50 | Train Loss: 0.5237 | Val Loss: 0.4646 | Train Spearman: 0.4904 | Val Spearman: 0.5475 | Time: 11.72s
#
# Training completed in 544.46s
# Best validation Spearman correlation: 0.5475
#   → Search progress saved to Outputs_t4/CNN_search_results_t4.json
#
# ============================================================
# Best CNN configuration: {'learning_rate': 6e-05, 'hidden_dim': 256, 'dropout': 0.2}
# Best validation Spearman: 0.6701
# Best model saved to Outputs_t4/best_cnn_model_t4.pth
# ============================================================

# %%
# 8.2 Train and Search LSTM
print("---- Tuning LSTM ----")
best_lstm_config, lstm_history = hyperparameter_search(
    RNABindingLSTM, 'LSTM', lstm_param_grid, train_loader, val_loader, device, epochs=50
)
# Out:
# ---- Tuning LSTM ----
# Starting Hyperparameter Search for LSTM with 4 configurations...
#
# Running experiment 1/4: {'learning_rate': 6e-05, 'hidden_dim': 256, 'dropout': 0.3}
#
# ============================================================
# Training LSTM_exp0
# ============================================================
#   → Saved new best model (Spearman: 0.2798)
# Epoch   1/50 | Train Loss: 0.9945 | Val Loss: 0.9466 | Train Spearman: 0.1694 | Val Spearman: 0.2798 | Time: 25.35s
#   → Saved new best model (Spearman: 0.3023)
#   → Saved new best model (Spearman: 0.3726)
#   → Saved new best model (Spearman: 0.3809)
#   → Saved new best model (Spearman: 0.4039)
# Epoch   5/50 | Train Loss: 0.8626 | Val Loss: 0.8514 | Train Spearman: 0.3776 | Val Spearman: 0.4039 | Time: 24.46s
#   → Saved new best model (Spearman: 0.4214)
#   → Saved new best model (Spearman: 0.4318)
#   → Saved new best model (Spearman: 0.4373)
#   → Saved new best model (Spearman: 0.4451)
# Epoch  10/50 | Train Loss: 0.7763 | Val Loss: 0.7723 | Train Spearman: 0.4394 | Val Spearman: 0.4451 | Time: 27.85s
#   → Saved new best model (Spearman: 0.4672)
#   → Saved new best model (Spearman: 0.5067)
#   → Saved new best model (Spearman: 0.5088)
#   → Saved new best model (Spearman: 0.5283)
# Epoch  15/50 | Train Loss: 0.5489 | Val Loss: 0.5253 | Train Spearman: 0.5074 | Val Spearman: 0.5283 | Time: 25.82s
#   → Saved new best model (Spearman: 0.5331)
#   → Saved new best model (Spearman: 0.5378)
#   → Saved new best model (Spearman: 0.5459)
#   → Saved new best model (Spearman: 0.5472)
#   → Saved new best model (Spearman: 0.5648)
# Epoch  20/50 | Train Loss: 0.4819 | Val Loss: 0.4724 | Train Spearman: 0.5501 | Val Spearman: 0.5648 | Time: 25.12s
#   → Saved new best model (Spearman: 0.5749)
#   → Saved new best model (Spearman: 0.5798)
# Epoch  25/50 | Train Loss: 0.4397 | Val Loss: 0.4792 | Train Spearman: 0.5759 | Val Spearman: 0.5798 | Time: 25.54s
#   → Saved new best model (Spearman: 0.6051)
# Epoch  30/50 | Train Loss: 0.4182 | Val Loss: 0.4217 | Train Spearman: 0.5872 | Val Spearman: 0.5765 | Time: 26.63s
#   → Saved new best model (Spearman: 0.6151)
# Epoch  35/50 | Train Loss: 0.4042 | Val Loss: 0.4157 | Train Spearman: 0.5965 | Val Spearman: 0.5961 | Time: 25.45s
#   → Saved new best model (Spearman: 0.6239)
# Epoch  40/50 | Train Loss: 0.3892 | Val Loss: 0.4013 | Train Spearman: 0.6043 | Val Spearman: 0.6237 | Time: 25.80s
#   → Saved new best model (Spearman: 0.6278)
# Epoch  45/50 | Train Loss: 0.3834 | Val Loss: 0.3984 | Train Spearman: 0.6114 | Val Spearman: 0.5925 | Time: 25.98s
#   → Saved new best model (Spearman: 0.6287)
#   → Saved new best model (Spearman: 0.6342)
#   → Saved new best model (Spearman: 0.6353)
# Epoch  50/50 | Train Loss: 0.3747 | Val Loss: 0.3661 | Train Spearman: 0.6173 | Val Spearman: 0.6353 | Time: 29.22s
#
# Training completed in 1309.36s
# Best validation Spearman correlation: 0.6353
#   → Search progress saved to Outputs_t4/LSTM_search_results_t4.json
#
# Running experiment 2/4: {'learning_rate': 1e-05, 'hidden_dim': 256, 'dropout': 0.3}
#
# ============================================================
# Training LSTM_exp1
# ============================================================
#   → Saved new best model (Spearman: 0.2345)
# Epoch   1/50 | Train Loss: 1.0215 | Val Loss: 0.9653 | Train Spearman: 0.1060 | Val Spearman: 0.2345 | Time: 27.33s
#   → Saved new best model (Spearman: 0.2471)
#   → Saved new best model (Spearman: 0.2578)
#   → Saved new best model (Spearman: 0.2678)
#   → Saved new best model (Spearman: 0.2760)
# Epoch   5/50 | Train Loss: 0.9777 | Val Loss: 0.9504 | Train Spearman: 0.2096 | Val Spearman: 0.2760 | Time: 29.31s
#   → Saved new best model (Spearman: 0.2824)
#   → Saved new best model (Spearman: 0.2873)
#   → Saved new best model (Spearman: 0.2880)
#   → Saved new best model (Spearman: 0.2914)
#   → Saved new best model (Spearman: 0.2950)
# Epoch  10/50 | Train Loss: 0.9562 | Val Loss: 0.9398 | Train Spearman: 0.2562 | Val Spearman: 0.2950 | Time: 24.44s
#   → Saved new best model (Spearman: 0.2967)
#   → Saved new best model (Spearman: 0.3211)
#   → Saved new best model (Spearman: 0.3604)
#   → Saved new best model (Spearman: 0.3706)
# Epoch  15/50 | Train Loss: 0.9019 | Val Loss: 0.9075 | Train Spearman: 0.3458 | Val Spearman: 0.3706 | Time: 23.89s
#   → Saved new best model (Spearman: 0.3748)
# Epoch  20/50 | Train Loss: 0.8831 | Val Loss: 0.8702 | Train Spearman: 0.3591 | Val Spearman: 0.3741 | Time: 24.69s
#   → Saved new best model (Spearman: 0.3794)
#   → Saved new best model (Spearman: 0.3817)
#   → Saved new best model (Spearman: 0.3827)
#   → Saved new best model (Spearman: 0.3838)
# Epoch  25/50 | Train Loss: 0.8693 | Val Loss: 0.8563 | Train Spearman: 0.3737 | Val Spearman: 0.3838 | Time: 27.66s
#   → Saved new best model (Spearman: 0.3857)
#   → Saved new best model (Spearman: 0.3913)
#   → Saved new best model (Spearman: 0.3942)
#   → Saved new best model (Spearman: 0.3971)
#   → Saved new best model (Spearman: 0.4012)
# Epoch  30/50 | Train Loss: 0.8530 | Val Loss: 0.8403 | Train Spearman: 0.3863 | Val Spearman: 0.4012 | Time: 25.80s
#   → Saved new best model (Spearman: 0.4020)
#   → Saved new best model (Spearman: 0.4054)
#   → Saved new best model (Spearman: 0.4083)
#   → Saved new best model (Spearman: 0.4092)
# Epoch  35/50 | Train Loss: 0.8387 | Val Loss: 0.8849 | Train Spearman: 0.3991 | Val Spearman: 0.4092 | Time: 24.90s
#   → Saved new best model (Spearman: 0.4157)
#   → Saved new best model (Spearman: 0.4204)
# Epoch  40/50 | Train Loss: 0.8260 | Val Loss: 0.8258 | Train Spearman: 0.4097 | Val Spearman: 0.4178 | Time: 28.66s
#   → Saved new best model (Spearman: 0.4218)
#   → Saved new best model (Spearman: 0.4224)
#   → Saved new best model (Spearman: 0.4287)
#   → Saved new best model (Spearman: 0.4314)
# Epoch  45/50 | Train Loss: 0.8122 | Val Loss: 0.8078 | Train Spearman: 0.4212 | Val Spearman: 0.4286 | Time: 26.34s
#   → Saved new best model (Spearman: 0.4315)
#   → Saved new best model (Spearman: 0.4347)
#   → Saved new best model (Spearman: 0.4348)
#   → Saved new best model (Spearman: 0.4360)
#   → Saved new best model (Spearman: 0.4381)
# Epoch  50/50 | Train Loss: 0.8032 | Val Loss: 0.8000 | Train Spearman: 0.4279 | Val Spearman: 0.4381 | Time: 26.42s
#
# Training completed in 1339.10s
# Best validation Spearman correlation: 0.4381
#   → Search progress saved to Outputs_t4/LSTM_search_results_t4.json
#
# Running experiment 3/4: {'learning_rate': 0.0015, 'hidden_dim': 256, 'dropout': 0.3}
#
# ============================================================
# Training LSTM_exp2
# ============================================================
#   → Saved new best model (Spearman: 0.1305)
# Epoch   1/50 | Train Loss: 1.0027 | Val Loss: 1.0145 | Train Spearman: 0.0980 | Val Spearman: 0.1305 | Time: 26.03s
# Epoch   5/50 | Train Loss: 1.0002 | Val Loss: 1.0006 | Train Spearman: 0.0027 | Val Spearman: 0.0036 | Time: 24.79s
#   → Saved new best model (Spearman: 0.1888)
#   → Saved new best model (Spearman: 0.2027)
# Epoch  10/50 | Train Loss: 1.0000 | Val Loss: 1.0008 | Train Spearman: -0.0045 | Val Spearman: 0.2027 | Time: 23.97s
#   → Saved new best model (Spearman: 0.2548)
#   → Saved new best model (Spearman: 0.5076)
#   → Saved new best model (Spearman: 0.5730)
#   → Saved new best model (Spearman: 0.6015)
# Epoch  15/50 | Train Loss: 0.4452 | Val Loss: 0.4104 | Train Spearman: 0.5700 | Val Spearman: 0.6015 | Time: 28.86s
#   → Saved new best model (Spearman: 0.6029)
#   → Saved new best model (Spearman: 0.6258)
#   → Saved new best model (Spearman: 0.6370)
#   → Saved new best model (Spearman: 0.6408)
# Epoch  20/50 | Train Loss: 0.3682 | Val Loss: 0.3781 | Train Spearman: 0.6213 | Val Spearman: 0.6408 | Time: 28.16s
#   → Saved new best model (Spearman: 0.6453)
#   → Saved new best model (Spearman: 0.6488)
#   → Saved new best model (Spearman: 0.6549)
# Epoch  25/50 | Train Loss: 0.3371 | Val Loss: 0.3751 | Train Spearman: 0.6407 | Val Spearman: 0.6549 | Time: 23.72s
#   → Saved new best model (Spearman: 0.6553)
#   → Saved new best model (Spearman: 0.6627)
#   → Saved new best model (Spearman: 0.6648)
# Epoch  30/50 | Train Loss: 0.3142 | Val Loss: 0.3441 | Train Spearman: 0.6521 | Val Spearman: 0.6648 | Time: 26.98s
#   → Saved new best model (Spearman: 0.6679)
# Epoch  35/50 | Train Loss: 0.2912 | Val Loss: 0.3288 | Train Spearman: 0.6611 | Val Spearman: 0.6667 | Time: 40.60s
#   → Saved new best model (Spearman: 0.6695)
# Epoch  40/50 | Train Loss: 0.2702 | Val Loss: 0.3270 | Train Spearman: 0.6680 | Val Spearman: 0.6655 | Time: 38.97s
#   → Saved new best model (Spearman: 0.6706)
#   → Saved new best model (Spearman: 0.6722)
# Epoch  45/50 | Train Loss: 0.2526 | Val Loss: 0.3283 | Train Spearman: 0.6766 | Val Spearman: 0.6722 | Time: 40.39s
#   → Saved new best model (Spearman: 0.6748)
# Epoch  50/50 | Train Loss: 0.2358 | Val Loss: 0.3256 | Train Spearman: 0.6862 | Val Spearman: 0.6741 | Time: 39.44s
#
# Training completed in 1558.80s
# Best validation Spearman correlation: 0.6748
#   → Search progress saved to Outputs_t4/LSTM_search_results_t4.json
#
# Running experiment 4/4: {'learning_rate': 0.0025, 'hidden_dim': 256, 'dropout': 0.3}
#
# ============================================================
# Training LSTM_exp3
# ============================================================
#   → Saved new best model (Spearman: -0.0437)
# Epoch   1/50 | Train Loss: 1.0122 | Val Loss: 1.0024 | Train Spearman: 0.0159 | Val Spearman: -0.0437 | Time: 40.33s
#   → Saved new best model (Spearman: 0.0036)
# Epoch   5/50 | Train Loss: 1.0003 | Val Loss: 1.0009 | Train Spearman: 0.0005 | Val Spearman: -0.0436 | Time: 41.14s
#   → Saved new best model (Spearman: 0.0665)
#   → Saved new best model (Spearman: 0.2140)
# Epoch  10/50 | Train Loss: 1.0000 | Val Loss: 1.0008 | Train Spearman: 0.0023 | Val Spearman: 0.0036 | Time: 40.78s
# Epoch  15/50 | Train Loss: 1.0005 | Val Loss: 1.0007 | Train Spearman: -0.0003 | Val Spearman: 0.0036 | Time: 38.74s
#
# Early stopping at epoch 16
#
# Training completed in 635.40s
# Best validation Spearman correlation: 0.2140
#   → Search progress saved to Outputs_t4/LSTM_search_results_t4.json
#
# ============================================================
# Best LSTM configuration: {'learning_rate': 0.0015, 'hidden_dim': 256, 'dropout': 0.3}
# Best validation Spearman: 0.6748
# Best model saved to Outputs_t4/best_lstm_model_t4.pth
# ============================================================

# %% [markdown]
# ## 9. Test Evaluation

# %%
# Load best CNN model
cnn_model = RNABindingCNN(
    hidden_dim=best_cnn_config['hidden_dim'], 
    dropout=best_cnn_config['dropout']
).to(device)
cnn_model.load_state_dict(torch.load(f'{OUTPUT_DIR}/best_cnn_model_t4.pth'))

# Evaluate CNN on test set
cnn_test_loss, cnn_test_corr = evaluate(cnn_model, test_loader, device)
print(f"\nBest CNN Test Results:")
print(f"  Test Loss: {cnn_test_loss:.4f}")
print(f"  Test Spearman Correlation: {cnn_test_corr:.4f}")
# Out:
# Best CNN Test Results:
#   Test Loss: 0.3303
#   Test Spearman Correlation: 0.6711

# %%
# Load best LSTM model
lstm_model = RNABindingLSTM(
    hidden_dim=best_lstm_config['hidden_dim'], 
    dropout=best_lstm_config['dropout']
).to(device)
lstm_model.load_state_dict(torch.load(f'{OUTPUT_DIR}/best_lstm_model_t4.pth'))

# Evaluate LSTM on test set
lstm_test_loss, lstm_test_corr = evaluate(lstm_model, test_loader, device)
print(f"\nBest LSTM Test Results:")
print(f"  Test Loss: {lstm_test_loss:.4f}")
print(f"  Test Spearman Correlation: {lstm_test_corr:.4f}")
# Out:
# Best LSTM Test Results:
#   Test Loss: 0.3322
#   Test Spearman Correlation: 0.6740

# %% [markdown]
# ## 10. Plotting Results and Saving History
#
# Saving plots and full experiment history to JSON for reproducibility.

# %%
import json

def save_and_plot_results(cnn_hist, lstm_hist, cnn_config, lstm_config, cnn_test_res, lstm_test_res):
    # Unpack test results
    cnn_test_loss, cnn_test_corr = cnn_test_res
    lstm_test_loss, lstm_test_corr = lstm_test_res
    
    # 1. Prepare Data for JSON Storage
    experiment_data = {
        "CNN": {
            "parameters": cnn_config,
            "training_time_seconds": cnn_hist['training_time'],
            "best_val_accuracy": cnn_hist['best_val_corr'],
            "best_val_epoch": int(np.argmax(cnn_hist['val_correlations']) + 1),
            "test_loss": cnn_test_loss,
            "test_accuracy": cnn_test_corr,
            "history": {
                "train_losses": cnn_hist['train_losses'],
                "train_correlations": cnn_hist['train_correlations'],
                "val_losses": cnn_hist['val_losses'],
                "val_correlations": cnn_hist['val_correlations']
            }
        },
        "LSTM": {
            "parameters": lstm_config,
            "training_time_seconds": lstm_hist['training_time'],
            "best_val_accuracy": lstm_hist['best_val_corr'],
            "best_val_epoch": int(np.argmax(lstm_hist['val_correlations']) + 1),
            "test_loss": lstm_test_loss,
            "test_accuracy": lstm_test_corr,
            "history": {
                "train_losses": lstm_hist['train_losses'],
                "train_correlations": lstm_hist['train_correlations'],
                "val_losses": lstm_hist['val_losses'],
                "val_correlations": lstm_hist['val_correlations']
            }
        }
    }

    # Save to JSON
    json_path = f'{OUTPUT_DIR}/complete_experiment_data_t4.json'
    with open(json_path, 'w') as f:
        json.dump(experiment_data, f, indent=4)
    print(f"Complete experiment data saved to '{json_path}'")

    # 2. Plotting
    epochs_cnn = range(1, len(cnn_hist['train_losses']) + 1)
    epochs_lstm = range(1, len(lstm_hist['train_losses']) + 1)

    # --- Plot 1: Loss ---
    plt.figure(figsize=(10, 6))
    plt.plot(epochs_cnn, cnn_hist['train_losses'], label='CNN Train Loss', color='blue', linestyle='--')
    plt.plot(epochs_cnn, cnn_hist['val_losses'], label='CNN Val Loss', color='blue')
    plt.plot(epochs_lstm, lstm_hist['train_losses'], label='LSTM Train Loss', color='red', linestyle='--')
    plt.plot(epochs_lstm, lstm_hist['val_losses'], label='LSTM Val Loss', color='red')
    plt.xlabel('Epochs')
    plt.ylabel('Loss (MSE)')
    plt.title('Training and Validation Loss')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.savefig(f'{OUTPUT_DIR}/loss_plot.png')
    plt.close()

    # --- Plot 2: Accuracy (Spearman Correlation) ---
    plt.figure(figsize=(10, 6))
    plt.plot(epochs_cnn, cnn_hist['train_correlations'], label='CNN Train Spearman', color='blue', linestyle='--')
    plt.plot(epochs_cnn, cnn_hist['val_correlations'], label='CNN Val Spearman', color='blue')
    plt.plot(epochs_lstm, lstm_hist['train_correlations'], label='LSTM Train Spearman', color='red', linestyle='--')
    plt.plot(epochs_lstm, lstm_hist['val_correlations'], label='LSTM Val Spearman', color='red')
    plt.xlabel('Epochs')
    plt.ylabel('Spearman Correlation')
    plt.title('Training and Validation Spearman Correlation')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.savefig(f'{OUTPUT_DIR}/accuracy_plot.png')
    plt.close()
    
    print("Plots saved to 'loss_plot.png' and 'accuracy_plot.png'.")

# Execute
save_and_plot_results(
    cnn_history, lstm_history, 
    best_cnn_config, best_lstm_config, 
    (cnn_test_loss, cnn_test_corr), 
    (lstm_test_loss, lstm_test_corr)
)
# Out:
# Complete experiment data saved to 'Outputs_t4/complete_experiment_data_t4.json'
# Plots saved to 'loss_plot.png' and 'accuracy_plot.png'.
