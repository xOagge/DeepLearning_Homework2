# %% [markdown]
# # Deep Learning Homework 2 - Question 2.1
# ## RNA Binding Protein (RBP) Interaction Prediction

# %% [markdown]
# ## 1. Setup and Imports

# %%
# Install required packages
# !pip install openpyxl -q

# %%
import os
import random
import time
import itertools
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from typing import List, Tuple

# Create Output Directory
OUTPUT_DIR = 'Outputs'
os.makedirs(OUTPUT_DIR, exist_ok=True)

# Check device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# Using device: cuda
# GPU: NVIDIA GeForce RTX 4060 Laptop GPU

# %% [markdown]
# ## 2. Download Data
#
# Download the data files from the Google Drive link provided in the homework:
# - `norm_data.txt`
# - `metadata.xlsx`
#
# Upload them to Colab or mount your Google Drive.

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
# Set the path to your data files
DATA_DIR = 'data'  # Change this to your folder path

# %% [markdown]
# ## 3. Configuration and Utility Functions

# %%
from config import RNAConfig

# %%
from utils import configure_seed, masked_mse_loss, masked_spearman_correlation

configure_seed(42)

# %% [markdown]
# ## 4. Data Loader

# %%
from utils import RNACompeteLoader, load_rnacompete_data

# %% [markdown]
# ## 5. Model Definitions
#
# ### 5.1 CNN Model

# %%
class RNABindingCNN(nn.Module):
    """
    1D Convolutional Neural Network for RNA sequence binding prediction.

    Architecture:
    - 3 convolutional layers with increasing channels (64 -> 128 -> 256)
    - Batch normalization after each conv layer
    - ReLU activation and dropout for regularization
    - Global max + average pooling for richer representation
    - 2 fully connected layers for regression output
    """

    def __init__(self, input_channels=4, seq_length=41, hidden_dim=128, dropout=0.3):
        super(RNABindingCNN, self).__init__()
        #L_out = ((L_in + 2P - K) / S)  + 1

        # Convolutional layers with different kernel sizes to capture various motif lengths
        # Padding choices allow to preserve input length through the feature maps
        #L_out = 41
        self.conv1 = nn.Conv1d(input_channels, 64, kernel_size=5, padding=2)
        self.bn1 = nn.BatchNorm1d(64)

        #L_out = 41
        self.conv2 = nn.Conv1d(64, 128, kernel_size=7, padding=3)
        self.bn2 = nn.BatchNorm1d(128)

        #L_out = 41
        self.conv3 = nn.Conv1d(128, 256, kernel_size=9, padding=4)
        self.bn3 = nn.BatchNorm1d(256)

        self.dropout = nn.Dropout(dropout)

        # Global pooling (both max and average)
        # allows to get the strongest value of a given feature for the sequence
        self.global_max_pool = nn.AdaptiveMaxPool1d(1)
        # allows to get the average of how much a feature is present throughout the sequence
        self.global_avg_pool = nn.AdaptiveAvgPool1d(1)

        # Fully connected layers
        self.fc1 = nn.Linear(256 * 2, hidden_dim)  # *2 for concat of max and avg pool
        self.fc2 = nn.Linear(hidden_dim, 1)
        self.relu = nn.ReLU()

    def forward(self, x):
        # Input x shape: (batch, seq_length, 4)
        # Conv1d expects: (batch, channels, seq_length)
        x = x.permute(0, 2, 1)

        # Convolutional blocks
        x = self.relu(self.bn1(self.conv1(x)))
        x = self.dropout(x)

        x = self.relu(self.bn2(self.conv2(x)))
        x = self.dropout(x)

        x = self.relu(self.bn3(self.conv3(x)))
        x = self.dropout(x)

        # Global pooling
        max_pool = self.global_max_pool(x).squeeze(-1)
        avg_pool = self.global_avg_pool(x).squeeze(-1)
        x = torch.cat([max_pool, avg_pool], dim=1)

        # Fully connected layers
        x = self.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.fc2(x)

        return x

# %% [markdown]
# ### 5.2 LSTM Model

# %%
class RNABindingLSTM(nn.Module):
    """
    Bidirectional LSTM for RNA sequence binding prediction.

    Architecture:
    - 2-layer bidirectional LSTM
    - Batch normalization
    - Dropout for regularization
    - 2 fully connected layers for regression
    """

    def __init__(self, input_dim=4, hidden_dim=128, num_layers=2, dropout=0.3, bidirectional=True):
        super(RNABindingLSTM, self).__init__()

        self.hidden_dim = hidden_dim
        self.num_layers = num_layers
        self.bidirectional = bidirectional
        self.num_directions = 2 if bidirectional else 1

        self.lstm = nn.LSTM(
            input_size=input_dim,
            hidden_size=hidden_dim,
            num_layers=num_layers,
            batch_first=True,
            dropout=dropout if num_layers > 1 else 0,
            bidirectional=bidirectional
        )

        self.bn = nn.BatchNorm1d(hidden_dim * self.num_directions)
        self.dropout = nn.Dropout(dropout)

        self.fc1 = nn.Linear(hidden_dim * self.num_directions, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, 1)
        self.relu = nn.ReLU()

    def forward(self, x):
        # Input x shape: (batch, seq_length, 4)
        lstm_out, (hidden, cell) = self.lstm(x)

        if self.bidirectional:
            # Concatenate last hidden states from forward and backward
            hidden_forward = hidden[-2, :, :]
            hidden_backward = hidden[-1, :, :]
            combined = torch.cat([hidden_forward, hidden_backward], dim=1)
        else:
            combined = hidden[-1, :, :]

        combined = self.bn(combined)
        combined = self.dropout(combined)

        x = self.relu(self.fc1(combined))
        x = self.dropout(x)
        x = self.fc2(x)

        return x

# %% [markdown]
# ## 6. Training and Evaluation Functions

# %%
def train_epoch(model, train_loader, optimizer, device):
    """Train for one epoch and return loss and correlation."""
    model.train()
    total_loss = 0.0
    num_batches = 0
    
    all_preds = []
    all_targets = []
    all_masks = []

    for batch in train_loader:
        x, y, mask = batch
        x, y, mask = x.to(device), y.to(device), mask.to(device)

        optimizer.zero_grad()
        predictions = model(x)
        loss = masked_mse_loss(predictions, y, mask)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()

        total_loss += loss.item()
        num_batches += 1
        
        # Collect for metric calculation
        all_preds.append(predictions.detach().cpu())
        all_targets.append(y.detach().cpu())
        all_masks.append(mask.detach().cpu())

    all_preds = torch.cat(all_preds, dim=0)
    all_targets = torch.cat(all_targets, dim=0)
    all_masks = torch.cat(all_masks, dim=0)
    
    spearman_corr = masked_spearman_correlation(all_preds, all_targets, all_masks)

    return total_loss / num_batches, spearman_corr.item()


def evaluate(model, data_loader, device):
    """Evaluate model and return loss and Spearman correlation."""
    model.eval()
    total_loss = 0.0
    num_batches = 0

    all_preds = []
    all_targets = []
    all_masks = []

    with torch.no_grad():
        for batch in data_loader:
            x, y, mask = batch
            x, y, mask = x.to(device), y.to(device), mask.to(device)

            predictions = model(x)
            loss = masked_mse_loss(predictions, y, mask)

            total_loss += loss.item()
            num_batches += 1

            all_preds.append(predictions.cpu())
            all_targets.append(y.cpu())
            all_masks.append(mask.cpu())

    all_preds = torch.cat(all_preds, dim=0)
    all_targets = torch.cat(all_targets, dim=0)
    all_masks = torch.cat(all_masks, dim=0)

    spearman_corr = masked_spearman_correlation(all_preds, all_targets, all_masks)

    return total_loss / num_batches, spearman_corr.item()


def train_model(model, train_loader, val_loader, optimizer, scheduler, device,
                num_epochs, model_name, patience=15, save_every=10):
    """Full training loop with early stopping and periodic checkpoints."""
    print(f"\n{'='*60}")
    print(f"Training {model_name}")
    print(f"{'='*60}")

    train_losses = []
    train_correlations = []
    val_losses = []
    val_correlations = []

    best_val_corr = -float('inf')
    best_model_state = None
    epochs_without_improvement = 0

    start_time = time.time()

    for epoch in range(num_epochs):
        epoch_start = time.time()

        train_loss, train_corr = train_epoch(model, train_loader, optimizer, device)
        val_loss, val_corr = evaluate(model, val_loader, device)

        if scheduler is not None:
            scheduler.step(val_corr)

        train_losses.append(train_loss)
        train_correlations.append(train_corr)
        val_losses.append(val_loss)
        val_correlations.append(val_corr)

        if val_corr > best_val_corr:
            best_val_corr = val_corr
            best_model_state = {k: v.cpu().clone() for k, v in model.state_dict().items()}
            epochs_without_improvement = 0
            # Save best model to Output directory
            torch.save(best_model_state, f'{OUTPUT_DIR}/{model_name}_best.pth')
            print(f"  → Saved new best model (Spearman: {val_corr:.4f})")
        else:
            epochs_without_improvement += 1

        epoch_time = time.time() - epoch_start

        if (epoch + 1) % 5 == 0 or epoch == 0:
            print(f"Epoch {epoch+1:3d}/{num_epochs} | "
                  f"Train Loss: {train_loss:.4f} | "
                  f"Val Loss: {val_loss:.4f} | "
                  f"Train Spearman: {train_corr:.4f} | "
                  f"Val Spearman: {val_corr:.4f} | "
                  f"Time: {epoch_time:.2f}s")

        # Periodic checkpoint every N epochs
        if (epoch + 1) % save_every == 0:
            checkpoint = {
                'epoch': epoch + 1,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'train_losses': train_losses,
                'train_correlations': train_correlations,
                'val_losses': val_losses,
                'val_correlations': val_correlations,
                'best_val_corr': best_val_corr
            }
            torch.save(checkpoint, f'{OUTPUT_DIR}/{model_name}_checkpoint_epoch{epoch+1}.pth')
            print(f"  → Checkpoint saved at epoch {epoch+1}")

        if epochs_without_improvement >= patience:
            print(f"\nEarly stopping at epoch {epoch+1}")
            break

    total_time = time.time() - start_time

    if best_model_state is not None:
        model.load_state_dict(best_model_state)

    print(f"\nTraining completed in {total_time:.2f}s")
    print(f"Best validation Spearman correlation: {best_val_corr:.4f}")

    return {
        'train_losses': train_losses,
        'train_correlations': train_correlations,
        'val_losses': val_losses,
        'val_correlations': val_correlations,
        'best_val_corr': best_val_corr,
        'training_time': total_time
    }

# %% [markdown]
# ## 7. Load Data

# %%
PROTEIN_NAME = 'RBFOX1'
BATCH_SIZE = 64

# Load data
print(f"Loading data for protein: {PROTEIN_NAME}")
config = RNAConfig()

train_dataset = load_rnacompete_data(PROTEIN_NAME, split='train', config=config)
val_dataset = load_rnacompete_data(PROTEIN_NAME, split='val', config=config)
test_dataset = load_rnacompete_data(PROTEIN_NAME, split='test', config=config)

print(f"\nDataset sizes:")
print(f"  Train: {len(train_dataset)}")
print(f"  Val: {len(val_dataset)}")
print(f"  Test: {len(test_dataset)}")

# Create data loaders
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)
# Out:
# Loading data for protein: RBFOX1
# Found cached data for RBFOX1 (train). Loading from data/RBFOX1_train_data.pt...
# Found cached data for RBFOX1 (val). Loading from data/RBFOX1_val_data.pt...
# Found cached data for RBFOX1 (test). Loading from data/RBFOX1_test_data.pt...
#
# Dataset sizes:
#   Train: 96261
#   Val: 24065
#   Test: 121031

# %% [markdown]
# ## 8. Hyperparameter Search and Training
#
# Here we define the search space and a function to iterate through hyperparameters, training the model for each combination.

# %%
# --- ROBUST GRID SEARCH (12 Combinations) ---
# for train_model with patience 7, and scheduler patience 5
param_grid = {
    # Covers best LSTM (0.001), best CNN (0.0001) and midpoint (0.0005)
    'learning_rate': [0.001, 0.0005, 0.0001],
    # Tests if doubling capacity improves results
    'hidden_dim': [128, 256],
    # Standard regularization vs Stronger regularization (for larger models)
    'dropout': [0.3, 0.5]
}

#simply fast grid to test if code runs well
# param_grid = {
#     # Covers best LSTM (0.001), best CNN (0.0001) and midpoint (0.0005)
#     'learning_rate': [0.0001],
#     # Tests if doubling capacity improves results
#     'hidden_dim': [2],
#     # Standard regularization vs Stronger regularization (for larger models)
#     'dropout': [0.8]
# }

def hyperparameter_search(model_class, model_name, param_grid, train_loader, val_loader, device, epochs=50):
    keys, values = zip(*param_grid.items())
    experiments = [dict(zip(keys, v)) for v in itertools.product(*values)]
    
    best_val_corr = -float('inf')
    best_config = None
    best_history = None
    
    print(f"Starting Hyperparameter Search for {model_name} with {len(experiments)} configurations...")
    
    results = []
    # Define a path for the intermediate results
    results_path = f'{OUTPUT_DIR}/{model_name}_search_results.json'
    
    for i, config in enumerate(experiments):
        print(f"\nRunning experiment {i+1}/{len(experiments)}: {config}")
        
        configure_seed(42)
        
        # Initialize model with current config
        # Note: LSTM and CNN have slightly different init signatures if not careful,
        # but here we matched the param names in the grid to the init args
        if model_name == 'LSTM':
             model = model_class(
                hidden_dim=config['hidden_dim'],
                dropout=config['dropout']
            ).to(device)
        else:
             model = model_class(
                hidden_dim=config['hidden_dim'],
                dropout=config['dropout']
            ).to(device)
            
        optimizer = optim.Adam(model.parameters(), lr=config['learning_rate'], weight_decay=1e-5)
        scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', factor=0.5, patience=5)
        
        # Train - using fewer epochs for search to save time (can increase for final result)
        # We use a unique name for temporary checkpoints
        temp_name = f"{model_name}_exp{i}"
        history = train_model(
            model, train_loader, val_loader, optimizer, scheduler,
            device, num_epochs=epochs, model_name=temp_name, patience=7, save_every=100
        )
        
        # --- SAVE PROGRESS IMMEDIATELY ---
        run_result = {
            'experiment_index': i,
            'config': config,
            'best_val_corr': history['best_val_corr'],
            'training_time': history['training_time'],
            'history': history # Full history included for plotting/resuming
        }
        results.append(run_result)
        
        try:
            with open(results_path, 'w') as f:
                json.dump(results, f, indent=4)
            print(f"  → Search progress saved to {results_path}")
        except Exception as e:
            print(f"  → Warning: Could not save progress to JSON: {e}")

        if history['best_val_corr'] > best_val_corr:
            best_val_corr = history['best_val_corr']
            best_config = config
            best_history = history
            
            # Save the best model of the search as the final best model
            # We load the best state from the temp file and save it to the final destination
            best_state = torch.load(f'{OUTPUT_DIR}/{temp_name}_best.pth')
            torch.save(best_state, f'{OUTPUT_DIR}/best_{model_name.lower()}_model.pth')
            
    print(f"\n{'='*60}")
    print(f"Best {model_name} configuration: {best_config}")
    print(f"Best validation Spearman: {best_val_corr:.4f}")
    print(f"Best model saved to {OUTPUT_DIR}/best_{model_name.lower()}_model.pth")
    print(f"{'='*60}")
    
    return best_config, best_history

# %%
# 8.1 Train and Search CNN
print("---- Tuning CNN ----")
best_cnn_config, cnn_history = hyperparameter_search(
    RNABindingCNN, 'CNN', param_grid, train_loader, val_loader, device, epochs=50
)
# Out:
# ---- Tuning CNN ----
# Starting Hyperparameter Search for CNN with 12 configurations...
#
# Running experiment 1/12: {'learning_rate': 0.001, 'hidden_dim': 128, 'dropout': 0.3}
#
# ============================================================
# Training CNN_exp0
# ============================================================
#   → Saved new best model (Spearman: 0.5452)
# Epoch   1/50 | Train Loss: 0.6327 | Val Loss: 0.5194 | Train Spearman: 0.4410 | Val Spearman: 0.5452 | Time: 23.46s
#   → Saved new best model (Spearman: 0.5710)
#   → Saved new best model (Spearman: 0.5893)
#   → Saved new best model (Spearman: 0.6036)
#   → Saved new best model (Spearman: 0.6060)
# Epoch   5/50 | Train Loss: 0.4774 | Val Loss: 0.4930 | Train Spearman: 0.5460 | Val Spearman: 0.6060 | Time: 18.50s
#   → Saved new best model (Spearman: 0.6115)
#   → Saved new best model (Spearman: 0.6223)
#   → Saved new best model (Spearman: 0.6268)
#   → Saved new best model (Spearman: 0.6307)
# Epoch  10/50 | Train Loss: 0.4424 | Val Loss: 0.4380 | Train Spearman: 0.5741 | Val Spearman: 0.6307 | Time: 20.13s
#   → Saved new best model (Spearman: 0.6347)
#   → Saved new best model (Spearman: 0.6368)
#   → Saved new best model (Spearman: 0.6377)
# Epoch  15/50 | Train Loss: 0.4266 | Val Loss: 0.3975 | Train Spearman: 0.5872 | Val Spearman: 0.6314 | Time: 20.04s
#   → Saved new best model (Spearman: 0.6424)
#   → Saved new best model (Spearman: 0.6436)
# Epoch  20/50 | Train Loss: 0.4215 | Val Loss: 0.3784 | Train Spearman: 0.5910 | Val Spearman: 0.6432 | Time: 19.99s
#   → Saved new best model (Spearman: 0.6465)
#   → Saved new best model (Spearman: 0.6476)
# Epoch  25/50 | Train Loss: 0.4079 | Val Loss: 0.4118 | Train Spearman: 0.6020 | Val Spearman: 0.6447 | Time: 23.37s
#   → Saved new best model (Spearman: 0.6514)
# Epoch  30/50 | Train Loss: 0.3897 | Val Loss: 0.3947 | Train Spearman: 0.6111 | Val Spearman: 0.6514 | Time: 24.10s
#   → Saved new best model (Spearman: 0.6541)
#   → Saved new best model (Spearman: 0.6551)
#   → Saved new best model (Spearman: 0.6564)
# Epoch  35/50 | Train Loss: 0.3668 | Val Loss: 0.3717 | Train Spearman: 0.6213 | Val Spearman: 0.6553 | Time: 21.08s
#   → Saved new best model (Spearman: 0.6567)
#   → Saved new best model (Spearman: 0.6573)
# Epoch  40/50 | Train Loss: 0.3525 | Val Loss: 0.3675 | Train Spearman: 0.6282 | Val Spearman: 0.6566 | Time: 29.19s
#   → Saved new best model (Spearman: 0.6603)
#   → Saved new best model (Spearman: 0.6609)
# Epoch  45/50 | Train Loss: 0.3492 | Val Loss: 0.3796 | Train Spearman: 0.6300 | Val Spearman: 0.6585 | Time: 28.44s
#   → Saved new best model (Spearman: 0.6614)
#   → Saved new best model (Spearman: 0.6622)
# Epoch  50/50 | Train Loss: 0.3475 | Val Loss: 0.3462 | Train Spearman: 0.6330 | Val Spearman: 0.6622 | Time: 48.02s
#
# Training completed in 1247.60s
# Best validation Spearman correlation: 0.6622
#   → Search progress saved to Outputs/CNN_search_results.json
#
# Running experiment 2/12: {'learning_rate': 0.001, 'hidden_dim': 128, 'dropout': 0.5}
#
# ============================================================
# Training CNN_exp1
# ============================================================
#   → Saved new best model (Spearman: 0.5057)
# Epoch   1/50 | Train Loss: 0.7908 | Val Loss: 0.6285 | Train Spearman: 0.3346 | Val Spearman: 0.5057 | Time: 43.84s
#   → Saved new best model (Spearman: 0.5089)
#   → Saved new best model (Spearman: 0.5371)
#   → Saved new best model (Spearman: 0.5493)
#   → Saved new best model (Spearman: 0.5515)
# Epoch   5/50 | Train Loss: 0.6342 | Val Loss: 0.5904 | Train Spearman: 0.4217 | Val Spearman: 0.5515 | Time: 42.32s
#   → Saved new best model (Spearman: 0.5559)
#   → Saved new best model (Spearman: 0.5629)
#   → Saved new best model (Spearman: 0.5687)
#   → Saved new best model (Spearman: 0.5710)
#   → Saved new best model (Spearman: 0.5810)
# Epoch  10/50 | Train Loss: 0.5795 | Val Loss: 0.5571 | Train Spearman: 0.4645 | Val Spearman: 0.5810 | Time: 44.35s
#   → Saved new best model (Spearman: 0.5830)
#   → Saved new best model (Spearman: 0.5900)
#   → Saved new best model (Spearman: 0.5941)
#   → Saved new best model (Spearman: 0.5969)
# Epoch  15/50 | Train Loss: 0.5523 | Val Loss: 0.5254 | Train Spearman: 0.4896 | Val Spearman: 0.5969 | Time: 43.45s
#   → Saved new best model (Spearman: 0.6036)
# Epoch  20/50 | Train Loss: 0.5285 | Val Loss: 0.4957 | Train Spearman: 0.5114 | Val Spearman: 0.5995 | Time: 37.83s
#   → Saved new best model (Spearman: 0.6065)
#   → Saved new best model (Spearman: 0.6118)
# Epoch  25/50 | Train Loss: 0.5138 | Val Loss: 0.5250 | Train Spearman: 0.5202 | Val Spearman: 0.6117 | Time: 43.28s
#   → Saved new best model (Spearman: 0.6139)
#   → Saved new best model (Spearman: 0.6157)
#   → Saved new best model (Spearman: 0.6208)
#   → Saved new best model (Spearman: 0.6222)
# Epoch  30/50 | Train Loss: 0.5059 | Val Loss: 0.5103 | Train Spearman: 0.5347 | Val Spearman: 0.6222 | Time: 43.79s
#   → Saved new best model (Spearman: 0.6225)
# Epoch  35/50 | Train Loss: 0.4868 | Val Loss: 0.4722 | Train Spearman: 0.5440 | Val Spearman: 0.6216 | Time: 33.19s
#   → Saved new best model (Spearman: 0.6230)
#   → Saved new best model (Spearman: 0.6261)
# Epoch  40/50 | Train Loss: 0.4803 | Val Loss: 0.4579 | Train Spearman: 0.5496 | Val Spearman: 0.6230 | Time: 31.02s
#   → Saved new best model (Spearman: 0.6270)
#   → Saved new best model (Spearman: 0.6294)
# Epoch  45/50 | Train Loss: 0.4594 | Val Loss: 0.4638 | Train Spearman: 0.5645 | Val Spearman: 0.6255 | Time: 28.81s
#   → Saved new best model (Spearman: 0.6309)
#   → Saved new best model (Spearman: 0.6362)
# Epoch  50/50 | Train Loss: 0.4497 | Val Loss: 0.4027 | Train Spearman: 0.5710 | Val Spearman: 0.6298 | Time: 31.10s
#
# Training completed in 1858.43s
# Best validation Spearman correlation: 0.6362
#   → Search progress saved to Outputs/CNN_search_results.json
#
# Running experiment 3/12: {'learning_rate': 0.001, 'hidden_dim': 256, 'dropout': 0.3}
#
# ============================================================
# Training CNN_exp2
# ============================================================
#   → Saved new best model (Spearman: 0.5484)
# Epoch   1/50 | Train Loss: 0.6328 | Val Loss: 0.5268 | Train Spearman: 0.4396 | Val Spearman: 0.5484 | Time: 28.62s
#   → Saved new best model (Spearman: 0.5775)
#   → Saved new best model (Spearman: 0.5957)
#   → Saved new best model (Spearman: 0.6095)
#   → Saved new best model (Spearman: 0.6175)
# Epoch   5/50 | Train Loss: 0.4668 | Val Loss: 0.4156 | Train Spearman: 0.5552 | Val Spearman: 0.6175 | Time: 27.11s
#   → Saved new best model (Spearman: 0.6217)
#   → Saved new best model (Spearman: 0.6277)
#   → Saved new best model (Spearman: 0.6306)
#   → Saved new best model (Spearman: 0.6328)
# Epoch  10/50 | Train Loss: 0.4340 | Val Loss: 0.4395 | Train Spearman: 0.5814 | Val Spearman: 0.6328 | Time: 30.78s
#   → Saved new best model (Spearman: 0.6349)
#   → Saved new best model (Spearman: 0.6391)
#   → Saved new best model (Spearman: 0.6417)
#   → Saved new best model (Spearman: 0.6418)
# Epoch  15/50 | Train Loss: 0.4203 | Val Loss: 0.4379 | Train Spearman: 0.5949 | Val Spearman: 0.6418 | Time: 30.08s
#   → Saved new best model (Spearman: 0.6426)
#   → Saved new best model (Spearman: 0.6434)
#   → Saved new best model (Spearman: 0.6449)
#   → Saved new best model (Spearman: 0.6449)
# Epoch  20/50 | Train Loss: 0.4047 | Val Loss: 0.3707 | Train Spearman: 0.5968 | Val Spearman: 0.6449 | Time: 28.92s
#   → Saved new best model (Spearman: 0.6455)
#   → Saved new best model (Spearman: 0.6547)
# Epoch  25/50 | Train Loss: 0.3910 | Val Loss: 0.3907 | Train Spearman: 0.6065 | Val Spearman: 0.6547 | Time: 28.07s
# Epoch  30/50 | Train Loss: 0.3858 | Val Loss: 0.3896 | Train Spearman: 0.6098 | Val Spearman: 0.6492 | Time: 30.52s
#   → Saved new best model (Spearman: 0.6559)
#   → Saved new best model (Spearman: 0.6572)
# Epoch  35/50 | Train Loss: 0.3785 | Val Loss: 0.3647 | Train Spearman: 0.6131 | Val Spearman: 0.6539 | Time: 30.17s
#   → Saved new best model (Spearman: 0.6620)
# Epoch  40/50 | Train Loss: 0.3466 | Val Loss: 0.3691 | Train Spearman: 0.6292 | Val Spearman: 0.6617 | Time: 28.64s
#   → Saved new best model (Spearman: 0.6650)
# Epoch  45/50 | Train Loss: 0.3401 | Val Loss: 0.3777 | Train Spearman: 0.6365 | Val Spearman: 0.6642 | Time: 33.35s
#   → Saved new best model (Spearman: 0.6656)
#   → Saved new best model (Spearman: 0.6658)
# Epoch  50/50 | Train Loss: 0.3339 | Val Loss: 0.3475 | Train Spearman: 0.6386 | Val Spearman: 0.6640 | Time: 33.53s
#
# Training completed in 1461.04s
# Best validation Spearman correlation: 0.6658
#   → Search progress saved to Outputs/CNN_search_results.json
#
# Running experiment 4/12: {'learning_rate': 0.001, 'hidden_dim': 256, 'dropout': 0.5}
#
# ============================================================
# Training CNN_exp3
# ============================================================
#   → Saved new best model (Spearman: 0.5127)
# Epoch   1/50 | Train Loss: 0.7780 | Val Loss: 0.6294 | Train Spearman: 0.3658 | Val Spearman: 0.5127 | Time: 33.17s
#   → Saved new best model (Spearman: 0.5343)
#   → Saved new best model (Spearman: 0.5478)
#   → Saved new best model (Spearman: 0.5559)
#   → Saved new best model (Spearman: 0.5652)
# Epoch   5/50 | Train Loss: 0.5999 | Val Loss: 0.5615 | Train Spearman: 0.4619 | Val Spearman: 0.5652 | Time: 32.68s
#   → Saved new best model (Spearman: 0.5705)
#   → Saved new best model (Spearman: 0.5817)
#   → Saved new best model (Spearman: 0.5817)
#   → Saved new best model (Spearman: 0.5868)
#   → Saved new best model (Spearman: 0.5891)
# Epoch  10/50 | Train Loss: 0.5474 | Val Loss: 0.5147 | Train Spearman: 0.5007 | Val Spearman: 0.5891 | Time: 33.02s
#   → Saved new best model (Spearman: 0.5923)
#   → Saved new best model (Spearman: 0.5957)
#   → Saved new best model (Spearman: 0.6002)
#   → Saved new best model (Spearman: 0.6017)
#   → Saved new best model (Spearman: 0.6061)
# Epoch  15/50 | Train Loss: 0.5392 | Val Loss: 0.5327 | Train Spearman: 0.5173 | Val Spearman: 0.6061 | Time: 33.36s
#   → Saved new best model (Spearman: 0.6061)
#   → Saved new best model (Spearman: 0.6102)
#   → Saved new best model (Spearman: 0.6110)
# Epoch  20/50 | Train Loss: 0.5118 | Val Loss: 0.5184 | Train Spearman: 0.5316 | Val Spearman: 0.6110 | Time: 30.57s
#   → Saved new best model (Spearman: 0.6112)
#   → Saved new best model (Spearman: 0.6169)
#   → Saved new best model (Spearman: 0.6171)
#   → Saved new best model (Spearman: 0.6202)
# Epoch  25/50 | Train Loss: 0.4895 | Val Loss: 0.5096 | Train Spearman: 0.5397 | Val Spearman: 0.6202 | Time: 34.32s
#   → Saved new best model (Spearman: 0.6251)
# Epoch  30/50 | Train Loss: 0.4745 | Val Loss: 0.4579 | Train Spearman: 0.5492 | Val Spearman: 0.6222 | Time: 38.02s
#   → Saved new best model (Spearman: 0.6252)
# Epoch  35/50 | Train Loss: 0.4672 | Val Loss: 0.4759 | Train Spearman: 0.5595 | Val Spearman: 0.6227 | Time: 35.01s
#   → Saved new best model (Spearman: 0.6270)
#   → Saved new best model (Spearman: 0.6278)
#   → Saved new best model (Spearman: 0.6280)
# Epoch  40/50 | Train Loss: 0.4485 | Val Loss: 0.4283 | Train Spearman: 0.5677 | Val Spearman: 0.6280 | Time: 33.99s
#   → Saved new best model (Spearman: 0.6313)
#   → Saved new best model (Spearman: 0.6373)
#   → Saved new best model (Spearman: 0.6374)
# Epoch  45/50 | Train Loss: 0.4385 | Val Loss: 0.4291 | Train Spearman: 0.5707 | Val Spearman: 0.6374 | Time: 31.09s
# Epoch  50/50 | Train Loss: 0.4321 | Val Loss: 0.4101 | Train Spearman: 0.5761 | Val Spearman: 0.6303 | Time: 35.96s
#
# Training completed in 1678.12s
# Best validation Spearman correlation: 0.6374
#   → Search progress saved to Outputs/CNN_search_results.json
#
# Running experiment 5/12: {'learning_rate': 0.0005, 'hidden_dim': 128, 'dropout': 0.3}
#
# ============================================================
# Training CNN_exp4
# ============================================================
#   → Saved new best model (Spearman: 0.5367)
# Epoch   1/50 | Train Loss: 0.6350 | Val Loss: 0.5016 | Train Spearman: 0.4363 | Val Spearman: 0.5367 | Time: 29.94s
#   → Saved new best model (Spearman: 0.5729)
#   → Saved new best model (Spearman: 0.5894)
#   → Saved new best model (Spearman: 0.6013)
#   → Saved new best model (Spearman: 0.6090)
# Epoch   5/50 | Train Loss: 0.4573 | Val Loss: 0.4235 | Train Spearman: 0.5529 | Val Spearman: 0.6090 | Time: 36.27s
#   → Saved new best model (Spearman: 0.6199)
#   → Saved new best model (Spearman: 0.6255)
#   → Saved new best model (Spearman: 0.6277)
#   → Saved new best model (Spearman: 0.6318)
# Epoch  10/50 | Train Loss: 0.4213 | Val Loss: 0.3989 | Train Spearman: 0.5852 | Val Spearman: 0.6318 | Time: 30.88s
#   → Saved new best model (Spearman: 0.6373)
#   → Saved new best model (Spearman: 0.6423)
# Epoch  15/50 | Train Loss: 0.4049 | Val Loss: 0.3692 | Train Spearman: 0.5989 | Val Spearman: 0.6387 | Time: 33.12s
#   → Saved new best model (Spearman: 0.6433)
#   → Saved new best model (Spearman: 0.6471)
# Epoch  20/50 | Train Loss: 0.3874 | Val Loss: 0.3731 | Train Spearman: 0.6066 | Val Spearman: 0.6447 | Time: 28.56s
#   → Saved new best model (Spearman: 0.6492)
#   → Saved new best model (Spearman: 0.6498)
# Epoch  25/50 | Train Loss: 0.3727 | Val Loss: 0.3799 | Train Spearman: 0.6127 | Val Spearman: 0.6476 | Time: 28.44s
#   → Saved new best model (Spearman: 0.6507)
# Epoch  30/50 | Train Loss: 0.3577 | Val Loss: 0.3824 | Train Spearman: 0.6236 | Val Spearman: 0.6507 | Time: 21.03s
#   → Saved new best model (Spearman: 0.6531)
#   → Saved new best model (Spearman: 0.6540)
#   → Saved new best model (Spearman: 0.6546)
#   → Saved new best model (Spearman: 0.6560)
# Epoch  35/50 | Train Loss: 0.3427 | Val Loss: 0.3722 | Train Spearman: 0.6331 | Val Spearman: 0.6560 | Time: 20.44s
#   → Saved new best model (Spearman: 0.6574)
#   → Saved new best model (Spearman: 0.6577)
# Epoch  40/50 | Train Loss: 0.3389 | Val Loss: 0.3543 | Train Spearman: 0.6333 | Val Spearman: 0.6569 | Time: 18.56s
#   → Saved new best model (Spearman: 0.6579)
#   → Saved new best model (Spearman: 0.6581)
# Epoch  45/50 | Train Loss: 0.3273 | Val Loss: 0.3562 | Train Spearman: 0.6367 | Val Spearman: 0.6581 | Time: 17.51s
#   → Saved new best model (Spearman: 0.6584)
#   → Saved new best model (Spearman: 0.6590)
# Epoch  50/50 | Train Loss: 0.3266 | Val Loss: 0.3468 | Train Spearman: 0.6382 | Val Spearman: 0.6590 | Time: 17.73s
#
# Training completed in 1296.23s
# Best validation Spearman correlation: 0.6590
#   → Search progress saved to Outputs/CNN_search_results.json
#
# Running experiment 6/12: {'learning_rate': 0.0005, 'hidden_dim': 128, 'dropout': 0.5}
#
# ============================================================
# Training CNN_exp5
# ============================================================
#   → Saved new best model (Spearman: 0.5041)
# Epoch   1/50 | Train Loss: 0.7899 | Val Loss: 0.5862 | Train Spearman: 0.3558 | Val Spearman: 0.5041 | Time: 17.72s
#   → Saved new best model (Spearman: 0.5173)
#   → Saved new best model (Spearman: 0.5414)
#   → Saved new best model (Spearman: 0.5500)
#   → Saved new best model (Spearman: 0.5626)
# Epoch   5/50 | Train Loss: 0.5830 | Val Loss: 0.5733 | Train Spearman: 0.4724 | Val Spearman: 0.5626 | Time: 20.20s
#   → Saved new best model (Spearman: 0.5654)
#   → Saved new best model (Spearman: 0.5711)
#   → Saved new best model (Spearman: 0.5740)
#   → Saved new best model (Spearman: 0.5754)
#   → Saved new best model (Spearman: 0.5819)
# Epoch  10/50 | Train Loss: 0.5578 | Val Loss: 0.5600 | Train Spearman: 0.4966 | Val Spearman: 0.5819 | Time: 20.34s
#   → Saved new best model (Spearman: 0.5858)
#   → Saved new best model (Spearman: 0.5922)
#   → Saved new best model (Spearman: 0.5923)
#   → Saved new best model (Spearman: 0.5969)
#   → Saved new best model (Spearman: 0.5978)
# Epoch  15/50 | Train Loss: 0.5306 | Val Loss: 0.5005 | Train Spearman: 0.5130 | Val Spearman: 0.5978 | Time: 17.94s
#   → Saved new best model (Spearman: 0.6010)
#   → Saved new best model (Spearman: 0.6057)
#   → Saved new best model (Spearman: 0.6060)
#   → Saved new best model (Spearman: 0.6094)
# Epoch  20/50 | Train Loss: 0.5197 | Val Loss: 0.5030 | Train Spearman: 0.5270 | Val Spearman: 0.6094 | Time: 17.28s
#   → Saved new best model (Spearman: 0.6117)
#   → Saved new best model (Spearman: 0.6159)
# Epoch  25/50 | Train Loss: 0.5035 | Val Loss: 0.5240 | Train Spearman: 0.5359 | Val Spearman: 0.6136 | Time: 17.40s
#   → Saved new best model (Spearman: 0.6161)
#   → Saved new best model (Spearman: 0.6171)
#   → Saved new best model (Spearman: 0.6175)
#   → Saved new best model (Spearman: 0.6221)
# Epoch  30/50 | Train Loss: 0.4914 | Val Loss: 0.5114 | Train Spearman: 0.5441 | Val Spearman: 0.6221 | Time: 17.27s
#   → Saved new best model (Spearman: 0.6239)
#   → Saved new best model (Spearman: 0.6251)
#   → Saved new best model (Spearman: 0.6270)
# Epoch  35/50 | Train Loss: 0.4802 | Val Loss: 0.5164 | Train Spearman: 0.5541 | Val Spearman: 0.6257 | Time: 18.09s
#   → Saved new best model (Spearman: 0.6284)
#   → Saved new best model (Spearman: 0.6312)
# Epoch  40/50 | Train Loss: 0.4793 | Val Loss: 0.4737 | Train Spearman: 0.5546 | Val Spearman: 0.6286 | Time: 20.58s
# Epoch  45/50 | Train Loss: 0.4702 | Val Loss: 0.4925 | Train Spearman: 0.5590 | Val Spearman: 0.6303 | Time: 19.91s
#   → Saved new best model (Spearman: 0.6337)
#   → Saved new best model (Spearman: 0.6338)
# Epoch  50/50 | Train Loss: 0.4501 | Val Loss: 0.4303 | Train Spearman: 0.5755 | Val Spearman: 0.6330 | Time: 18.04s
#
# Training completed in 934.70s
# Best validation Spearman correlation: 0.6338
#   → Search progress saved to Outputs/CNN_search_results.json
#
# Running experiment 7/12: {'learning_rate': 0.0005, 'hidden_dim': 256, 'dropout': 0.3}
#
# ============================================================
# Training CNN_exp6
# ============================================================
#   → Saved new best model (Spearman: 0.5389)
# Epoch   1/50 | Train Loss: 0.6299 | Val Loss: 0.4937 | Train Spearman: 0.4405 | Val Spearman: 0.5389 | Time: 20.63s
#   → Saved new best model (Spearman: 0.5700)
#   → Saved new best model (Spearman: 0.5964)
#   → Saved new best model (Spearman: 0.5981)
#   → Saved new best model (Spearman: 0.6090)
# Epoch   5/50 | Train Loss: 0.4495 | Val Loss: 0.4277 | Train Spearman: 0.5604 | Val Spearman: 0.6090 | Time: 18.29s
#   → Saved new best model (Spearman: 0.6222)
#   → Saved new best model (Spearman: 0.6260)
#   → Saved new best model (Spearman: 0.6324)
#   → Saved new best model (Spearman: 0.6338)
#   → Saved new best model (Spearman: 0.6351)
# Epoch  10/50 | Train Loss: 0.4122 | Val Loss: 0.3888 | Train Spearman: 0.5912 | Val Spearman: 0.6351 | Time: 21.55s
#   → Saved new best model (Spearman: 0.6376)
#   → Saved new best model (Spearman: 0.6392)
#   → Saved new best model (Spearman: 0.6411)
# Epoch  15/50 | Train Loss: 0.3935 | Val Loss: 0.3914 | Train Spearman: 0.6019 | Val Spearman: 0.6400 | Time: 21.27s
#   → Saved new best model (Spearman: 0.6439)
#   → Saved new best model (Spearman: 0.6483)
#   → Saved new best model (Spearman: 0.6502)
# Epoch  20/50 | Train Loss: 0.3808 | Val Loss: 0.3683 | Train Spearman: 0.6092 | Val Spearman: 0.6481 | Time: 20.25s
#   → Saved new best model (Spearman: 0.6509)
#   → Saved new best model (Spearman: 0.6534)
# Epoch  25/50 | Train Loss: 0.3702 | Val Loss: 0.3894 | Train Spearman: 0.6150 | Val Spearman: 0.6534 | Time: 21.34s
#   → Saved new best model (Spearman: 0.6548)
# Epoch  30/50 | Train Loss: 0.3591 | Val Loss: 0.3643 | Train Spearman: 0.6210 | Val Spearman: 0.6540 | Time: 20.65s
#   → Saved new best model (Spearman: 0.6555)
# Epoch  35/50 | Train Loss: 0.3415 | Val Loss: 0.3615 | Train Spearman: 0.6315 | Val Spearman: 0.6555 | Time: 18.89s
#   → Saved new best model (Spearman: 0.6606)
# Epoch  40/50 | Train Loss: 0.3303 | Val Loss: 0.3689 | Train Spearman: 0.6381 | Val Spearman: 0.6593 | Time: 21.64s
#   → Saved new best model (Spearman: 0.6609)
#   → Saved new best model (Spearman: 0.6611)
# Epoch  45/50 | Train Loss: 0.3220 | Val Loss: 0.3599 | Train Spearman: 0.6410 | Val Spearman: 0.6611 | Time: 17.91s
#   → Saved new best model (Spearman: 0.6631)
# Epoch  50/50 | Train Loss: 0.3166 | Val Loss: 0.3386 | Train Spearman: 0.6441 | Val Spearman: 0.6631 | Time: 18.31s
#
# Training completed in 985.80s
# Best validation Spearman correlation: 0.6631
#   → Search progress saved to Outputs/CNN_search_results.json
#
# Running experiment 8/12: {'learning_rate': 0.0005, 'hidden_dim': 256, 'dropout': 0.5}
#
# ============================================================
# Training CNN_exp7
# ============================================================
#   → Saved new best model (Spearman: 0.5122)
# Epoch   1/50 | Train Loss: 0.7811 | Val Loss: 0.5973 | Train Spearman: 0.3605 | Val Spearman: 0.5122 | Time: 18.21s
#   → Saved new best model (Spearman: 0.5274)
#   → Saved new best model (Spearman: 0.5396)
#   → Saved new best model (Spearman: 0.5515)
#   → Saved new best model (Spearman: 0.5597)
# Epoch   5/50 | Train Loss: 0.5635 | Val Loss: 0.5460 | Train Spearman: 0.4809 | Val Spearman: 0.5597 | Time: 22.08s
#   → Saved new best model (Spearman: 0.5720)
#   → Saved new best model (Spearman: 0.5758)
#   → Saved new best model (Spearman: 0.5832)
#   → Saved new best model (Spearman: 0.5864)
#   → Saved new best model (Spearman: 0.5865)
# Epoch  10/50 | Train Loss: 0.5348 | Val Loss: 0.5512 | Train Spearman: 0.5086 | Val Spearman: 0.5865 | Time: 17.37s
#   → Saved new best model (Spearman: 0.5902)
#   → Saved new best model (Spearman: 0.5945)
#   → Saved new best model (Spearman: 0.5961)
#   → Saved new best model (Spearman: 0.6001)
#   → Saved new best model (Spearman: 0.6023)
# Epoch  15/50 | Train Loss: 0.5148 | Val Loss: 0.4904 | Train Spearman: 0.5267 | Val Spearman: 0.6023 | Time: 18.28s
#   → Saved new best model (Spearman: 0.6048)
#   → Saved new best model (Spearman: 0.6123)
# Epoch  20/50 | Train Loss: 0.5038 | Val Loss: 0.5206 | Train Spearman: 0.5341 | Val Spearman: 0.6069 | Time: 24.22s
#   → Saved new best model (Spearman: 0.6146)
#   → Saved new best model (Spearman: 0.6179)
#   → Saved new best model (Spearman: 0.6188)
# Epoch  25/50 | Train Loss: 0.4840 | Val Loss: 0.5058 | Train Spearman: 0.5448 | Val Spearman: 0.6187 | Time: 19.86s
#   → Saved new best model (Spearman: 0.6208)
#   → Saved new best model (Spearman: 0.6251)
# Epoch  30/50 | Train Loss: 0.4750 | Val Loss: 0.4661 | Train Spearman: 0.5517 | Val Spearman: 0.6219 | Time: 17.58s
#   → Saved new best model (Spearman: 0.6277)
# Epoch  35/50 | Train Loss: 0.4634 | Val Loss: 0.4502 | Train Spearman: 0.5601 | Val Spearman: 0.6269 | Time: 20.83s
#   → Saved new best model (Spearman: 0.6297)
#   → Saved new best model (Spearman: 0.6325)
#   → Saved new best model (Spearman: 0.6327)
# Epoch  40/50 | Train Loss: 0.4581 | Val Loss: 0.4287 | Train Spearman: 0.5641 | Val Spearman: 0.6305 | Time: 18.96s
#   → Saved new best model (Spearman: 0.6338)
#   → Saved new best model (Spearman: 0.6348)
# Epoch  45/50 | Train Loss: 0.4494 | Val Loss: 0.4621 | Train Spearman: 0.5666 | Val Spearman: 0.6348 | Time: 18.12s
#   → Saved new best model (Spearman: 0.6367)
# Epoch  50/50 | Train Loss: 0.4498 | Val Loss: 0.4279 | Train Spearman: 0.5734 | Val Spearman: 0.6367 | Time: 18.16s
#
# Training completed in 972.22s
# Best validation Spearman correlation: 0.6367
#   → Search progress saved to Outputs/CNN_search_results.json
#
# Running experiment 9/12: {'learning_rate': 0.0001, 'hidden_dim': 128, 'dropout': 0.3}
#
# ============================================================
# Training CNN_exp8
# ============================================================
#   → Saved new best model (Spearman: 0.5018)
# Epoch   1/50 | Train Loss: 0.7456 | Val Loss: 0.6575 | Train Spearman: 0.3859 | Val Spearman: 0.5018 | Time: 17.30s
#   → Saved new best model (Spearman: 0.5233)
#   → Saved new best model (Spearman: 0.5522)
#   → Saved new best model (Spearman: 0.5671)
#   → Saved new best model (Spearman: 0.5844)
# Epoch   5/50 | Train Loss: 0.4859 | Val Loss: 0.4502 | Train Spearman: 0.5314 | Val Spearman: 0.5844 | Time: 20.21s
#   → Saved new best model (Spearman: 0.5941)
#   → Saved new best model (Spearman: 0.6093)
#   → Saved new best model (Spearman: 0.6162)
#   → Saved new best model (Spearman: 0.6232)
# Epoch  10/50 | Train Loss: 0.4295 | Val Loss: 0.4045 | Train Spearman: 0.5761 | Val Spearman: 0.6232 | Time: 20.60s
#   → Saved new best model (Spearman: 0.6268)
#   → Saved new best model (Spearman: 0.6340)
#   → Saved new best model (Spearman: 0.6350)
#   → Saved new best model (Spearman: 0.6356)
# Epoch  15/50 | Train Loss: 0.4051 | Val Loss: 0.3777 | Train Spearman: 0.5944 | Val Spearman: 0.6356 | Time: 18.35s
#   → Saved new best model (Spearman: 0.6388)
#   → Saved new best model (Spearman: 0.6396)
#   → Saved new best model (Spearman: 0.6458)
#   → Saved new best model (Spearman: 0.6485)
# Epoch  20/50 | Train Loss: 0.3831 | Val Loss: 0.3662 | Train Spearman: 0.6061 | Val Spearman: 0.6485 | Time: 18.30s
# Epoch  25/50 | Train Loss: 0.3630 | Val Loss: 0.3658 | Train Spearman: 0.6161 | Val Spearman: 0.6480 | Time: 23.58s
#   → Saved new best model (Spearman: 0.6494)
#   → Saved new best model (Spearman: 0.6507)
#   → Saved new best model (Spearman: 0.6535)
# Epoch  30/50 | Train Loss: 0.3606 | Val Loss: 0.3694 | Train Spearman: 0.6195 | Val Spearman: 0.6535 | Time: 19.65s
#   → Saved new best model (Spearman: 0.6546)
#   → Saved new best model (Spearman: 0.6548)
# Epoch  35/50 | Train Loss: 0.3459 | Val Loss: 0.3544 | Train Spearman: 0.6261 | Val Spearman: 0.6531 | Time: 19.97s
#   → Saved new best model (Spearman: 0.6557)
# Epoch  40/50 | Train Loss: 0.3353 | Val Loss: 0.3555 | Train Spearman: 0.6338 | Val Spearman: 0.6557 | Time: 18.27s
#   → Saved new best model (Spearman: 0.6565)
# Epoch  45/50 | Train Loss: 0.3294 | Val Loss: 0.3588 | Train Spearman: 0.6363 | Val Spearman: 0.6565 | Time: 20.75s
#   → Saved new best model (Spearman: 0.6571)
# Epoch  50/50 | Train Loss: 0.3247 | Val Loss: 0.3479 | Train Spearman: 0.6373 | Val Spearman: 0.6571 | Time: 21.06s
#
# Training completed in 984.13s
# Best validation Spearman correlation: 0.6571
#   → Search progress saved to Outputs/CNN_search_results.json
#
# Running experiment 10/12: {'learning_rate': 0.0001, 'hidden_dim': 128, 'dropout': 0.5}
#
# ============================================================
# Training CNN_exp9
# ============================================================
#   → Saved new best model (Spearman: 0.4742)
# Epoch   1/50 | Train Loss: 0.9432 | Val Loss: 0.7780 | Train Spearman: 0.2348 | Val Spearman: 0.4742 | Time: 19.19s
#   → Saved new best model (Spearman: 0.4833)
#   → Saved new best model (Spearman: 0.4985)
#   → Saved new best model (Spearman: 0.5066)
#   → Saved new best model (Spearman: 0.5117)
# Epoch   5/50 | Train Loss: 0.6168 | Val Loss: 0.5329 | Train Spearman: 0.4505 | Val Spearman: 0.5117 | Time: 25.92s
#   → Saved new best model (Spearman: 0.5193)
#   → Saved new best model (Spearman: 0.5314)
#   → Saved new best model (Spearman: 0.5366)
#   → Saved new best model (Spearman: 0.5434)
#   → Saved new best model (Spearman: 0.5520)
# Epoch  10/50 | Train Loss: 0.5594 | Val Loss: 0.5138 | Train Spearman: 0.4870 | Val Spearman: 0.5520 | Time: 19.08s
#   → Saved new best model (Spearman: 0.5548)
#   → Saved new best model (Spearman: 0.5608)
#   → Saved new best model (Spearman: 0.5630)
#   → Saved new best model (Spearman: 0.5651)
#   → Saved new best model (Spearman: 0.5689)
# Epoch  15/50 | Train Loss: 0.5300 | Val Loss: 0.4947 | Train Spearman: 0.5057 | Val Spearman: 0.5689 | Time: 21.76s
#   → Saved new best model (Spearman: 0.5713)
#   → Saved new best model (Spearman: 0.5772)
#   → Saved new best model (Spearman: 0.5806)
# Epoch  20/50 | Train Loss: 0.5027 | Val Loss: 0.4855 | Train Spearman: 0.5223 | Val Spearman: 0.5784 | Time: 18.27s
#   → Saved new best model (Spearman: 0.5840)
#   → Saved new best model (Spearman: 0.5848)
#   → Saved new best model (Spearman: 0.5893)
#   → Saved new best model (Spearman: 0.5904)
#   → Saved new best model (Spearman: 0.5917)
# Epoch  25/50 | Train Loss: 0.4812 | Val Loss: 0.4934 | Train Spearman: 0.5335 | Val Spearman: 0.5917 | Time: 17.85s
#   → Saved new best model (Spearman: 0.5939)
#   → Saved new best model (Spearman: 0.5943)
#   → Saved new best model (Spearman: 0.5953)
#   → Saved new best model (Spearman: 0.6007)
# Epoch  30/50 | Train Loss: 0.4788 | Val Loss: 0.4779 | Train Spearman: 0.5436 | Val Spearman: 0.6007 | Time: 22.61s
#   → Saved new best model (Spearman: 0.6013)
#   → Saved new best model (Spearman: 0.6049)
#   → Saved new best model (Spearman: 0.6052)
# Epoch  35/50 | Train Loss: 0.4680 | Val Loss: 0.4658 | Train Spearman: 0.5503 | Val Spearman: 0.6052 | Time: 21.04s
#   → Saved new best model (Spearman: 0.6061)
#   → Saved new best model (Spearman: 0.6091)
# Epoch  40/50 | Train Loss: 0.4586 | Val Loss: 0.4729 | Train Spearman: 0.5558 | Val Spearman: 0.6091 | Time: 19.36s
#   → Saved new best model (Spearman: 0.6127)
# Epoch  45/50 | Train Loss: 0.4535 | Val Loss: 0.5141 | Train Spearman: 0.5630 | Val Spearman: 0.6116 | Time: 19.86s
#   → Saved new best model (Spearman: 0.6130)
#   → Saved new best model (Spearman: 0.6152)
# Epoch  50/50 | Train Loss: 0.4455 | Val Loss: 0.4615 | Train Spearman: 0.5647 | Val Spearman: 0.6152 | Time: 21.26s
#
# Training completed in 1035.58s
# Best validation Spearman correlation: 0.6152
#   → Search progress saved to Outputs/CNN_search_results.json
#
# Running experiment 11/12: {'learning_rate': 0.0001, 'hidden_dim': 256, 'dropout': 0.3}
#
# ============================================================
# Training CNN_exp10
# ============================================================
#   → Saved new best model (Spearman: 0.5082)
# Epoch   1/50 | Train Loss: 0.7296 | Val Loss: 0.5917 | Train Spearman: 0.3909 | Val Spearman: 0.5082 | Time: 23.60s
#   → Saved new best model (Spearman: 0.5313)
#   → Saved new best model (Spearman: 0.5429)
#   → Saved new best model (Spearman: 0.5681)
#   → Saved new best model (Spearman: 0.5874)
# Epoch   5/50 | Train Loss: 0.4804 | Val Loss: 0.4429 | Train Spearman: 0.5318 | Val Spearman: 0.5874 | Time: 18.18s
#   → Saved new best model (Spearman: 0.5997)
#   → Saved new best model (Spearman: 0.6057)
#   → Saved new best model (Spearman: 0.6151)
#   → Saved new best model (Spearman: 0.6221)
#   → Saved new best model (Spearman: 0.6258)
# Epoch  10/50 | Train Loss: 0.4261 | Val Loss: 0.4079 | Train Spearman: 0.5805 | Val Spearman: 0.6258 | Time: 20.11s
#   → Saved new best model (Spearman: 0.6309)
#   → Saved new best model (Spearman: 0.6330)
#   → Saved new best model (Spearman: 0.6369)
#   → Saved new best model (Spearman: 0.6387)
#   → Saved new best model (Spearman: 0.6398)
# Epoch  15/50 | Train Loss: 0.3983 | Val Loss: 0.3761 | Train Spearman: 0.5985 | Val Spearman: 0.6398 | Time: 23.15s
#   → Saved new best model (Spearman: 0.6428)
#   → Saved new best model (Spearman: 0.6438)
#   → Saved new best model (Spearman: 0.6459)
#   → Saved new best model (Spearman: 0.6471)
# Epoch  20/50 | Train Loss: 0.3806 | Val Loss: 0.3707 | Train Spearman: 0.6068 | Val Spearman: 0.6471 | Time: 19.72s
#   → Saved new best model (Spearman: 0.6497)
# Epoch  25/50 | Train Loss: 0.3683 | Val Loss: 0.4070 | Train Spearman: 0.6163 | Val Spearman: 0.6478 | Time: 20.64s
#   → Saved new best model (Spearman: 0.6507)
#   → Saved new best model (Spearman: 0.6557)
# Epoch  30/50 | Train Loss: 0.3570 | Val Loss: 0.3647 | Train Spearman: 0.6221 | Val Spearman: 0.6550 | Time: 17.85s
# Epoch  35/50 | Train Loss: 0.3397 | Val Loss: 0.3666 | Train Spearman: 0.6303 | Val Spearman: 0.6534 | Time: 23.29s
#
# Early stopping at epoch 35
#
# Training completed in 720.88s
# Best validation Spearman correlation: 0.6557
#   → Search progress saved to Outputs/CNN_search_results.json
#
# Running experiment 12/12: {'learning_rate': 0.0001, 'hidden_dim': 256, 'dropout': 0.5}
#
# ============================================================
# Training CNN_exp11
# ============================================================
#   → Saved new best model (Spearman: 0.4769)
# Epoch   1/50 | Train Loss: 0.9295 | Val Loss: 0.7477 | Train Spearman: 0.2481 | Val Spearman: 0.4769 | Time: 21.96s
#   → Saved new best model (Spearman: 0.4863)
#   → Saved new best model (Spearman: 0.4927)
#   → Saved new best model (Spearman: 0.5050)
#   → Saved new best model (Spearman: 0.5097)
# Epoch   5/50 | Train Loss: 0.6018 | Val Loss: 0.5286 | Train Spearman: 0.4466 | Val Spearman: 0.5097 | Time: 19.17s
#   → Saved new best model (Spearman: 0.5144)
#   → Saved new best model (Spearman: 0.5250)
#   → Saved new best model (Spearman: 0.5322)
#   → Saved new best model (Spearman: 0.5408)
#   → Saved new best model (Spearman: 0.5504)
# Epoch  10/50 | Train Loss: 0.5422 | Val Loss: 0.5015 | Train Spearman: 0.4855 | Val Spearman: 0.5504 | Time: 23.10s
#   → Saved new best model (Spearman: 0.5562)
#   → Saved new best model (Spearman: 0.5588)
#   → Saved new best model (Spearman: 0.5670)
#   → Saved new best model (Spearman: 0.5724)
#   → Saved new best model (Spearman: 0.5759)
# Epoch  15/50 | Train Loss: 0.5117 | Val Loss: 0.4702 | Train Spearman: 0.5148 | Val Spearman: 0.5759 | Time: 18.86s
#   → Saved new best model (Spearman: 0.5768)
#   → Saved new best model (Spearman: 0.5817)
#   → Saved new best model (Spearman: 0.5820)
#   → Saved new best model (Spearman: 0.5842)
#   → Saved new best model (Spearman: 0.5867)
# Epoch  20/50 | Train Loss: 0.4935 | Val Loss: 0.4887 | Train Spearman: 0.5298 | Val Spearman: 0.5867 | Time: 22.82s
#   → Saved new best model (Spearman: 0.5920)
#   → Saved new best model (Spearman: 0.5923)
#   → Saved new best model (Spearman: 0.5945)
#   → Saved new best model (Spearman: 0.5947)
#   → Saved new best model (Spearman: 0.5961)
# Epoch  25/50 | Train Loss: 0.4707 | Val Loss: 0.4772 | Train Spearman: 0.5431 | Val Spearman: 0.5961 | Time: 16.92s
#   → Saved new best model (Spearman: 0.5991)
#   → Saved new best model (Spearman: 0.6026)
#   → Saved new best model (Spearman: 0.6040)
# Epoch  30/50 | Train Loss: 0.4650 | Val Loss: 0.4793 | Train Spearman: 0.5553 | Val Spearman: 0.6040 | Time: 18.56s
#   → Saved new best model (Spearman: 0.6051)
#   → Saved new best model (Spearman: 0.6094)
# Epoch  35/50 | Train Loss: 0.4557 | Val Loss: 0.4823 | Train Spearman: 0.5597 | Val Spearman: 0.6023 | Time: 22.18s
#   → Saved new best model (Spearman: 0.6098)
#   → Saved new best model (Spearman: 0.6149)
# Epoch  40/50 | Train Loss: 0.4444 | Val Loss: 0.4737 | Train Spearman: 0.5655 | Val Spearman: 0.6149 | Time: 20.95s
#   → Saved new best model (Spearman: 0.6154)
# Epoch  45/50 | Train Loss: 0.4425 | Val Loss: 0.4859 | Train Spearman: 0.5680 | Val Spearman: 0.6144 | Time: 21.83s
#   → Saved new best model (Spearman: 0.6157)
#   → Saved new best model (Spearman: 0.6158)
#   → Saved new best model (Spearman: 0.6205)
# Epoch  50/50 | Train Loss: 0.4339 | Val Loss: 0.4698 | Train Spearman: 0.5720 | Val Spearman: 0.6205 | Time: 26.17s
#
# Training completed in 1036.42s
# Best validation Spearman correlation: 0.6205
#   → Search progress saved to Outputs/CNN_search_results.json
#
# ============================================================
# Best CNN configuration: {'learning_rate': 0.001, 'hidden_dim': 256, 'dropout': 0.3}
# Best validation Spearman: 0.6658
# Best model saved to Outputs/best_cnn_model.pth
# ============================================================

# %%
# 8.2 Train and Search LSTM
print("---- Tuning LSTM ----")
best_lstm_config, lstm_history = hyperparameter_search(
    RNABindingLSTM, 'LSTM', param_grid, train_loader, val_loader, device, epochs=50
)
# Out:
# ---- Tuning LSTM ----
# Starting Hyperparameter Search for LSTM with 12 configurations...
#
# Running experiment 1/12: {'learning_rate': 0.001, 'hidden_dim': 128, 'dropout': 0.3}
#
# ============================================================
# Training LSTM_exp0
# ============================================================
#   → Saved new best model (Spearman: 0.4778)
# Epoch   1/50 | Train Loss: 0.8795 | Val Loss: 0.6444 | Train Spearman: 0.3200 | Val Spearman: 0.4778 | Time: 28.15s
#   → Saved new best model (Spearman: 0.5250)
#   → Saved new best model (Spearman: 0.5390)
#   → Saved new best model (Spearman: 0.5772)

# %% [markdown]
# ## 9. Test Evaluation

# %%
# Load best CNN model
cnn_model = RNABindingCNN(
    hidden_dim=best_cnn_config['hidden_dim'], 
    dropout=best_cnn_config['dropout']
).to(device)
cnn_model.load_state_dict(torch.load(f'{OUTPUT_DIR}/best_cnn_model.pth'))

# Evaluate CNN on test set
cnn_test_loss, cnn_test_corr = evaluate(cnn_model, test_loader, device)
print(f"\nBest CNN Test Results:")
print(f"  Test Loss: {cnn_test_loss:.4f}")
print(f"  Test Spearman Correlation: {cnn_test_corr:.4f}")

# %%
# Load best LSTM model
lstm_model = RNABindingLSTM(
    hidden_dim=best_lstm_config['hidden_dim'], 
    dropout=best_lstm_config['dropout']
).to(device)
lstm_model.load_state_dict(torch.load(f'{OUTPUT_DIR}/best_lstm_model.pth'))

# Evaluate LSTM on test set
lstm_test_loss, lstm_test_corr = evaluate(lstm_model, test_loader, device)
print(f"\nBest LSTM Test Results:")
print(f"  Test Loss: {lstm_test_loss:.4f}")
print(f"  Test Spearman Correlation: {lstm_test_corr:.4f}")

# %% [markdown]
# ## 10. Plotting Results and Saving History
#
# Saving plots and full experiment history to JSON for reproducibility.

# %%
import json

def save_and_plot_results(cnn_hist, lstm_hist, cnn_config, lstm_config, cnn_test_res, lstm_test_res):
    # Unpack test results
    cnn_test_loss, cnn_test_corr = cnn_test_res
    lstm_test_loss, lstm_test_corr = lstm_test_res
    
    # 1. Prepare Data for JSON Storage
    experiment_data = {
        "CNN": {
            "parameters": cnn_config,
            "training_time_seconds": cnn_hist['training_time'],
            "best_val_accuracy": cnn_hist['best_val_corr'],
            "best_val_epoch": int(np.argmax(cnn_hist['val_correlations']) + 1),
            "test_loss": cnn_test_loss,
            "test_accuracy": cnn_test_corr,
            "history": {
                "train_losses": cnn_hist['train_losses'],
                "train_correlations": cnn_hist['train_correlations'],
                "val_losses": cnn_hist['val_losses'],
                "val_correlations": cnn_hist['val_correlations']
            }
        },
        "LSTM": {
            "parameters": lstm_config,
            "training_time_seconds": lstm_hist['training_time'],
            "best_val_accuracy": lstm_hist['best_val_corr'],
            "best_val_epoch": int(np.argmax(lstm_hist['val_correlations']) + 1),
            "test_loss": lstm_test_loss,
            "test_accuracy": lstm_test_corr,
            "history": {
                "train_losses": lstm_hist['train_losses'],
                "train_correlations": lstm_hist['train_correlations'],
                "val_losses": lstm_hist['val_losses'],
                "val_correlations": lstm_hist['val_correlations']
            }
        }
    }

    # Save to JSON
    json_path = f'{OUTPUT_DIR}/complete_experiment_data.json'
    with open(json_path, 'w') as f:
        json.dump(experiment_data, f, indent=4)
    print(f"Complete experiment data saved to '{json_path}'")

    # 2. Plotting
    epochs_cnn = range(1, len(cnn_hist['train_losses']) + 1)
    epochs_lstm = range(1, len(lstm_hist['train_losses']) + 1)

    # --- Plot 1: Loss ---
    plt.figure(figsize=(10, 6))
    plt.plot(epochs_cnn, cnn_hist['train_losses'], label='CNN Train Loss', color='blue', linestyle='--')
    plt.plot(epochs_cnn, cnn_hist['val_losses'], label='CNN Val Loss', color='blue')
    plt.plot(epochs_lstm, lstm_hist['train_losses'], label='LSTM Train Loss', color='red', linestyle='--')
    plt.plot(epochs_lstm, lstm_hist['val_losses'], label='LSTM Val Loss', color='red')
    plt.xlabel('Epochs')
    plt.ylabel('Loss (MSE)')
    plt.title('Training and Validation Loss')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.savefig(f'{OUTPUT_DIR}/loss_plot.png')
    plt.close()

    # --- Plot 2: Accuracy (Spearman Correlation) ---
    plt.figure(figsize=(10, 6))
    plt.plot(epochs_cnn, cnn_hist['train_correlations'], label='CNN Train Spearman', color='blue', linestyle='--')
    plt.plot(epochs_cnn, cnn_hist['val_correlations'], label='CNN Val Spearman', color='blue')
    plt.plot(epochs_lstm, lstm_hist['train_correlations'], label='LSTM Train Spearman', color='red', linestyle='--')
    plt.plot(epochs_lstm, lstm_hist['val_correlations'], label='LSTM Val Spearman', color='red')
    plt.xlabel('Epochs')
    plt.ylabel('Spearman Correlation')
    plt.title('Training and Validation Spearman Correlation')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.savefig(f'{OUTPUT_DIR}/accuracy_plot.png')
    plt.close()
    
    print("Plots saved to 'loss_plot.png' and 'accuracy_plot.png'.")

# Execute
save_and_plot_results(
    cnn_history, lstm_history, 
    best_cnn_config, best_lstm_config, 
    (cnn_test_loss, cnn_test_corr), 
    (lstm_test_loss, lstm_test_corr)
)
