# %% [markdown]
# # Deep Learning Homework 2 - Question 2.1
# ## RNA Binding Protein (RBP) Interaction Prediction

# %% [markdown]
# ## 1. Setup and Imports

# %%
# Install required packages
# !pip install openpyxl -q

# %%
import os
import random
import time
import itertools
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from typing import List, Tuple

# Create Output Directory
OUTPUT_DIR = 'Outputs_t2'
os.makedirs(OUTPUT_DIR, exist_ok=True)

# Check device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# Using device: cuda
# GPU: NVIDIA GeForce RTX 4060 Laptop GPU

# %% [markdown]
# ## 2. Download Data
#
# Download the data files from the Google Drive link provided in the homework:
# - `norm_data.txt`
# - `metadata.xlsx`
#
# Upload them to Colab or mount your Google Drive.

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
# Set the path to your data files
DATA_DIR = 'data'  # Change this to your folder path

# %% [markdown]
# ## 3. Configuration and Utility Functions

# %%
from config import RNAConfig

# %%
from utils import configure_seed, masked_mse_loss, masked_spearman_correlation

configure_seed(42)

# %% [markdown]
# ## 4. Data Loader

# %%
from utils import RNACompeteLoader, load_rnacompete_data

# %% [markdown]
# ## 5. Model Definitions
#
# ### 5.1 CNN Model

# %%
class RNABindingCNN(nn.Module):
    """
    1D Convolutional Neural Network for RNA sequence binding prediction.

    Architecture:
    - 3 convolutional layers with increasing channels (64 -> 128 -> 256)
    - Batch normalization after each conv layer
    - ReLU activation and dropout for regularization
    - Global max + average pooling for richer representation
    - 2 fully connected layers for regression output
    """

    def __init__(self, input_channels=4, seq_length=41, hidden_dim=128, dropout=0.3):
        super(RNABindingCNN, self).__init__()
        #L_out = ((L_in + 2P - K) / S)  + 1

        # Convolutional layers with different kernel sizes to capture various motif lengths
        # Padding choices allow to preserve input length through the feature maps
        #L_out = 41
        self.conv1 = nn.Conv1d(input_channels, 64, kernel_size=5, padding=2)
        self.bn1 = nn.BatchNorm1d(64)

        #L_out = 41
        self.conv2 = nn.Conv1d(64, 128, kernel_size=7, padding=3)
        self.bn2 = nn.BatchNorm1d(128)

        #L_out = 41
        self.conv3 = nn.Conv1d(128, 256, kernel_size=9, padding=4)
        self.bn3 = nn.BatchNorm1d(256)

        self.dropout = nn.Dropout(dropout)

        # Global pooling (both max and average)
        # allows to get the strongest value of a given feature for the sequence
        self.global_max_pool = nn.AdaptiveMaxPool1d(1)
        # allows to get the average of how much a feature is present throughout the sequence
        self.global_avg_pool = nn.AdaptiveAvgPool1d(1)

        # Fully connected layers
        self.fc1 = nn.Linear(256 * 2, hidden_dim)  # *2 for concat of max and avg pool
        self.fc2 = nn.Linear(hidden_dim, 1)
        self.relu = nn.ReLU()

    def forward(self, x):
        # Input x shape: (batch, seq_length, 4)
        # Conv1d expects: (batch, channels, seq_length)
        x = x.permute(0, 2, 1)

        # Convolutional blocks
        x = self.relu(self.bn1(self.conv1(x)))
        x = self.dropout(x)

        x = self.relu(self.bn2(self.conv2(x)))
        x = self.dropout(x)

        x = self.relu(self.bn3(self.conv3(x)))
        x = self.dropout(x)

        # Global pooling
        max_pool = self.global_max_pool(x).squeeze(-1)
        avg_pool = self.global_avg_pool(x).squeeze(-1)
        x = torch.cat([max_pool, avg_pool], dim=1)

        # Fully connected layers
        x = self.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.fc2(x)

        return x

# %% [markdown]
# ### 5.2 LSTM Model

# %%
class RNABindingLSTM(nn.Module):
    """
    Bidirectional LSTM for RNA sequence binding prediction.

    Architecture:
    - 2-layer bidirectional LSTM
    - Batch normalization
    - Dropout for regularization
    - 2 fully connected layers for regression
    """

    def __init__(self, input_dim=4, hidden_dim=128, num_layers=2, dropout=0.3, bidirectional=True):
        super(RNABindingLSTM, self).__init__()

        self.hidden_dim = hidden_dim
        self.num_layers = num_layers
        self.bidirectional = bidirectional
        self.num_directions = 2 if bidirectional else 1

        self.lstm = nn.LSTM(
            input_size=input_dim,
            hidden_size=hidden_dim,
            num_layers=num_layers,
            batch_first=True,
            dropout=dropout if num_layers > 1 else 0,
            bidirectional=bidirectional
        )

        self.bn = nn.BatchNorm1d(hidden_dim * self.num_directions)
        self.dropout = nn.Dropout(dropout)

        self.fc1 = nn.Linear(hidden_dim * self.num_directions, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, 1)
        self.relu = nn.ReLU()

    def forward(self, x):
        # Input x shape: (batch, seq_length, 4)
        lstm_out, (hidden, cell) = self.lstm(x)

        if self.bidirectional:
            # Concatenate last hidden states from forward and backward
            hidden_forward = hidden[-2, :, :]
            hidden_backward = hidden[-1, :, :]
            combined = torch.cat([hidden_forward, hidden_backward], dim=1)
        else:
            combined = hidden[-1, :, :]

        combined = self.bn(combined)
        combined = self.dropout(combined)

        x = self.relu(self.fc1(combined))
        x = self.dropout(x)
        x = self.fc2(x)

        return x

# %% [markdown]
# ## 6. Training and Evaluation Functions

# %%
def train_epoch(model, train_loader, optimizer, device):
    """Train for one epoch and return loss and correlation."""
    model.train()
    total_loss = 0.0
    num_batches = 0
    
    all_preds = []
    all_targets = []
    all_masks = []

    for batch in train_loader:
        x, y, mask = batch
        x, y, mask = x.to(device), y.to(device), mask.to(device)

        optimizer.zero_grad()
        predictions = model(x)
        loss = masked_mse_loss(predictions, y, mask)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()

        total_loss += loss.item()
        num_batches += 1
        
        # Collect for metric calculation
        all_preds.append(predictions.detach().cpu())
        all_targets.append(y.detach().cpu())
        all_masks.append(mask.detach().cpu())

    all_preds = torch.cat(all_preds, dim=0)
    all_targets = torch.cat(all_targets, dim=0)
    all_masks = torch.cat(all_masks, dim=0)
    
    spearman_corr = masked_spearman_correlation(all_preds, all_targets, all_masks)

    return total_loss / num_batches, spearman_corr.item()


def evaluate(model, data_loader, device):
    """Evaluate model and return loss and Spearman correlation."""
    model.eval()
    total_loss = 0.0
    num_batches = 0

    all_preds = []
    all_targets = []
    all_masks = []

    with torch.no_grad():
        for batch in data_loader:
            x, y, mask = batch
            x, y, mask = x.to(device), y.to(device), mask.to(device)

            predictions = model(x)
            loss = masked_mse_loss(predictions, y, mask)

            total_loss += loss.item()
            num_batches += 1

            all_preds.append(predictions.cpu())
            all_targets.append(y.cpu())
            all_masks.append(mask.cpu())

    all_preds = torch.cat(all_preds, dim=0)
    all_targets = torch.cat(all_targets, dim=0)
    all_masks = torch.cat(all_masks, dim=0)

    spearman_corr = masked_spearman_correlation(all_preds, all_targets, all_masks)

    return total_loss / num_batches, spearman_corr.item()


def train_model(model, train_loader, val_loader, optimizer, scheduler, device,
                num_epochs, model_name, patience=15, save_every=10):
    """Full training loop with early stopping and periodic checkpoints."""
    print(f"\n{'='*60}")
    print(f"Training {model_name}")
    print(f"{'='*60}")

    train_losses = []
    train_correlations = []
    val_losses = []
    val_correlations = []

    best_val_corr = -float('inf')
    best_model_state = None
    epochs_without_improvement = 0

    start_time = time.time()

    for epoch in range(num_epochs):
        epoch_start = time.time()

        train_loss, train_corr = train_epoch(model, train_loader, optimizer, device)
        val_loss, val_corr = evaluate(model, val_loader, device)

        if scheduler is not None:
            scheduler.step(val_corr)

        train_losses.append(train_loss)
        train_correlations.append(train_corr)
        val_losses.append(val_loss)
        val_correlations.append(val_corr)

        if val_corr > best_val_corr:
            best_val_corr = val_corr
            best_model_state = {k: v.cpu().clone() for k, v in model.state_dict().items()}
            epochs_without_improvement = 0
            # Save best model to Output directory
            torch.save(best_model_state, f'{OUTPUT_DIR}/{model_name}_best_t2.pth')
            print(f"  → Saved new best model (Spearman: {val_corr:.4f})")
        else:
            epochs_without_improvement += 1

        epoch_time = time.time() - epoch_start

        if (epoch + 1) % 5 == 0 or epoch == 0:
            print(f"Epoch {epoch+1:3d}/{num_epochs} | "
                  f"Train Loss: {train_loss:.4f} | "
                  f"Val Loss: {val_loss:.4f} | "
                  f"Train Spearman: {train_corr:.4f} | "
                  f"Val Spearman: {val_corr:.4f} | "
                  f"Time: {epoch_time:.2f}s")

        # Periodic checkpoint every N epochs
        if (epoch + 1) % save_every == 0:
            checkpoint = {
                'epoch': epoch + 1,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'train_losses': train_losses,
                'train_correlations': train_correlations,
                'val_losses': val_losses,
                'val_correlations': val_correlations,
                'best_val_corr': best_val_corr
            }
            torch.save(checkpoint, f'{OUTPUT_DIR}/{model_name}_checkpoint_epoch{epoch+1}_t2.pth')
            print(f"  → Checkpoint saved at epoch {epoch+1}")

        if epochs_without_improvement >= patience:
            print(f"\nEarly stopping at epoch {epoch+1}")
            break

    total_time = time.time() - start_time

    if best_model_state is not None:
        model.load_state_dict(best_model_state)

    print(f"\nTraining completed in {total_time:.2f}s")
    print(f"Best validation Spearman correlation: {best_val_corr:.4f}")

    return {
        'train_losses': train_losses,
        'train_correlations': train_correlations,
        'val_losses': val_losses,
        'val_correlations': val_correlations,
        'best_val_corr': best_val_corr,
        'training_time': total_time
    }

# %% [markdown]
# ## 7. Load Data

# %%
PROTEIN_NAME = 'RBFOX1'
BATCH_SIZE = 64

# Load data
print(f"Loading data for protein: {PROTEIN_NAME}")
config = RNAConfig()

train_dataset = load_rnacompete_data(PROTEIN_NAME, split='train', config=config)
val_dataset = load_rnacompete_data(PROTEIN_NAME, split='val', config=config)
test_dataset = load_rnacompete_data(PROTEIN_NAME, split='test', config=config)

print(f"\nDataset sizes:")
print(f"  Train: {len(train_dataset)}")
print(f"  Val: {len(val_dataset)}")
print(f"  Test: {len(test_dataset)}")

# Create data loaders
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)
# Out:
# Loading data for protein: RBFOX1
# Found cached data for RBFOX1 (train). Loading from data/RBFOX1_train_data.pt...
# Found cached data for RBFOX1 (val). Loading from data/RBFOX1_val_data.pt...
# Found cached data for RBFOX1 (test). Loading from data/RBFOX1_test_data.pt...
#
# Dataset sizes:
#   Train: 96261
#   Val: 24065
#   Test: 121031

# %% [markdown]
# ## 8. Hyperparameter Search and Training
#
# Here we define the search space and a function to iterate through hyperparameters, training the model for each combination.

# %%
# --- ROBUST GRID SEARCH (12 Combinations) ---
# for train_model with patience 7, and scheduler patience 5
# POSSIBLE HYPERPARAMETER TO ADD- SHCEDULER PATIENCE, INFLUENCES HOW LR CHANGES
cnn_param_grid = {
    'learning_rate': [0.001, 0.003, 0.005],
    'hidden_dim': [256, 512],   # 256 was better than 128, so we test 512
    'dropout': [0.2, 0.3]       # Lower dropout preferred for CNNs
}

lstm_param_grid = {
    'learning_rate': [0.0003, 0.0005, 0.0007],
    'hidden_dim': [256, 512],   # Larger LSTMs often capture complex motifs better
    'dropout': [0.3, 0.4]       # Standard regularization for LSTMs
}

#simply fast grid to test if code runs well
# param_grid = {
#     # Covers best LSTM (0.001), best CNN (0.0001) and midpoint (0.0005)
#     'learning_rate': [0.0001],
#     # Tests if doubling capacity improves results
#     'hidden_dim': [2],
#     # Standard regularization vs Stronger regularization (for larger models)
#     'dropout': [0.8]
# }

def hyperparameter_search(model_class, model_name, param_grid, train_loader, val_loader, device, epochs=50):
    keys, values = zip(*param_grid.items())
    experiments = [dict(zip(keys, v)) for v in itertools.product(*values)]
    
    best_val_corr = -float('inf')
    best_config = None
    best_history = None
    
    print(f"Starting Hyperparameter Search for {model_name} with {len(experiments)} configurations...")
    
    results = []
    # Define a path for the intermediate results
    results_path = f'{OUTPUT_DIR}/{model_name}_search_results_t2.json'
    
    for i, config in enumerate(experiments):
        print(f"\nRunning experiment {i+1}/{len(experiments)}: {config}")
        
        configure_seed(42)
        
        # Initialize model with current config
        # Note: LSTM and CNN have slightly different init signatures if not careful,
        # but here we matched the param names in the grid to the init args
        if model_name == 'LSTM':
             model = model_class(
                hidden_dim=config['hidden_dim'],
                dropout=config['dropout']
            ).to(device)
        else:
             model = model_class(
                hidden_dim=config['hidden_dim'],
                dropout=config['dropout']
            ).to(device)
            
        optimizer = optim.Adam(model.parameters(), lr=config['learning_rate'], weight_decay=1e-5)
        scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', factor=0.5, patience=5)
        
        # Train - using fewer epochs for search to save time (can increase for final result)
        # We use a unique name for temporary checkpoints
        temp_name = f"{model_name}_exp{i}"
        history = train_model(
            model, train_loader, val_loader, optimizer, scheduler,
            device, num_epochs=epochs, model_name=temp_name, patience=7, save_every=100
        )
        
        # --- SAVE PROGRESS IMMEDIATELY ---
        run_result = {
            'experiment_index': i,
            'config': config,
            'best_val_corr': history['best_val_corr'],
            'training_time': history['training_time'],
            'history': history # Full history included for plotting/resuming
        }
        results.append(run_result)
        
        try:
            with open(results_path, 'w') as f:
                json.dump(results, f, indent=4)
            print(f"  → Search progress saved to {results_path}")
        except Exception as e:
            print(f"  → Warning: Could not save progress to JSON: {e}")

        if history['best_val_corr'] > best_val_corr:
            best_val_corr = history['best_val_corr']
            best_config = config
            best_history = history
            
            # Save the best model of the search as the final best model
            # We load the best state from the temp file and save it to the final destination
            best_state = torch.load(f'{OUTPUT_DIR}/{temp_name}_best_t2.pth')
            torch.save(best_state, f'{OUTPUT_DIR}/best_{model_name.lower()}_model_t2.pth')
            
    print(f"\n{'='*60}")
    print(f"Best {model_name} configuration: {best_config}")
    print(f"Best validation Spearman: {best_val_corr:.4f}")
    print(f"Best model saved to {OUTPUT_DIR}/best_{model_name.lower()}_model_t2.pth")
    print(f"{'='*60}")
    
    return best_config, best_history

# %%
# 8.1 Train and Search CNN
print("---- Tuning CNN ----")
best_cnn_config, cnn_history = hyperparameter_search(
    RNABindingCNN, 'CNN', cnn_param_grid, train_loader, val_loader, device, epochs=50
)
# Out:
# ---- Tuning CNN ----
# Starting Hyperparameter Search for CNN with 12 configurations...
#
# Running experiment 1/12: {'learning_rate': 0.001, 'hidden_dim': 256, 'dropout': 0.2}
#
# ============================================================
# Training CNN_exp0
# ============================================================
#   → Saved new best model (Spearman: 0.5495)
# Epoch   1/50 | Train Loss: 0.5823 | Val Loss: 0.4674 | Train Spearman: 0.4707 | Val Spearman: 0.5495 | Time: 15.72s
#   → Saved new best model (Spearman: 0.5882)
#   → Saved new best model (Spearman: 0.6087)
#   → Saved new best model (Spearman: 0.6213)
#   → Saved new best model (Spearman: 0.6330)
# Epoch   5/50 | Train Loss: 0.4184 | Val Loss: 0.4232 | Train Spearman: 0.5840 | Val Spearman: 0.6330 | Time: 14.93s
#   → Saved new best model (Spearman: 0.6341)
#   → Saved new best model (Spearman: 0.6434)
#   → Saved new best model (Spearman: 0.6452)
#   → Saved new best model (Spearman: 0.6499)
# Epoch  10/50 | Train Loss: 0.3877 | Val Loss: 0.3572 | Train Spearman: 0.6117 | Val Spearman: 0.6499 | Time: 18.28s
#   → Saved new best model (Spearman: 0.6505)
#   → Saved new best model (Spearman: 0.6546)
# Epoch  15/50 | Train Loss: 0.3660 | Val Loss: 0.3616 | Train Spearman: 0.6240 | Val Spearman: 0.6539 | Time: 16.81s
#   → Saved new best model (Spearman: 0.6549)
#   → Saved new best model (Spearman: 0.6577)
#   → Saved new best model (Spearman: 0.6585)
# Epoch  20/50 | Train Loss: 0.3523 | Val Loss: 0.3412 | Train Spearman: 0.6289 | Val Spearman: 0.6585 | Time: 11.79s
#   → Saved new best model (Spearman: 0.6588)
#   → Saved new best model (Spearman: 0.6617)
# Epoch  25/50 | Train Loss: 0.3350 | Val Loss: 0.3634 | Train Spearman: 0.6370 | Val Spearman: 0.6617 | Time: 18.37s
# Epoch  30/50 | Train Loss: 0.3249 | Val Loss: 0.3471 | Train Spearman: 0.6410 | Val Spearman: 0.6605 | Time: 17.25s
#   → Saved new best model (Spearman: 0.6626)
#   → Saved new best model (Spearman: 0.6655)
# Epoch  35/50 | Train Loss: 0.2894 | Val Loss: 0.3403 | Train Spearman: 0.6617 | Val Spearman: 0.6646 | Time: 17.48s
#   → Saved new best model (Spearman: 0.6657)
#   → Saved new best model (Spearman: 0.6670)
# Epoch  40/50 | Train Loss: 0.2801 | Val Loss: 0.3401 | Train Spearman: 0.6656 | Val Spearman: 0.6670 | Time: 18.89s
#   → Saved new best model (Spearman: 0.6671)
# Epoch  45/50 | Train Loss: 0.2709 | Val Loss: 0.3461 | Train Spearman: 0.6710 | Val Spearman: 0.6663 | Time: 17.52s
#   → Saved new best model (Spearman: 0.6680)
#   → Saved new best model (Spearman: 0.6685)
# Epoch  50/50 | Train Loss: 0.2635 | Val Loss: 0.3326 | Train Spearman: 0.6745 | Val Spearman: 0.6666 | Time: 17.10s
#
# Training completed in 847.67s
# Best validation Spearman correlation: 0.6685
#   → Search progress saved to Outputs_t2/CNN_search_results_t2.json
#
# Running experiment 2/12: {'learning_rate': 0.001, 'hidden_dim': 256, 'dropout': 0.3}
#
# ============================================================
# Training CNN_exp1
# ============================================================
#   → Saved new best model (Spearman: 0.5484)
# Epoch   1/50 | Train Loss: 0.6328 | Val Loss: 0.5268 | Train Spearman: 0.4396 | Val Spearman: 0.5484 | Time: 18.71s
#   → Saved new best model (Spearman: 0.5775)
#   → Saved new best model (Spearman: 0.5957)
#   → Saved new best model (Spearman: 0.6095)
#   → Saved new best model (Spearman: 0.6175)
# Epoch   5/50 | Train Loss: 0.4668 | Val Loss: 0.4156 | Train Spearman: 0.5552 | Val Spearman: 0.6175 | Time: 17.41s
#   → Saved new best model (Spearman: 0.6217)
#   → Saved new best model (Spearman: 0.6277)
#   → Saved new best model (Spearman: 0.6306)
#   → Saved new best model (Spearman: 0.6328)
# Epoch  10/50 | Train Loss: 0.4340 | Val Loss: 0.4395 | Train Spearman: 0.5814 | Val Spearman: 0.6328 | Time: 18.69s
#   → Saved new best model (Spearman: 0.6349)
#   → Saved new best model (Spearman: 0.6391)
#   → Saved new best model (Spearman: 0.6417)
#   → Saved new best model (Spearman: 0.6418)
# Epoch  15/50 | Train Loss: 0.4203 | Val Loss: 0.4379 | Train Spearman: 0.5949 | Val Spearman: 0.6418 | Time: 20.59s
#   → Saved new best model (Spearman: 0.6426)
#   → Saved new best model (Spearman: 0.6434)
#   → Saved new best model (Spearman: 0.6449)
#   → Saved new best model (Spearman: 0.6449)
# Epoch  20/50 | Train Loss: 0.4047 | Val Loss: 0.3707 | Train Spearman: 0.5968 | Val Spearman: 0.6449 | Time: 19.43s
#   → Saved new best model (Spearman: 0.6455)
#   → Saved new best model (Spearman: 0.6547)
# Epoch  25/50 | Train Loss: 0.3910 | Val Loss: 0.3907 | Train Spearman: 0.6065 | Val Spearman: 0.6547 | Time: 18.72s
# Epoch  30/50 | Train Loss: 0.3858 | Val Loss: 0.3896 | Train Spearman: 0.6098 | Val Spearman: 0.6492 | Time: 18.40s
#   → Saved new best model (Spearman: 0.6559)
#   → Saved new best model (Spearman: 0.6572)
# Epoch  35/50 | Train Loss: 0.3785 | Val Loss: 0.3647 | Train Spearman: 0.6131 | Val Spearman: 0.6539 | Time: 16.89s
#   → Saved new best model (Spearman: 0.6620)
# Epoch  40/50 | Train Loss: 0.3466 | Val Loss: 0.3691 | Train Spearman: 0.6292 | Val Spearman: 0.6617 | Time: 19.72s
#   → Saved new best model (Spearman: 0.6650)
# Epoch  45/50 | Train Loss: 0.3401 | Val Loss: 0.3777 | Train Spearman: 0.6365 | Val Spearman: 0.6642 | Time: 20.43s
#   → Saved new best model (Spearman: 0.6656)
#   → Saved new best model (Spearman: 0.6658)
# Epoch  50/50 | Train Loss: 0.3339 | Val Loss: 0.3475 | Train Spearman: 0.6386 | Val Spearman: 0.6640 | Time: 18.54s
#
# Training completed in 905.23s
# Best validation Spearman correlation: 0.6658
#   → Search progress saved to Outputs_t2/CNN_search_results_t2.json
#
# Running experiment 3/12: {'learning_rate': 0.001, 'hidden_dim': 512, 'dropout': 0.2}
#
# ============================================================
# Training CNN_exp2
# ============================================================
#   → Saved new best model (Spearman: 0.5578)
# Epoch   1/50 | Train Loss: 0.5934 | Val Loss: 0.4694 | Train Spearman: 0.4638 | Val Spearman: 0.5578 | Time: 17.76s
#   → Saved new best model (Spearman: 0.5911)
#   → Saved new best model (Spearman: 0.6139)
#   → Saved new best model (Spearman: 0.6201)
#   → Saved new best model (Spearman: 0.6288)
# Epoch   5/50 | Train Loss: 0.4166 | Val Loss: 0.4130 | Train Spearman: 0.5855 | Val Spearman: 0.6288 | Time: 18.12s
#   → Saved new best model (Spearman: 0.6323)
#   → Saved new best model (Spearman: 0.6415)
#   → Saved new best model (Spearman: 0.6448)
#   → Saved new best model (Spearman: 0.6494)
# Epoch  10/50 | Train Loss: 0.3781 | Val Loss: 0.3577 | Train Spearman: 0.6121 | Val Spearman: 0.6494 | Time: 18.95s
#   → Saved new best model (Spearman: 0.6501)
#   → Saved new best model (Spearman: 0.6503)
#   → Saved new best model (Spearman: 0.6514)
# Epoch  15/50 | Train Loss: 0.3570 | Val Loss: 0.3550 | Train Spearman: 0.6240 | Val Spearman: 0.6514 | Time: 19.34s
#   → Saved new best model (Spearman: 0.6523)
#   → Saved new best model (Spearman: 0.6554)
#   → Saved new best model (Spearman: 0.6568)
# Epoch  20/50 | Train Loss: 0.3457 | Val Loss: 0.3538 | Train Spearman: 0.6330 | Val Spearman: 0.6568 | Time: 17.33s
#   → Saved new best model (Spearman: 0.6594)
#   → Saved new best model (Spearman: 0.6602)
# Epoch  25/50 | Train Loss: 0.3285 | Val Loss: 0.3424 | Train Spearman: 0.6390 | Val Spearman: 0.6595 | Time: 17.42s
# Epoch  30/50 | Train Loss: 0.3216 | Val Loss: 0.3342 | Train Spearman: 0.6437 | Val Spearman: 0.6601 | Time: 17.86s
#   → Saved new best model (Spearman: 0.6671)
#   → Saved new best model (Spearman: 0.6686)
# Epoch  35/50 | Train Loss: 0.2843 | Val Loss: 0.3638 | Train Spearman: 0.6646 | Val Spearman: 0.6633 | Time: 18.79s
#   → Saved new best model (Spearman: 0.6686)
#   → Saved new best model (Spearman: 0.6692)
# Epoch  40/50 | Train Loss: 0.2764 | Val Loss: 0.3258 | Train Spearman: 0.6687 | Val Spearman: 0.6687 | Time: 19.09s
# Epoch  45/50 | Train Loss: 0.2652 | Val Loss: 0.3375 | Train Spearman: 0.6764 | Val Spearman: 0.6676 | Time: 16.85s
#
# Early stopping at epoch 46
#
# Training completed in 834.53s
# Best validation Spearman correlation: 0.6692
#   → Search progress saved to Outputs_t2/CNN_search_results_t2.json
#
# Running experiment 4/12: {'learning_rate': 0.001, 'hidden_dim': 512, 'dropout': 0.3}
#
# ============================================================
# Training CNN_exp3
# ============================================================
#   → Saved new best model (Spearman: 0.5554)
# Epoch   1/50 | Train Loss: 0.6611 | Val Loss: 0.4994 | Train Spearman: 0.4385 | Val Spearman: 0.5554 | Time: 18.55s
#   → Saved new best model (Spearman: 0.5767)
#   → Saved new best model (Spearman: 0.5932)
#   → Saved new best model (Spearman: 0.6032)
#   → Saved new best model (Spearman: 0.6160)
# Epoch   5/50 | Train Loss: 0.4540 | Val Loss: 0.4078 | Train Spearman: 0.5598 | Val Spearman: 0.6160 | Time: 17.92s
#   → Saved new best model (Spearman: 0.6164)
#   → Saved new best model (Spearman: 0.6273)
#   → Saved new best model (Spearman: 0.6314)
#   → Saved new best model (Spearman: 0.6364)
# Epoch  10/50 | Train Loss: 0.4220 | Val Loss: 0.3890 | Train Spearman: 0.5860 | Val Spearman: 0.6364 | Time: 17.49s
#   → Saved new best model (Spearman: 0.6401)
#   → Saved new best model (Spearman: 0.6435)
#   → Saved new best model (Spearman: 0.6442)
# Epoch  15/50 | Train Loss: 0.4041 | Val Loss: 0.3900 | Train Spearman: 0.6000 | Val Spearman: 0.6442 | Time: 18.69s
#   → Saved new best model (Spearman: 0.6467)
#   → Saved new best model (Spearman: 0.6505)
# Epoch  20/50 | Train Loss: 0.3918 | Val Loss: 0.3776 | Train Spearman: 0.6079 | Val Spearman: 0.6471 | Time: 18.40s
#   → Saved new best model (Spearman: 0.6513)
#   → Saved new best model (Spearman: 0.6549)
# Epoch  25/50 | Train Loss: 0.3830 | Val Loss: 0.3596 | Train Spearman: 0.6117 | Val Spearman: 0.6502 | Time: 18.17s
#   → Saved new best model (Spearman: 0.6608)
# Epoch  30/50 | Train Loss: 0.3565 | Val Loss: 0.3620 | Train Spearman: 0.6273 | Val Spearman: 0.6608 | Time: 18.90s
#   → Saved new best model (Spearman: 0.6618)
#   → Saved new best model (Spearman: 0.6619)
#   → Saved new best model (Spearman: 0.6635)
# Epoch  35/50 | Train Loss: 0.3441 | Val Loss: 0.3720 | Train Spearman: 0.6319 | Val Spearman: 0.6617 | Time: 17.73s
#   → Saved new best model (Spearman: 0.6647)
# Epoch  40/50 | Train Loss: 0.3269 | Val Loss: 0.3580 | Train Spearman: 0.6381 | Val Spearman: 0.6633 | Time: 17.46s
#   → Saved new best model (Spearman: 0.6680)
# Epoch  45/50 | Train Loss: 0.3090 | Val Loss: 0.3467 | Train Spearman: 0.6515 | Val Spearman: 0.6647 | Time: 17.14s
#   → Saved new best model (Spearman: 0.6686)
#   → Saved new best model (Spearman: 0.6687)
#   → Saved new best model (Spearman: 0.6700)
# Epoch  50/50 | Train Loss: 0.3020 | Val Loss: 0.3563 | Train Spearman: 0.6513 | Val Spearman: 0.6700 | Time: 18.03s
#
# Training completed in 908.25s
# Best validation Spearman correlation: 0.6700
#   → Search progress saved to Outputs_t2/CNN_search_results_t2.json
#
# Running experiment 5/12: {'learning_rate': 0.003, 'hidden_dim': 256, 'dropout': 0.2}
#
# ============================================================
# Training CNN_exp4
# ============================================================
#   → Saved new best model (Spearman: 0.5456)
# Epoch   1/50 | Train Loss: 0.6562 | Val Loss: 0.4849 | Train Spearman: 0.4529 | Val Spearman: 0.5456 | Time: 16.89s
#   → Saved new best model (Spearman: 0.5778)
#   → Saved new best model (Spearman: 0.6028)
#   → Saved new best model (Spearman: 0.6107)
# Epoch   5/50 | Train Loss: 0.4774 | Val Loss: 0.4386 | Train Spearman: 0.5548 | Val Spearman: 0.6107 | Time: 18.09s
#   → Saved new best model (Spearman: 0.6158)
#   → Saved new best model (Spearman: 0.6245)
#   → Saved new best model (Spearman: 0.6355)
#   → Saved new best model (Spearman: 0.6367)
# Epoch  10/50 | Train Loss: 0.4287 | Val Loss: 0.3677 | Train Spearman: 0.5914 | Val Spearman: 0.6367 | Time: 17.34s
#   → Saved new best model (Spearman: 0.6434)
#   → Saved new best model (Spearman: 0.6481)
#   → Saved new best model (Spearman: 0.6493)
# Epoch  15/50 | Train Loss: 0.3992 | Val Loss: 0.4197 | Train Spearman: 0.6052 | Val Spearman: 0.6493 | Time: 17.57s
#   → Saved new best model (Spearman: 0.6513)
# Epoch  20/50 | Train Loss: 0.3831 | Val Loss: 0.3600 | Train Spearman: 0.6108 | Val Spearman: 0.6449 | Time: 17.03s
#   → Saved new best model (Spearman: 0.6517)
#   → Saved new best model (Spearman: 0.6519)
#   → Saved new best model (Spearman: 0.6524)
#   → Saved new best model (Spearman: 0.6555)
# Epoch  25/50 | Train Loss: 0.3727 | Val Loss: 0.3697 | Train Spearman: 0.6178 | Val Spearman: 0.6555 | Time: 19.80s
# Epoch  30/50 | Train Loss: 0.3706 | Val Loss: 0.4335 | Train Spearman: 0.6198 | Val Spearman: 0.6483 | Time: 17.02s
#   → Saved new best model (Spearman: 0.6587)
#   → Saved new best model (Spearman: 0.6587)
#   → Saved new best model (Spearman: 0.6619)
# Epoch  35/50 | Train Loss: 0.3607 | Val Loss: 0.3588 | Train Spearman: 0.6225 | Val Spearman: 0.6619 | Time: 18.80s
# Epoch  40/50 | Train Loss: 0.3570 | Val Loss: 0.3334 | Train Spearman: 0.6228 | Val Spearman: 0.6601 | Time: 18.17s
#   → Saved new best model (Spearman: 0.6636)
# Epoch  45/50 | Train Loss: 0.3545 | Val Loss: 0.3663 | Train Spearman: 0.6234 | Val Spearman: 0.6597 | Time: 17.32s
#   → Saved new best model (Spearman: 0.6681)
#   → Saved new best model (Spearman: 0.6689)
# Epoch  50/50 | Train Loss: 0.3218 | Val Loss: 0.3267 | Train Spearman: 0.6393 | Val Spearman: 0.6689 | Time: 18.05s
#
# Training completed in 906.98s
# Best validation Spearman correlation: 0.6689
#   → Search progress saved to Outputs_t2/CNN_search_results_t2.json
#
# Running experiment 6/12: {'learning_rate': 0.003, 'hidden_dim': 256, 'dropout': 0.3}
#
# ============================================================
# Training CNN_exp5
# ============================================================
#   → Saved new best model (Spearman: 0.5303)
# Epoch   1/50 | Train Loss: 0.7171 | Val Loss: 0.5633 | Train Spearman: 0.4227 | Val Spearman: 0.5303 | Time: 19.24s
#   → Saved new best model (Spearman: 0.5446)
#   → Saved new best model (Spearman: 0.5748)
#   → Saved new best model (Spearman: 0.5902)
#   → Saved new best model (Spearman: 0.6013)
# Epoch   5/50 | Train Loss: 0.5123 | Val Loss: 0.4824 | Train Spearman: 0.5282 | Val Spearman: 0.6013 | Time: 17.16s
#   → Saved new best model (Spearman: 0.6048)
#   → Saved new best model (Spearman: 0.6158)
#   → Saved new best model (Spearman: 0.6175)
#   → Saved new best model (Spearman: 0.6252)
# Epoch  10/50 | Train Loss: 0.4563 | Val Loss: 0.4133 | Train Spearman: 0.5624 | Val Spearman: 0.6252 | Time: 17.70s
#   → Saved new best model (Spearman: 0.6272)
#   → Saved new best model (Spearman: 0.6338)
# Epoch  15/50 | Train Loss: 0.4381 | Val Loss: 0.4657 | Train Spearman: 0.5786 | Val Spearman: 0.6338 | Time: 17.23s
#   → Saved new best model (Spearman: 0.6356)
# Epoch  20/50 | Train Loss: 0.4190 | Val Loss: 0.4293 | Train Spearman: 0.5848 | Val Spearman: 0.6290 | Time: 17.42s
#   → Saved new best model (Spearman: 0.6398)
#   → Saved new best model (Spearman: 0.6453)
# Epoch  25/50 | Train Loss: 0.4123 | Val Loss: 0.4511 | Train Spearman: 0.5917 | Val Spearman: 0.6453 | Time: 17.91s
#   → Saved new best model (Spearman: 0.6454)
# Epoch  30/50 | Train Loss: 0.4022 | Val Loss: 0.4569 | Train Spearman: 0.5932 | Val Spearman: 0.6371 | Time: 18.79s
#   → Saved new best model (Spearman: 0.6534)
# Epoch  35/50 | Train Loss: 0.3729 | Val Loss: 0.3686 | Train Spearman: 0.6146 | Val Spearman: 0.6531 | Time: 19.46s
#   → Saved new best model (Spearman: 0.6547)
#   → Saved new best model (Spearman: 0.6568)
# Epoch  40/50 | Train Loss: 0.3613 | Val Loss: 0.3974 | Train Spearman: 0.6169 | Val Spearman: 0.6564 | Time: 18.81s
#   → Saved new best model (Spearman: 0.6582)
# Epoch  45/50 | Train Loss: 0.3551 | Val Loss: 0.3845 | Train Spearman: 0.6209 | Val Spearman: 0.6573 | Time: 19.09s
#   → Saved new best model (Spearman: 0.6608)
# Epoch  50/50 | Train Loss: 0.3512 | Val Loss: 0.3682 | Train Spearman: 0.6227 | Val Spearman: 0.6579 | Time: 19.19s
#
# Training completed in 907.32s
# Best validation Spearman correlation: 0.6608
#   → Search progress saved to Outputs_t2/CNN_search_results_t2.json
#
# Running experiment 7/12: {'learning_rate': 0.003, 'hidden_dim': 512, 'dropout': 0.2}
#
# ============================================================
# Training CNN_exp6
# ============================================================
#   → Saved new best model (Spearman: 0.5557)
# Epoch   1/50 | Train Loss: 0.8201 | Val Loss: 0.4782 | Train Spearman: 0.4408 | Val Spearman: 0.5557 | Time: 19.39s
#   → Saved new best model (Spearman: 0.5850)
#   → Saved new best model (Spearman: 0.6020)
#   → Saved new best model (Spearman: 0.6126)
# Epoch   5/50 | Train Loss: 0.4560 | Val Loss: 0.4384 | Train Spearman: 0.5632 | Val Spearman: 0.6101 | Time: 18.67s
#   → Saved new best model (Spearman: 0.6197)
#   → Saved new best model (Spearman: 0.6237)
#   → Saved new best model (Spearman: 0.6304)
#   → Saved new best model (Spearman: 0.6402)
# Epoch  10/50 | Train Loss: 0.4088 | Val Loss: 0.3681 | Train Spearman: 0.5925 | Val Spearman: 0.6402 | Time: 18.89s
#   → Saved new best model (Spearman: 0.6412)
#   → Saved new best model (Spearman: 0.6449)
#   → Saved new best model (Spearman: 0.6495)
# Epoch  15/50 | Train Loss: 0.3861 | Val Loss: 0.3717 | Train Spearman: 0.6061 | Val Spearman: 0.6495 | Time: 18.84s
#   → Saved new best model (Spearman: 0.6524)
#   → Saved new best model (Spearman: 0.6572)
# Epoch  20/50 | Train Loss: 0.3736 | Val Loss: 0.3607 | Train Spearman: 0.6163 | Val Spearman: 0.6443 | Time: 19.27s
# Epoch  25/50 | Train Loss: 0.3666 | Val Loss: 0.3850 | Train Spearman: 0.6188 | Val Spearman: 0.6459 | Time: 17.47s
#   → Saved new best model (Spearman: 0.6606)
#   → Saved new best model (Spearman: 0.6630)
# Epoch  30/50 | Train Loss: 0.3251 | Val Loss: 0.3480 | Train Spearman: 0.6388 | Val Spearman: 0.6604 | Time: 17.49s
#   → Saved new best model (Spearman: 0.6656)
#   → Saved new best model (Spearman: 0.6664)
# Epoch  35/50 | Train Loss: 0.3136 | Val Loss: 0.3568 | Train Spearman: 0.6424 | Val Spearman: 0.6627 | Time: 17.53s
#   → Saved new best model (Spearman: 0.6672)
#   → Saved new best model (Spearman: 0.6715)
# Epoch  40/50 | Train Loss: 0.2909 | Val Loss: 0.3360 | Train Spearman: 0.6549 | Val Spearman: 0.6715 | Time: 19.59s
#   → Saved new best model (Spearman: 0.6719)
# Epoch  45/50 | Train Loss: 0.2820 | Val Loss: 0.3338 | Train Spearman: 0.6595 | Val Spearman: 0.6702 | Time: 17.16s
#
# Early stopping at epoch 48
#
# Training completed in 887.20s
# Best validation Spearman correlation: 0.6719
#   → Search progress saved to Outputs_t2/CNN_search_results_t2.json
#
# Running experiment 8/12: {'learning_rate': 0.003, 'hidden_dim': 512, 'dropout': 0.3}
#
# ============================================================
# Training CNN_exp7
# ============================================================
#   → Saved new best model (Spearman: 0.5502)
# Epoch   1/50 | Train Loss: 0.8799 | Val Loss: 0.4969 | Train Spearman: 0.4153 | Val Spearman: 0.5502 | Time: 17.81s
#   → Saved new best model (Spearman: 0.5731)
#   → Saved new best model (Spearman: 0.5869)
#   → Saved new best model (Spearman: 0.6021)
#   → Saved new best model (Spearman: 0.6140)
# Epoch   5/50 | Train Loss: 0.4894 | Val Loss: 0.5043 | Train Spearman: 0.5410 | Val Spearman: 0.6140 | Time: 20.99s
#   → Saved new best model (Spearman: 0.6159)
#   → Saved new best model (Spearman: 0.6224)
#   → Saved new best model (Spearman: 0.6228)
#   → Saved new best model (Spearman: 0.6318)
# Epoch  10/50 | Train Loss: 0.4293 | Val Loss: 0.3883 | Train Spearman: 0.5811 | Val Spearman: 0.6318 | Time: 19.06s
#   → Saved new best model (Spearman: 0.6344)
#   → Saved new best model (Spearman: 0.6357)
#   → Saved new best model (Spearman: 0.6424)
# Epoch  15/50 | Train Loss: 0.4139 | Val Loss: 0.3940 | Train Spearman: 0.5911 | Val Spearman: 0.6300 | Time: 19.10s
#   → Saved new best model (Spearman: 0.6437)
#   → Saved new best model (Spearman: 0.6463)
# Epoch  20/50 | Train Loss: 0.4034 | Val Loss: 0.4290 | Train Spearman: 0.5963 | Val Spearman: 0.6347 | Time: 18.46s
#   → Saved new best model (Spearman: 0.6466)
# Epoch  25/50 | Train Loss: 0.4011 | Val Loss: 0.3987 | Train Spearman: 0.6012 | Val Spearman: 0.6466 | Time: 17.65s
# Epoch  30/50 | Train Loss: 0.3905 | Val Loss: 0.3894 | Train Spearman: 0.5997 | Val Spearman: 0.6449 | Time: 17.07s
#   → Saved new best model (Spearman: 0.6536)
#   → Saved new best model (Spearman: 0.6562)
#   → Saved new best model (Spearman: 0.6568)
# Epoch  35/50 | Train Loss: 0.3607 | Val Loss: 0.4127 | Train Spearman: 0.6203 | Val Spearman: 0.6563 | Time: 16.77s
#   → Saved new best model (Spearman: 0.6579)
#   → Saved new best model (Spearman: 0.6589)
#   → Saved new best model (Spearman: 0.6616)
# Epoch  40/50 | Train Loss: 0.3544 | Val Loss: 0.3520 | Train Spearman: 0.6245 | Val Spearman: 0.6616 | Time: 17.74s
# Epoch  45/50 | Train Loss: 0.3460 | Val Loss: 0.3764 | Train Spearman: 0.6292 | Val Spearman: 0.6573 | Time: 16.67s
#
# Early stopping at epoch 47
#
# Training completed in 854.34s
# Best validation Spearman correlation: 0.6616
#   → Search progress saved to Outputs_t2/CNN_search_results_t2.json
#
# Running experiment 9/12: {'learning_rate': 0.005, 'hidden_dim': 256, 'dropout': 0.2}
#
# ============================================================
# Training CNN_exp8
# ============================================================
#   → Saved new best model (Spearman: 0.5452)
# Epoch   1/50 | Train Loss: 0.7905 | Val Loss: 0.5218 | Train Spearman: 0.4312 | Val Spearman: 0.5452 | Time: 19.34s
#   → Saved new best model (Spearman: 0.5523)
#   → Saved new best model (Spearman: 0.5783)
#   → Saved new best model (Spearman: 0.5982)
#   → Saved new best model (Spearman: 0.6036)
# Epoch   5/50 | Train Loss: 0.4812 | Val Loss: 0.4680 | Train Spearman: 0.5447 | Val Spearman: 0.6036 | Time: 19.24s
#   → Saved new best model (Spearman: 0.6136)
#   → Saved new best model (Spearman: 0.6233)
# Epoch  10/50 | Train Loss: 0.4393 | Val Loss: 0.4165 | Train Spearman: 0.5773 | Val Spearman: 0.6210 | Time: 17.34s
#   → Saved new best model (Spearman: 0.6308)
#   → Saved new best model (Spearman: 0.6329)
# Epoch  15/50 | Train Loss: 0.4199 | Val Loss: 0.4751 | Train Spearman: 0.5888 | Val Spearman: 0.6324 | Time: 17.48s
#   → Saved new best model (Spearman: 0.6388)
# Epoch  20/50 | Train Loss: 0.4035 | Val Loss: 0.3827 | Train Spearman: 0.5912 | Val Spearman: 0.6362 | Time: 17.39s
#   → Saved new best model (Spearman: 0.6397)
#   → Saved new best model (Spearman: 0.6399)
#   → Saved new best model (Spearman: 0.6416)
# Epoch  25/50 | Train Loss: 0.3980 | Val Loss: 0.3894 | Train Spearman: 0.5961 | Val Spearman: 0.6416 | Time: 17.26s
#   → Saved new best model (Spearman: 0.6450)
# Epoch  30/50 | Train Loss: 0.3964 | Val Loss: 0.3980 | Train Spearman: 0.5977 | Val Spearman: 0.6304 | Time: 17.13s
#   → Saved new best model (Spearman: 0.6455)
# Epoch  35/50 | Train Loss: 0.3918 | Val Loss: 0.3643 | Train Spearman: 0.6026 | Val Spearman: 0.6443 | Time: 18.81s
#   → Saved new best model (Spearman: 0.6529)
#   → Saved new best model (Spearman: 0.6543)
#   → Saved new best model (Spearman: 0.6550)
# Epoch  40/50 | Train Loss: 0.3602 | Val Loss: 0.3366 | Train Spearman: 0.6201 | Val Spearman: 0.6550 | Time: 18.69s
# Epoch  45/50 | Train Loss: 0.3533 | Val Loss: 0.3512 | Train Spearman: 0.6226 | Val Spearman: 0.6538 | Time: 17.99s
#   → Saved new best model (Spearman: 0.6596)
#   → Saved new best model (Spearman: 0.6606)
#   → Saved new best model (Spearman: 0.6620)
# Epoch  50/50 | Train Loss: 0.3260 | Val Loss: 0.3290 | Train Spearman: 0.6382 | Val Spearman: 0.6620 | Time: 18.73s
#
# Training completed in 900.33s
# Best validation Spearman correlation: 0.6620
#   → Search progress saved to Outputs_t2/CNN_search_results_t2.json
#
# Running experiment 10/12: {'learning_rate': 0.005, 'hidden_dim': 256, 'dropout': 0.3}
#
# ============================================================
# Training CNN_exp9
# ============================================================
#   → Saved new best model (Spearman: 0.5125)
# Epoch   1/50 | Train Loss: 0.8915 | Val Loss: 0.5405 | Train Spearman: 0.3744 | Val Spearman: 0.5125 | Time: 17.03s
#   → Saved new best model (Spearman: 0.5365)
#   → Saved new best model (Spearman: 0.5519)
#   → Saved new best model (Spearman: 0.5662)
#   → Saved new best model (Spearman: 0.5929)
# Epoch   5/50 | Train Loss: 0.5130 | Val Loss: 0.4988 | Train Spearman: 0.5192 | Val Spearman: 0.5929 | Time: 17.47s
#   → Saved new best model (Spearman: 0.5994)
#   → Saved new best model (Spearman: 0.6092)
#   → Saved new best model (Spearman: 0.6096)
#   → Saved new best model (Spearman: 0.6135)
# Epoch  10/50 | Train Loss: 0.4647 | Val Loss: 0.4310 | Train Spearman: 0.5567 | Val Spearman: 0.6135 | Time: 16.57s
#   → Saved new best model (Spearman: 0.6171)
#   → Saved new best model (Spearman: 0.6182)
#   → Saved new best model (Spearman: 0.6187)
#   → Saved new best model (Spearman: 0.6236)
# Epoch  15/50 | Train Loss: 0.4502 | Val Loss: 0.5074 | Train Spearman: 0.5694 | Val Spearman: 0.6236 | Time: 16.89s
#   → Saved new best model (Spearman: 0.6259)
# Epoch  20/50 | Train Loss: 0.4429 | Val Loss: 0.3992 | Train Spearman: 0.5710 | Val Spearman: 0.6248 | Time: 17.53s
#   → Saved new best model (Spearman: 0.6332)
#   → Saved new best model (Spearman: 0.6382)
#   → Saved new best model (Spearman: 0.6456)
# Epoch  25/50 | Train Loss: 0.4016 | Val Loss: 0.4386 | Train Spearman: 0.5965 | Val Spearman: 0.6456 | Time: 17.20s
# Epoch  30/50 | Train Loss: 0.3959 | Val Loss: 0.4165 | Train Spearman: 0.5986 | Val Spearman: 0.6354 | Time: 16.95s
#
# Early stopping at epoch 32
#
# Training completed in 569.18s
# Best validation Spearman correlation: 0.6456
#   → Search progress saved to Outputs_t2/CNN_search_results_t2.json
#
# Running experiment 11/12: {'learning_rate': 0.005, 'hidden_dim': 512, 'dropout': 0.2}
#
# ============================================================
# Training CNN_exp10
# ============================================================
#   → Saved new best model (Spearman: 0.5496)
# Epoch   1/50 | Train Loss: 1.2755 | Val Loss: 0.4769 | Train Spearman: 0.4258 | Val Spearman: 0.5496 | Time: 18.56s
#   → Saved new best model (Spearman: 0.5799)
#   → Saved new best model (Spearman: 0.6017)
#   → Saved new best model (Spearman: 0.6021)
#   → Saved new best model (Spearman: 0.6174)
# Epoch   5/50 | Train Loss: 0.4658 | Val Loss: 0.4295 | Train Spearman: 0.5549 | Val Spearman: 0.6174 | Time: 17.57s
#   → Saved new best model (Spearman: 0.6283)
#   → Saved new best model (Spearman: 0.6312)
#   → Saved new best model (Spearman: 0.6317)
# Epoch  10/50 | Train Loss: 0.4164 | Val Loss: 0.3739 | Train Spearman: 0.5868 | Val Spearman: 0.6317 | Time: 16.95s
#   → Saved new best model (Spearman: 0.6336)
# Epoch  15/50 | Train Loss: 0.4105 | Val Loss: 0.3959 | Train Spearman: 0.5920 | Val Spearman: 0.6332 | Time: 17.27s
#   → Saved new best model (Spearman: 0.6381)
#   → Saved new best model (Spearman: 0.6418)
# Epoch  20/50 | Train Loss: 0.3990 | Val Loss: 0.3823 | Train Spearman: 0.5981 | Val Spearman: 0.6359 | Time: 19.33s
#   → Saved new best model (Spearman: 0.6424)
#   → Saved new best model (Spearman: 0.6458)
# Epoch  25/50 | Train Loss: 0.3944 | Val Loss: 0.4031 | Train Spearman: 0.6024 | Val Spearman: 0.6393 | Time: 18.26s
# Epoch  30/50 | Train Loss: 0.3931 | Val Loss: 0.4180 | Train Spearman: 0.6027 | Val Spearman: 0.6355 | Time: 18.49s
#   → Saved new best model (Spearman: 0.6519)
#   → Saved new best model (Spearman: 0.6548)
#   → Saved new best model (Spearman: 0.6583)
# Epoch  35/50 | Train Loss: 0.3546 | Val Loss: 0.3698 | Train Spearman: 0.6230 | Val Spearman: 0.6522 | Time: 18.74s
# Epoch  40/50 | Train Loss: 0.3509 | Val Loss: 0.3513 | Train Spearman: 0.6239 | Val Spearman: 0.6537 | Time: 18.19s
#   → Saved new best model (Spearman: 0.6621)
#   → Saved new best model (Spearman: 0.6628)
#   → Saved new best model (Spearman: 0.6632)
# Epoch  45/50 | Train Loss: 0.3239 | Val Loss: 0.3419 | Train Spearman: 0.6384 | Val Spearman: 0.6632 | Time: 17.10s
#   → Saved new best model (Spearman: 0.6643)
# Epoch  50/50 | Train Loss: 0.3155 | Val Loss: 0.3417 | Train Spearman: 0.6410 | Val Spearman: 0.6643 | Time: 16.84s
#
# Training completed in 890.61s
# Best validation Spearman correlation: 0.6643
#   → Search progress saved to Outputs_t2/CNN_search_results_t2.json
#
# Running experiment 12/12: {'learning_rate': 0.005, 'hidden_dim': 512, 'dropout': 0.3}
#
# ============================================================
# Training CNN_exp11
# ============================================================
#   → Saved new best model (Spearman: 0.5316)
# Epoch   1/50 | Train Loss: 1.2259 | Val Loss: 0.5147 | Train Spearman: 0.3943 | Val Spearman: 0.5316 | Time: 18.72s
#   → Saved new best model (Spearman: 0.5667)
#   → Saved new best model (Spearman: 0.5716)
#   → Saved new best model (Spearman: 0.5721)
#   → Saved new best model (Spearman: 0.5926)
# Epoch   5/50 | Train Loss: 0.5062 | Val Loss: 0.4617 | Train Spearman: 0.5256 | Val Spearman: 0.5926 | Time: 16.46s
#   → Saved new best model (Spearman: 0.5968)
#   → Saved new best model (Spearman: 0.6074)
#   → Saved new best model (Spearman: 0.6084)
#   → Saved new best model (Spearman: 0.6150)
# Epoch  10/50 | Train Loss: 0.4517 | Val Loss: 0.4072 | Train Spearman: 0.5599 | Val Spearman: 0.6150 | Time: 17.05s
#   → Saved new best model (Spearman: 0.6160)
#   → Saved new best model (Spearman: 0.6177)
#   → Saved new best model (Spearman: 0.6210)
#   → Saved new best model (Spearman: 0.6238)
# Epoch  15/50 | Train Loss: 0.4446 | Val Loss: 0.4340 | Train Spearman: 0.5667 | Val Spearman: 0.6238 | Time: 18.94s
#   → Saved new best model (Spearman: 0.6273)
# Epoch  20/50 | Train Loss: 0.4331 | Val Loss: 0.4746 | Train Spearman: 0.5730 | Val Spearman: 0.6072 | Time: 19.10s
#   → Saved new best model (Spearman: 0.6283)
#   → Saved new best model (Spearman: 0.6306)
# Epoch  25/50 | Train Loss: 0.4342 | Val Loss: 0.4476 | Train Spearman: 0.5754 | Val Spearman: 0.6306 | Time: 18.81s
# Epoch  30/50 | Train Loss: 0.4294 | Val Loss: 0.4163 | Train Spearman: 0.5749 | Val Spearman: 0.6264 | Time: 18.04s
#   → Saved new best model (Spearman: 0.6314)
#   → Saved new best model (Spearman: 0.6363)
# Epoch  35/50 | Train Loss: 0.3950 | Val Loss: 0.4359 | Train Spearman: 0.5989 | Val Spearman: 0.6349 | Time: 18.85s
#   → Saved new best model (Spearman: 0.6373)
#   → Saved new best model (Spearman: 0.6404)
#   → Saved new best model (Spearman: 0.6429)
# Epoch  40/50 | Train Loss: 0.3853 | Val Loss: 0.3788 | Train Spearman: 0.6016 | Val Spearman: 0.6429 | Time: 16.90s
#   → Saved new best model (Spearman: 0.6454)
# Epoch  45/50 | Train Loss: 0.3803 | Val Loss: 0.3831 | Train Spearman: 0.6029 | Val Spearman: 0.6390 | Time: 16.95s
#   → Saved new best model (Spearman: 0.6454)
# Epoch  50/50 | Train Loss: 0.3615 | Val Loss: 0.3946 | Train Spearman: 0.6161 | Val Spearman: 0.6451 | Time: 16.52s
#
# Training completed in 885.77s
# Best validation Spearman correlation: 0.6454
#   → Search progress saved to Outputs_t2/CNN_search_results_t2.json
#
# ============================================================
# Best CNN configuration: {'learning_rate': 0.003, 'hidden_dim': 512, 'dropout': 0.2}
# Best validation Spearman: 0.6719
# Best model saved to Outputs_t2/best_cnn_model_t2.pth
# ============================================================

# %%
# 8.2 Train and Search LSTM
print("---- Tuning LSTM ----")
best_lstm_config, lstm_history = hyperparameter_search(
    RNABindingLSTM, 'LSTM', lstm_param_grid, train_loader, val_loader, device, epochs=50
)
# Out:
# ---- Tuning LSTM ----
# Starting Hyperparameter Search for LSTM with 12 configurations...
#
# Running experiment 1/12: {'learning_rate': 0.0003, 'hidden_dim': 256, 'dropout': 0.3}
#
# ============================================================
# Training LSTM_exp0
# ============================================================
#   → Saved new best model (Spearman: 0.4024)
# Epoch   1/50 | Train Loss: 0.9515 | Val Loss: 0.8642 | Train Spearman: 0.2551 | Val Spearman: 0.4024 | Time: 41.18s
#   → Saved new best model (Spearman: 0.4817)
#   → Saved new best model (Spearman: 0.5197)
#   → Saved new best model (Spearman: 0.5434)
#   → Saved new best model (Spearman: 0.5508)
# Epoch   5/50 | Train Loss: 0.5017 | Val Loss: 0.6212 | Train Spearman: 0.5373 | Val Spearman: 0.5508 | Time: 39.75s
#   → Saved new best model (Spearman: 0.5832)
#   → Saved new best model (Spearman: 0.5896)
#   → Saved new best model (Spearman: 0.6047)
#   → Saved new best model (Spearman: 0.6134)
# Epoch  10/50 | Train Loss: 0.4118 | Val Loss: 0.3925 | Train Spearman: 0.5921 | Val Spearman: 0.6134 | Time: 40.71s
#   → Saved new best model (Spearman: 0.6211)
# Epoch  15/50 | Train Loss: 0.3819 | Val Loss: 0.4198 | Train Spearman: 0.6134 | Val Spearman: 0.6206 | Time: 40.55s
#   → Saved new best model (Spearman: 0.6298)
#   → Saved new best model (Spearman: 0.6349)
#   → Saved new best model (Spearman: 0.6397)
# Epoch  20/50 | Train Loss: 0.3571 | Val Loss: 0.3832 | Train Spearman: 0.6302 | Val Spearman: 0.6340 | Time: 40.30s
#   → Saved new best model (Spearman: 0.6465)
#   → Saved new best model (Spearman: 0.6483)
# Epoch  25/50 | Train Loss: 0.3425 | Val Loss: 0.3638 | Train Spearman: 0.6401 | Val Spearman: 0.6481 | Time: 41.38s
#   → Saved new best model (Spearman: 0.6564)
#   → Saved new best model (Spearman: 0.6579)
#   → Saved new best model (Spearman: 0.6582)
# Epoch  30/50 | Train Loss: 0.3238 | Val Loss: 0.3581 | Train Spearman: 0.6502 | Val Spearman: 0.6570 | Time: 38.77s
#   → Saved new best model (Spearman: 0.6641)
#   → Saved new best model (Spearman: 0.6646)
#   → Saved new best model (Spearman: 0.6696)
# Epoch  35/50 | Train Loss: 0.3108 | Val Loss: 0.3450 | Train Spearman: 0.6569 | Val Spearman: 0.6634 | Time: 40.52s
#   → Saved new best model (Spearman: 0.6710)
# Epoch  40/50 | Train Loss: 0.2944 | Val Loss: 0.3334 | Train Spearman: 0.6648 | Val Spearman: 0.6683 | Time: 40.57s
#   → Saved new best model (Spearman: 0.6760)
#   → Saved new best model (Spearman: 0.6803)
# Epoch  45/50 | Train Loss: 0.2612 | Val Loss: 0.3290 | Train Spearman: 0.6805 | Val Spearman: 0.6782 | Time: 38.92s
# Epoch  50/50 | Train Loss: 0.2496 | Val Loss: 0.3253 | Train Spearman: 0.6854 | Val Spearman: 0.6800 | Time: 41.13s
#
# Training completed in 2022.07s
# Best validation Spearman correlation: 0.6803
#   → Search progress saved to Outputs_t2/LSTM_search_results_t2.json
#
# Running experiment 2/12: {'learning_rate': 0.0003, 'hidden_dim': 256, 'dropout': 0.4}
#
# ============================================================
# Training LSTM_exp1
# ============================================================
#   → Saved new best model (Spearman: 0.3808)
# Epoch   1/50 | Train Loss: 0.9669 | Val Loss: 0.8677 | Train Spearman: 0.2330 | Val Spearman: 0.3808 | Time: 38.54s
#   → Saved new best model (Spearman: 0.4789)
#   → Saved new best model (Spearman: 0.5199)
#   → Saved new best model (Spearman: 0.5418)
# Epoch   5/50 | Train Loss: 0.5157 | Val Loss: 0.6601 | Train Spearman: 0.5267 | Val Spearman: 0.5410 | Time: 41.00s
#   → Saved new best model (Spearman: 0.5443)
#   → Saved new best model (Spearman: 0.5882)
# Epoch  10/50 | Train Loss: 0.4237 | Val Loss: 0.4250 | Train Spearman: 0.5813 | Val Spearman: 0.6011 | Time: 39.94s
#   → Saved new best model (Spearman: 0.6202)
#   → Saved new best model (Spearman: 0.6291)
# Epoch  15/50 | Train Loss: 0.3884 | Val Loss: 0.3902 | Train Spearman: 0.6079 | Val Spearman: 0.6291 | Time: 41.59s
#   → Saved new best model (Spearman: 0.6308)
#   → Saved new best model (Spearman: 0.6434)
# Epoch  20/50 | Train Loss: 0.3683 | Val Loss: 0.3601 | Train Spearman: 0.6241 | Val Spearman: 0.6425 | Time: 41.25s
#   → Saved new best model (Spearman: 0.6487)
#   → Saved new best model (Spearman: 0.6490)
# Epoch  25/50 | Train Loss: 0.3528 | Val Loss: 0.3776 | Train Spearman: 0.6342 | Val Spearman: 0.6472 | Time: 38.57s
#   → Saved new best model (Spearman: 0.6508)
#   → Saved new best model (Spearman: 0.6525)
#   → Saved new best model (Spearman: 0.6559)
#   → Saved new best model (Spearman: 0.6572)
# Epoch  30/50 | Train Loss: 0.3349 | Val Loss: 0.3504 | Train Spearman: 0.6441 | Val Spearman: 0.6528 | Time: 41.19s
#   → Saved new best model (Spearman: 0.6583)
#   → Saved new best model (Spearman: 0.6646)
# Epoch  35/50 | Train Loss: 0.3198 | Val Loss: 0.3506 | Train Spearman: 0.6528 | Val Spearman: 0.6556 | Time: 40.68s
#   → Saved new best model (Spearman: 0.6651)
#   → Saved new best model (Spearman: 0.6661)
#   → Saved new best model (Spearman: 0.6676)
# Epoch  40/50 | Train Loss: 0.3054 | Val Loss: 0.3299 | Train Spearman: 0.6577 | Val Spearman: 0.6676 | Time: 38.50s
#   → Saved new best model (Spearman: 0.6735)
# Epoch  45/50 | Train Loss: 0.2922 | Val Loss: 0.3299 | Train Spearman: 0.6636 | Val Spearman: 0.6686 | Time: 41.02s
#   → Saved new best model (Spearman: 0.6741)
# Epoch  50/50 | Train Loss: 0.2795 | Val Loss: 0.3289 | Train Spearman: 0.6674 | Val Spearman: 0.6741 | Time: 40.96s
#
# Training completed in 2016.18s
# Best validation Spearman correlation: 0.6741
#   → Search progress saved to Outputs_t2/LSTM_search_results_t2.json
#
# Running experiment 3/12: {'learning_rate': 0.0003, 'hidden_dim': 512, 'dropout': 0.3}
#
# ============================================================
# Training LSTM_exp2
# ============================================================
#   → Saved new best model (Spearman: 0.3786)
# Epoch   1/50 | Train Loss: 0.9694 | Val Loss: 0.8678 | Train Spearman: 0.2324 | Val Spearman: 0.3786 | Time: 51.96s
#   → Saved new best model (Spearman: 0.4043)
#   → Saved new best model (Spearman: 0.5197)
#   → Saved new best model (Spearman: 0.5416)
# Epoch   5/50 | Train Loss: 0.5193 | Val Loss: 0.5489 | Train Spearman: 0.5259 | Val Spearman: 0.5416 | Time: 51.83s
#   → Saved new best model (Spearman: 0.5744)
#   → Saved new best model (Spearman: 0.5860)
#   → Saved new best model (Spearman: 0.6078)
# Epoch  10/50 | Train Loss: 0.4234 | Val Loss: 0.4397 | Train Spearman: 0.5894 | Val Spearman: 0.6078 | Time: 51.22s
#   → Saved new best model (Spearman: 0.6096)
#   → Saved new best model (Spearman: 0.6238)
# Epoch  15/50 | Train Loss: 0.3855 | Val Loss: 0.3831 | Train Spearman: 0.6111 | Val Spearman: 0.6129 | Time: 51.29s
#   → Saved new best model (Spearman: 0.6282)
#   → Saved new best model (Spearman: 0.6344)
# Epoch  20/50 | Train Loss: 0.3658 | Val Loss: 0.3805 | Train Spearman: 0.6275 | Val Spearman: 0.6336 | Time: 51.13s
#   → Saved new best model (Spearman: 0.6476)
# Epoch  25/50 | Train Loss: 0.3475 | Val Loss: 0.4872 | Train Spearman: 0.6375 | Val Spearman: 0.6439 | Time: 53.30s
#   → Saved new best model (Spearman: 0.6515)
#   → Saved new best model (Spearman: 0.6538)
# Epoch  30/50 | Train Loss: 0.3310 | Val Loss: 0.3594 | Train Spearman: 0.6456 | Val Spearman: 0.6487 | Time: 51.58s
#   → Saved new best model (Spearman: 0.6570)
#   → Saved new best model (Spearman: 0.6599)
#   → Saved new best model (Spearman: 0.6650)
# Epoch  35/50 | Train Loss: 0.3170 | Val Loss: 0.3469 | Train Spearman: 0.6530 | Val Spearman: 0.6581 | Time: 51.69s
# Epoch  40/50 | Train Loss: 0.3055 | Val Loss: 0.3449 | Train Spearman: 0.6600 | Val Spearman: 0.6634 | Time: 53.40s
#   → Saved new best model (Spearman: 0.6728)
#   → Saved new best model (Spearman: 0.6746)
#   → Saved new best model (Spearman: 0.6778)
# Epoch  45/50 | Train Loss: 0.2697 | Val Loss: 0.3186 | Train Spearman: 0.6755 | Val Spearman: 0.6736 | Time: 51.54s
#   → Saved new best model (Spearman: 0.6795)
#   → Saved new best model (Spearman: 0.6795)
# Epoch  50/50 | Train Loss: 0.2591 | Val Loss: 0.3157 | Train Spearman: 0.6799 | Val Spearman: 0.6778 | Time: 51.51s
#
# Training completed in 2603.24s
# Best validation Spearman correlation: 0.6795
#   → Search progress saved to Outputs_t2/LSTM_search_results_t2.json
#
# Running experiment 4/12: {'learning_rate': 0.0003, 'hidden_dim': 512, 'dropout': 0.4}
#
# ============================================================
# Training LSTM_exp3
# ============================================================
#   → Saved new best model (Spearman: 0.3587)
# Epoch   1/50 | Train Loss: 0.9768 | Val Loss: 1.3148 | Train Spearman: 0.2225 | Val Spearman: 0.3587 | Time: 53.73s
#   → Saved new best model (Spearman: 0.4133)
#   → Saved new best model (Spearman: 0.5184)
#   → Saved new best model (Spearman: 0.5342)
#   → Saved new best model (Spearman: 0.5462)
# Epoch   5/50 | Train Loss: 0.5119 | Val Loss: 0.5176 | Train Spearman: 0.5316 | Val Spearman: 0.5462 | Time: 50.78s
#   → Saved new best model (Spearman: 0.5575)
#   → Saved new best model (Spearman: 0.5877)
#   → Saved new best model (Spearman: 0.6082)
#   → Saved new best model (Spearman: 0.6142)
# Epoch  10/50 | Train Loss: 0.4194 | Val Loss: 0.4014 | Train Spearman: 0.5897 | Val Spearman: 0.6142 | Time: 51.45s
#   → Saved new best model (Spearman: 0.6212)
#   → Saved new best model (Spearman: 0.6229)
# Epoch  15/50 | Train Loss: 0.3889 | Val Loss: 0.3774 | Train Spearman: 0.6107 | Val Spearman: 0.6186 | Time: 53.71s
#   → Saved new best model (Spearman: 0.6277)
#   → Saved new best model (Spearman: 0.6318)
#   → Saved new best model (Spearman: 0.6475)
# Epoch  20/50 | Train Loss: 0.3680 | Val Loss: 0.3756 | Train Spearman: 0.6248 | Val Spearman: 0.6410 | Time: 51.20s
#   → Saved new best model (Spearman: 0.6510)
# Epoch  25/50 | Train Loss: 0.3531 | Val Loss: 0.4091 | Train Spearman: 0.6349 | Val Spearman: 0.6446 | Time: 51.44s
#   → Saved new best model (Spearman: 0.6517)
#   → Saved new best model (Spearman: 0.6585)
# Epoch  30/50 | Train Loss: 0.3360 | Val Loss: 0.3459 | Train Spearman: 0.6420 | Val Spearman: 0.6585 | Time: 53.20s
#   → Saved new best model (Spearman: 0.6626)
# Epoch  35/50 | Train Loss: 0.3234 | Val Loss: 0.3526 | Train Spearman: 0.6505 | Val Spearman: 0.6599 | Time: 51.16s
#   → Saved new best model (Spearman: 0.6643)
# Epoch  40/50 | Train Loss: 0.3152 | Val Loss: 0.3376 | Train Spearman: 0.6550 | Val Spearman: 0.6609 | Time: 52.73s
#   → Saved new best model (Spearman: 0.6656)
#   → Saved new best model (Spearman: 0.6690)
#   → Saved new best model (Spearman: 0.6696)
# Epoch  45/50 | Train Loss: 0.3017 | Val Loss: 0.3297 | Train Spearman: 0.6611 | Val Spearman: 0.6630 | Time: 51.90s
#   → Saved new best model (Spearman: 0.6729)
#   → Saved new best model (Spearman: 0.6737)
# Epoch  50/50 | Train Loss: 0.2910 | Val Loss: 0.3181 | Train Spearman: 0.6679 | Val Spearman: 0.6737 | Time: 54.11s
#
# Training completed in 2609.73s
# Best validation Spearman correlation: 0.6737
#   → Search progress saved to Outputs_t2/LSTM_search_results_t2.json
#
# Running experiment 5/12: {'learning_rate': 0.0005, 'hidden_dim': 256, 'dropout': 0.3}
#
# ============================================================
# Training LSTM_exp4
# ============================================================
#   → Saved new best model (Spearman: 0.4219)
# Epoch   1/50 | Train Loss: 0.9194 | Val Loss: 1.2222 | Train Spearman: 0.2945 | Val Spearman: 0.4219 | Time: 38.87s
#   → Saved new best model (Spearman: 0.5160)
#   → Saved new best model (Spearman: 0.5396)
#   → Saved new best model (Spearman: 0.5635)
# Epoch   5/50 | Train Loss: 0.4705 | Val Loss: 0.6767 | Train Spearman: 0.5566 | Val Spearman: 0.5604 | Time: 40.73s
#   → Saved new best model (Spearman: 0.6048)
#   → Saved new best model (Spearman: 0.6050)
#   → Saved new best model (Spearman: 0.6214)
# Epoch  10/50 | Train Loss: 0.4037 | Val Loss: 0.3990 | Train Spearman: 0.5986 | Val Spearman: 0.6214 | Time: 38.70s
#   → Saved new best model (Spearman: 0.6398)
# Epoch  15/50 | Train Loss: 0.3702 | Val Loss: 0.3774 | Train Spearman: 0.6217 | Val Spearman: 0.6342 | Time: 38.75s
#   → Saved new best model (Spearman: 0.6441)
#   → Saved new best model (Spearman: 0.6499)
#   → Saved new best model (Spearman: 0.6524)
# Epoch  20/50 | Train Loss: 0.3483 | Val Loss: 0.3555 | Train Spearman: 0.6359 | Val Spearman: 0.6478 | Time: 40.58s
#   → Saved new best model (Spearman: 0.6547)
#   → Saved new best model (Spearman: 0.6624)
# Epoch  25/50 | Train Loss: 0.3304 | Val Loss: 0.3565 | Train Spearman: 0.6469 | Val Spearman: 0.6623 | Time: 41.35s
#   → Saved new best model (Spearman: 0.6639)
#   → Saved new best model (Spearman: 0.6642)
# Epoch  30/50 | Train Loss: 0.3134 | Val Loss: 0.3414 | Train Spearman: 0.6552 | Val Spearman: 0.6642 | Time: 39.13s
#   → Saved new best model (Spearman: 0.6673)
#   → Saved new best model (Spearman: 0.6735)
#   → Saved new best model (Spearman: 0.6743)
# Epoch  35/50 | Train Loss: 0.2979 | Val Loss: 0.3207 | Train Spearman: 0.6626 | Val Spearman: 0.6743 | Time: 38.77s
#   → Saved new best model (Spearman: 0.6749)
# Epoch  40/50 | Train Loss: 0.2800 | Val Loss: 0.3355 | Train Spearman: 0.6686 | Val Spearman: 0.6636 | Time: 41.96s
#   → Saved new best model (Spearman: 0.6770)
#   → Saved new best model (Spearman: 0.6812)
# Epoch  45/50 | Train Loss: 0.2437 | Val Loss: 0.3178 | Train Spearman: 0.6855 | Val Spearman: 0.6791 | Time: 41.87s
#   → Saved new best model (Spearman: 0.6823)
# Epoch  50/50 | Train Loss: 0.2314 | Val Loss: 0.3189 | Train Spearman: 0.6912 | Val Spearman: 0.6791 | Time: 41.44s
#
# Training completed in 2022.34s
# Best validation Spearman correlation: 0.6823
#   → Search progress saved to Outputs_t2/LSTM_search_results_t2.json
#
# Running experiment 6/12: {'learning_rate': 0.0005, 'hidden_dim': 256, 'dropout': 0.4}
#
# ============================================================
# Training LSTM_exp5
# ============================================================
#   → Saved new best model (Spearman: 0.4149)
# Epoch   1/50 | Train Loss: 0.9347 | Val Loss: 0.8781 | Train Spearman: 0.2736 | Val Spearman: 0.4149 | Time: 41.38s
#   → Saved new best model (Spearman: 0.5090)
#   → Saved new best model (Spearman: 0.5587)
# Epoch   5/50 | Train Loss: 0.4932 | Val Loss: 0.6965 | Train Spearman: 0.5398 | Val Spearman: 0.5587 | Time: 38.99s
#   → Saved new best model (Spearman: 0.5849)
#   → Saved new best model (Spearman: 0.5995)
#   → Saved new best model (Spearman: 0.6270)
# Epoch  10/50 | Train Loss: 0.4146 | Val Loss: 0.3869 | Train Spearman: 0.5909 | Val Spearman: 0.6270 | Time: 39.03s
#   → Saved new best model (Spearman: 0.6329)
#   → Saved new best model (Spearman: 0.6330)
# Epoch  15/50 | Train Loss: 0.3844 | Val Loss: 0.3864 | Train Spearman: 0.6118 | Val Spearman: 0.6330 | Time: 41.48s
#   → Saved new best model (Spearman: 0.6397)
#   → Saved new best model (Spearman: 0.6487)
#   → Saved new best model (Spearman: 0.6502)
# Epoch  20/50 | Train Loss: 0.3597 | Val Loss: 0.3660 | Train Spearman: 0.6287 | Val Spearman: 0.6424 | Time: 41.22s
#   → Saved new best model (Spearman: 0.6517)
#   → Saved new best model (Spearman: 0.6531)
#   → Saved new best model (Spearman: 0.6552)
# Epoch  25/50 | Train Loss: 0.3419 | Val Loss: 0.3787 | Train Spearman: 0.6387 | Val Spearman: 0.6552 | Time: 41.04s
#   → Saved new best model (Spearman: 0.6609)
#   → Saved new best model (Spearman: 0.6621)
# Epoch  30/50 | Train Loss: 0.3207 | Val Loss: 0.3389 | Train Spearman: 0.6487 | Val Spearman: 0.6596 | Time: 38.98s
#   → Saved new best model (Spearman: 0.6623)
#   → Saved new best model (Spearman: 0.6663)
#   → Saved new best model (Spearman: 0.6693)
# Epoch  35/50 | Train Loss: 0.3096 | Val Loss: 0.3295 | Train Spearman: 0.6562 | Val Spearman: 0.6665 | Time: 38.56s
# Epoch  40/50 | Train Loss: 0.2927 | Val Loss: 0.3279 | Train Spearman: 0.6623 | Val Spearman: 0.6648 | Time: 41.73s
#   → Saved new best model (Spearman: 0.6732)
#   → Saved new best model (Spearman: 0.6747)
#   → Saved new best model (Spearman: 0.6758)
#   → Saved new best model (Spearman: 0.6764)
# Epoch  45/50 | Train Loss: 0.2559 | Val Loss: 0.3186 | Train Spearman: 0.6790 | Val Spearman: 0.6758 | Time: 41.78s
#   → Saved new best model (Spearman: 0.6782)
# Epoch  50/50 | Train Loss: 0.2439 | Val Loss: 0.3199 | Train Spearman: 0.6838 | Val Spearman: 0.6769 | Time: 42.39s
#
# Training completed in 2027.11s
# Best validation Spearman correlation: 0.6782
#   → Search progress saved to Outputs_t2/LSTM_search_results_t2.json
#
# Running experiment 7/12: {'learning_rate': 0.0005, 'hidden_dim': 512, 'dropout': 0.3}
#
# ============================================================
# Training LSTM_exp6
# ============================================================
#   → Saved new best model (Spearman: 0.4121)
# Epoch   1/50 | Train Loss: 0.9503 | Val Loss: 2.5643 | Train Spearman: 0.2601 | Val Spearman: 0.4121 | Time: 51.61s
#   → Saved new best model (Spearman: 0.4615)
#   → Saved new best model (Spearman: 0.5242)
#   → Saved new best model (Spearman: 0.5648)
# Epoch   5/50 | Train Loss: 0.4692 | Val Loss: 0.5432 | Train Spearman: 0.5616 | Val Spearman: 0.5648 | Time: 51.51s
#   → Saved new best model (Spearman: 0.5795)
#   → Saved new best model (Spearman: 0.5928)
#   → Saved new best model (Spearman: 0.5985)
#   → Saved new best model (Spearman: 0.6064)
#   → Saved new best model (Spearman: 0.6256)
# Epoch  10/50 | Train Loss: 0.3966 | Val Loss: 0.3773 | Train Spearman: 0.6072 | Val Spearman: 0.6256 | Time: 51.24s
#   → Saved new best model (Spearman: 0.6277)
#   → Saved new best model (Spearman: 0.6455)
# Epoch  15/50 | Train Loss: 0.3637 | Val Loss: 0.4208 | Train Spearman: 0.6273 | Val Spearman: 0.6455 | Time: 54.11s
#   → Saved new best model (Spearman: 0.6464)
#   → Saved new best model (Spearman: 0.6542)
# Epoch  20/50 | Train Loss: 0.3421 | Val Loss: 0.3644 | Train Spearman: 0.6432 | Val Spearman: 0.6459 | Time: 51.65s
#   → Saved new best model (Spearman: 0.6598)
#   → Saved new best model (Spearman: 0.6623)
#   → Saved new best model (Spearman: 0.6667)
# Epoch  25/50 | Train Loss: 0.3251 | Val Loss: 0.3898 | Train Spearman: 0.6523 | Val Spearman: 0.6598 | Time: 51.09s
#   → Saved new best model (Spearman: 0.6685)
# Epoch  30/50 | Train Loss: 0.3079 | Val Loss: 0.3345 | Train Spearman: 0.6577 | Val Spearman: 0.6685 | Time: 52.70s
#   → Saved new best model (Spearman: 0.6692)
# Epoch  35/50 | Train Loss: 0.2941 | Val Loss: 0.3434 | Train Spearman: 0.6662 | Val Spearman: 0.6692 | Time: 51.96s
#   → Saved new best model (Spearman: 0.6731)
# Epoch  40/50 | Train Loss: 0.2765 | Val Loss: 0.3385 | Train Spearman: 0.6720 | Val Spearman: 0.6720 | Time: 53.85s
#   → Saved new best model (Spearman: 0.6771)
#   → Saved new best model (Spearman: 0.6814)
# Epoch  45/50 | Train Loss: 0.2407 | Val Loss: 0.3353 | Train Spearman: 0.6880 | Val Spearman: 0.6789 | Time: 54.38s
# Epoch  50/50 | Train Loss: 0.2252 | Val Loss: 0.3256 | Train Spearman: 0.6937 | Val Spearman: 0.6804 | Time: 51.63s
#
# Training completed in 2614.54s
# Best validation Spearman correlation: 0.6814
#   → Search progress saved to Outputs_t2/LSTM_search_results_t2.json
#
# Running experiment 8/12: {'learning_rate': 0.0005, 'hidden_dim': 512, 'dropout': 0.4}
#
# ============================================================
# Training LSTM_exp7
# ============================================================
#   → Saved new best model (Spearman: 0.3403)
# Epoch   1/50 | Train Loss: 0.9699 | Val Loss: 1.7170 | Train Spearman: 0.2320 | Val Spearman: 0.3403 | Time: 52.08s
#   → Saved new best model (Spearman: 0.4751)
#   → Saved new best model (Spearman: 0.5233)
#   → Saved new best model (Spearman: 0.5392)
# Epoch   5/50 | Train Loss: 0.5292 | Val Loss: 0.8379 | Train Spearman: 0.5207 | Val Spearman: 0.5096 | Time: 50.89s
#   → Saved new best model (Spearman: 0.5569)
#   → Saved new best model (Spearman: 0.5867)
#   → Saved new best model (Spearman: 0.5896)
#   → Saved new best model (Spearman: 0.5986)
# Epoch  10/50 | Train Loss: 0.4241 | Val Loss: 0.4140 | Train Spearman: 0.5876 | Val Spearman: 0.5986 | Time: 51.17s
#   → Saved new best model (Spearman: 0.6012)
#   → Saved new best model (Spearman: 0.6239)
#   → Saved new best model (Spearman: 0.6301)
#   → Saved new best model (Spearman: 0.6337)
# Epoch  15/50 | Train Loss: 0.3803 | Val Loss: 0.3802 | Train Spearman: 0.6163 | Val Spearman: 0.6337 | Time: 52.95s
#   → Saved new best model (Spearman: 0.6365)
#   → Saved new best model (Spearman: 0.6465)
# Epoch  20/50 | Train Loss: 0.3561 | Val Loss: 0.3641 | Train Spearman: 0.6353 | Val Spearman: 0.6456 | Time: 50.61s
#   → Saved new best model (Spearman: 0.6606)
# Epoch  25/50 | Train Loss: 0.3353 | Val Loss: 0.4046 | Train Spearman: 0.6459 | Val Spearman: 0.6489 | Time: 51.92s
#   → Saved new best model (Spearman: 0.6714)
#   → Saved new best model (Spearman: 0.6727)
# Epoch  30/50 | Train Loss: 0.2958 | Val Loss: 0.3264 | Train Spearman: 0.6661 | Val Spearman: 0.6727 | Time: 52.28s
#   → Saved new best model (Spearman: 0.6736)
# Epoch  35/50 | Train Loss: 0.2813 | Val Loss: 0.3279 | Train Spearman: 0.6715 | Val Spearman: 0.6712 | Time: 54.10s
#   → Saved new best model (Spearman: 0.6738)
#   → Saved new best model (Spearman: 0.6768)
# Epoch  40/50 | Train Loss: 0.2688 | Val Loss: 0.3135 | Train Spearman: 0.6766 | Val Spearman: 0.6759 | Time: 51.68s
#   → Saved new best model (Spearman: 0.6771)
# Epoch  45/50 | Train Loss: 0.2407 | Val Loss: 0.3205 | Train Spearman: 0.6871 | Val Spearman: 0.6771 | Time: 51.90s
#   → Saved new best model (Spearman: 0.6780)
#   → Saved new best model (Spearman: 0.6806)
#   → Saved new best model (Spearman: 0.6807)

# %% [markdown]
# ## 9. Test Evaluation

# %%
# Load best CNN model
cnn_model = RNABindingCNN(
    hidden_dim=best_cnn_config['hidden_dim'], 
    dropout=best_cnn_config['dropout']
).to(device)
cnn_model.load_state_dict(torch.load(f'{OUTPUT_DIR}/best_cnn_model_t2.pth'))

# Evaluate CNN on test set
cnn_test_loss, cnn_test_corr = evaluate(cnn_model, test_loader, device)
print(f"\nBest CNN Test Results:")
print(f"  Test Loss: {cnn_test_loss:.4f}")
print(f"  Test Spearman Correlation: {cnn_test_corr:.4f}")

# %%
# Load best LSTM model
lstm_model = RNABindingLSTM(
    hidden_dim=best_lstm_config['hidden_dim'], 
    dropout=best_lstm_config['dropout']
).to(device)
lstm_model.load_state_dict(torch.load(f'{OUTPUT_DIR}/best_lstm_model_t2.pth'))

# Evaluate LSTM on test set
lstm_test_loss, lstm_test_corr = evaluate(lstm_model, test_loader, device)
print(f"\nBest LSTM Test Results:")
print(f"  Test Loss: {lstm_test_loss:.4f}")
print(f"  Test Spearman Correlation: {lstm_test_corr:.4f}")

# %% [markdown]
# ## 10. Plotting Results and Saving History
#
# Saving plots and full experiment history to JSON for reproducibility.

# %%
import json

def save_and_plot_results(cnn_hist, lstm_hist, cnn_config, lstm_config, cnn_test_res, lstm_test_res):
    # Unpack test results
    cnn_test_loss, cnn_test_corr = cnn_test_res
    lstm_test_loss, lstm_test_corr = lstm_test_res
    
    # 1. Prepare Data for JSON Storage
    experiment_data = {
        "CNN": {
            "parameters": cnn_config,
            "training_time_seconds": cnn_hist['training_time'],
            "best_val_accuracy": cnn_hist['best_val_corr'],
            "best_val_epoch": int(np.argmax(cnn_hist['val_correlations']) + 1),
            "test_loss": cnn_test_loss,
            "test_accuracy": cnn_test_corr,
            "history": {
                "train_losses": cnn_hist['train_losses'],
                "train_correlations": cnn_hist['train_correlations'],
                "val_losses": cnn_hist['val_losses'],
                "val_correlations": cnn_hist['val_correlations']
            }
        },
        "LSTM": {
            "parameters": lstm_config,
            "training_time_seconds": lstm_hist['training_time'],
            "best_val_accuracy": lstm_hist['best_val_corr'],
            "best_val_epoch": int(np.argmax(lstm_hist['val_correlations']) + 1),
            "test_loss": lstm_test_loss,
            "test_accuracy": lstm_test_corr,
            "history": {
                "train_losses": lstm_hist['train_losses'],
                "train_correlations": lstm_hist['train_correlations'],
                "val_losses": lstm_hist['val_losses'],
                "val_correlations": lstm_hist['val_correlations']
            }
        }
    }

    # Save to JSON
    json_path = f'{OUTPUT_DIR}/complete_experiment_data_t2.json'
    with open(json_path, 'w') as f:
        json.dump(experiment_data, f, indent=4)
    print(f"Complete experiment data saved to '{json_path}'")

    # 2. Plotting
    epochs_cnn = range(1, len(cnn_hist['train_losses']) + 1)
    epochs_lstm = range(1, len(lstm_hist['train_losses']) + 1)

    # --- Plot 1: Loss ---
    plt.figure(figsize=(10, 6))
    plt.plot(epochs_cnn, cnn_hist['train_losses'], label='CNN Train Loss', color='blue', linestyle='--')
    plt.plot(epochs_cnn, cnn_hist['val_losses'], label='CNN Val Loss', color='blue')
    plt.plot(epochs_lstm, lstm_hist['train_losses'], label='LSTM Train Loss', color='red', linestyle='--')
    plt.plot(epochs_lstm, lstm_hist['val_losses'], label='LSTM Val Loss', color='red')
    plt.xlabel('Epochs')
    plt.ylabel('Loss (MSE)')
    plt.title('Training and Validation Loss')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.savefig(f'{OUTPUT_DIR}/loss_plot.png')
    plt.close()

    # --- Plot 2: Accuracy (Spearman Correlation) ---
    plt.figure(figsize=(10, 6))
    plt.plot(epochs_cnn, cnn_hist['train_correlations'], label='CNN Train Spearman', color='blue', linestyle='--')
    plt.plot(epochs_cnn, cnn_hist['val_correlations'], label='CNN Val Spearman', color='blue')
    plt.plot(epochs_lstm, lstm_hist['train_correlations'], label='LSTM Train Spearman', color='red', linestyle='--')
    plt.plot(epochs_lstm, lstm_hist['val_correlations'], label='LSTM Val Spearman', color='red')
    plt.xlabel('Epochs')
    plt.ylabel('Spearman Correlation')
    plt.title('Training and Validation Spearman Correlation')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.savefig(f'{OUTPUT_DIR}/accuracy_plot.png')
    plt.close()
    
    print("Plots saved to 'loss_plot.png' and 'accuracy_plot.png'.")

# Execute
save_and_plot_results(
    cnn_history, lstm_history, 
    best_cnn_config, best_lstm_config, 
    (cnn_test_loss, cnn_test_corr), 
    (lstm_test_loss, lstm_test_corr)
)
